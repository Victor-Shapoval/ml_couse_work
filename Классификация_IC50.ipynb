# %% [markdown]
# ### Используемые библиотеки

# %%
import pandas as pd
from skopt import BayesSearchCV
from catboost import CatBoostClassifier
from skopt.space import Categorical, Real
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, mutual_info_regression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# считываем обработанные данные
df = pd.read_csv("data.csv")
df_y = df[['IC50, mM', 'CC50, mM', 'SI']].copy()
df_x = df.drop(columns=['IC50, mM', 'CC50, mM', 'SI'])

# добавляем новый признак согласно заданию
median = df_y['IC50, mM'].median()
df_y['bool'] = (df_y['IC50, mM'] > median).astype(bool)

# %% [markdown]
# ### Классификация IC50 (превышение медианного значения выборки)

# %%
# датасет для сравнения метрик по каждой из модели
metrics = pd.DataFrame(columns=["Accuracy",
                                "Precision",
                                "Recall",
                                "F1-score",
                                "ROC AUC"]
                                )

# %%
# избавимся от лишних признаков, выделим целевую переменную и добавим дополнительный признак
y_data = df_y['bool']
x_data = df_x
x_data['CC50, mM'] = df_y['CC50, mM']

# сократим количество признаков до 50 с помощью Mutual Info
selector = SelectKBest(score_func=mutual_info_regression, k=50)
select_x_data = selector.fit_transform(x_data, y_data)
selected_features = x_data.columns[selector.get_support()]
x_data = pd.DataFrame(select_x_data, columns=selected_features)

# разделим данные на тестовыые и тренировочные
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)
print(f'Тренеровочные данные: {X_train.shape}, {y_train.shape}')
print(f'Tестовые данные: {X_test.shape}, {y_test.shape}')

# стандартизируем данные train
scaler = StandardScaler()
tmp_data = scaler.fit_transform(X_train)
scaled_X_train = pd.DataFrame(tmp_data, columns=x_data.columns)

# стандартизируем данные test
tmp_data = scaler.transform(X_test)
scaled_X_test = pd.DataFrame(tmp_data, columns=x_data.columns)
# Out:
# Тренеровочные данные: (772, 50), (772,)
# Tестовые данные: (194, 50), (194,)

# %% [markdown]
# #### RandomForestClassifier

# %%
# определим пространство гиперпараметров для модели RandomForestClassifier
param_space_rfr = {
    'n_estimators': (50, 500),
    'max_depth': (1, 50),
    'min_samples_split': (2, 20),
    'min_samples_leaf': (1, 10),
    'max_features': Categorical(['sqrt', 'log2']),
    'bootstrap': Categorical([True, False])
}

# создадим модель
model = RandomForestClassifier(random_state=42)

# оптимизируем с помощью Байесовского поиска
bayes_search = BayesSearchCV(
    estimator=model,
    search_spaces=param_space_rfr,
    n_iter=20,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=42,
)

bayes_search.fit(scaled_X_train, y_train)

# выведем показатели
roc_auc = round(bayes_search.best_score_, 4)
print(f'ROC AUC = {roc_auc}\n')
print('Лучшие параметры модели:')
for k, v in bayes_search.best_params_.items():
    print(f"{k} = {v}")

# сохраним модель с наилучшими параметрами
rfc_model = bayes_search.best_estimator_
# Out:
# ROC AUC = 0.8266
#
# Лучшие параметры модели:
# bootstrap = True
# max_depth = 50
# max_features = sqrt
# min_samples_leaf = 10
# min_samples_split = 20
# n_estimators = 500

# %%
# расcчитаем y
y_pred = rfc_model.predict(scaled_X_test)

# оценим метрики
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {round(accuracy, 4)}")
print(f"Precision: {round(precision, 4)}")  
print(f"Recall: {round(recall, 4)}")        
print(f"F1-score: {round(f1, 4)}")

# сохраним данные в таблицу
res = {"Accuracy": round(accuracy, 4),
       "Precision": round(precision, 4),
       "Recall": round(recall, 4),
       "F1-score": round(f1, 4),
       "ROC AUC": round(roc_auc, 4)}

metrics.loc[0] = res
# Out:
# Accuracy: 0.8299
# Precision: 0.8571
# Recall: 0.75
# F1-score: 0.8

# %% [markdown]
# #### GradientBoostingClassifier

# %%
# определим пространство гиперпараметров для модели GradientBoostingClassifier
param_space_gbr = {
    'n_estimators': (10, 200),
    'max_depth': (1, 20),
    'min_samples_split': (2, 10),
    'min_samples_leaf': (1, 7),
}

# создадим модель
model = GradientBoostingClassifier(random_state=42)

# оптимизируем с помощью Байесовского поиска
bayes_search = BayesSearchCV(
    estimator=model,
    search_spaces=param_space_gbr,
    n_iter=20,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=42,
)

bayes_search.fit(scaled_X_train, y_train)

# выведем показатели
roc_auc = round(bayes_search.best_score_, 4)
print(f'ROC AUC = {roc_auc}\n')
print('Лучшие параметры модели:')
for k, v in bayes_search.best_params_.items():
    print(f"{k} = {v}")

# сохраним модель с наилучшими параметрами
gbc_model = bayes_search.best_estimator_
# Out:
# ROC AUC = 0.8407
#
# Лучшие параметры модели:
# max_depth = 4
# min_samples_leaf = 4
# min_samples_split = 6
# n_estimators = 200

# %%
# расcчитаем y
y_pred = gbc_model.predict(scaled_X_test)

# оценим метрики
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {round(accuracy, 4)}")
print(f"Precision: {round(precision, 4)}")  
print(f"Recall: {round(recall, 4)}")        
print(f"F1-score: {round(f1, 4)}")

# сохраним данные в таблицу
res = {"Accuracy": round(accuracy, 4),
       "Precision": round(precision, 4),
       "Recall": round(recall, 4),
       "F1-score": round(f1, 4),
       "ROC AUC": round(roc_auc, 4)}

metrics.loc[1] = res
# Out:
# Accuracy: 0.8093
# Precision: 0.8493
# Recall: 0.7045
# F1-score: 0.7702

# %% [markdown]
# #### CatBoostClassifier

# %%
# определим пространство гиперпараметров для модели CatBoostClassifier
param_space_cbc = {
    'iterations': (100, 1000),
    'depth': (4, 10),
    'grow_policy': Categorical(['SymmetricTree', 'Depthwise', 'Lossguide']),
    'loss_function': Categorical(['Logloss', 'CrossEntropy']),
    'l2_leaf_reg': Real(1, 10),
    'min_data_in_leaf': (1, 50),
    'one_hot_max_size': (2, 10)
}

# создадим модель
model = CatBoostClassifier()

# оптимизируем с помощью Байесовского поиска
bayes_search = BayesSearchCV(
    estimator=model,
    search_spaces=param_space_cbc,
    n_iter=20,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=42,
)

bayes_search.fit(scaled_X_train, y_train)

# выведем показатели
roc_auc = round(bayes_search.best_score_, 4)
print(f'ROC AUC = {roc_auc}\n')
print('Лучшие параметры модели:')
for k, v in bayes_search.best_params_.items():
    print(f"{k} = {v}")

# сохраним модель с наилучшими параметрами
cbc_model = bayes_search.best_estimator_
# Out:
# 0:	learn: 0.6793996	total: 7.3ms	remaining: 6.85s
# 1:	learn: 0.6646228	total: 12.1ms	remaining: 5.66s
# 2:	learn: 0.6506014	total: 26.2ms	remaining: 8.18s
# 0:	learn: 0.6793398	total: 23.9ms	remaining: 22.4s
# 3:	learn: 0.6380374	total: 46.5ms	remaining: 10.9s
# 0:	learn: 0.6797819	total: 26ms	remaining: 24.5s
# 0:	learn: 0.6802351	total: 25.7ms	remaining: 24.1s
# 1:	learn: 0.6699314	total: 38.3ms	remaining: 18s
# 1:	learn: 0.6645288	total: 44ms	remaining: 20.6s
# 0:	learn: 0.6791948	total: 24.1ms	remaining: 22.6s
# 4:	learn: 0.6241417	total: 65.7ms	remaining: 12.3s
# 1:	learn: 0.6676731	total: 43.9ms	remaining: 20.6s
# 1:	learn: 0.6681197	total: 40.2ms	remaining: 18.9s
# 2:	learn: 0.6502396	total: 62.6ms	remaining: 19.5s
# 2:	learn: 0.6581507	total: 60.9ms	remaining: 19s
# 5:	learn: 0.6116088	total: 87.3ms	remaining: 13.6s
# 2:	learn: 0.6544867	total: 65.7ms	remaining: 20.5s
# 2:	learn: 0.6560594	total: 60.6ms	remaining: 18.9s
# 3:	learn: 0.6359925	total: 83.3ms	remaining: 19.5s
# 3:	learn: 0.6445272	total: 79.9ms	remaining: 18.7s
# 6:	learn: 0.5989346	total: 106ms	remaining: 14.2s
# 3:	learn: 0.6396363	total: 88.1ms	remaining: 20.6s
# 3:	learn: 0.6449639	total: 79.5ms	remaining: 18.6s
# 4:	learn: 0.6256035	total: 100ms	remaining: 18.8s
# 4:	learn: 0.6338965	total: 97.2ms	remaining: 18.2s
# 7:	learn: 0.5885876	total: 126ms	remaining: 14.6s
# 4:	learn: 0.6282379	total: 106ms	remaining: 19.9s
# 5:	learn: 0.6139786	total: 114ms	remaining: 17.8s
# 4:	learn: 0.6306102	total: 98.6ms	remaining: 18.4s
# 8:	learn: 0.5798042	total: 141ms	remaining: 14.5s
# 5:	learn: 0.6218839	total: 118ms	remaining: 18.4s
# 5:	learn: 0.6153109	total: 125ms	remaining: 19.5s
# 6:	learn: 0.6040089	total: 133ms	remaining: 17.8s
# 5:	learn: 0.6209810	total: 120ms	remaining: 18.7s
# 6:	learn: 0.6109591	total: 137ms	remaining: 18.2s
# 9:	learn: 0.5694855	total: 163ms	remaining: 15.1s
# 6:	learn: 0.6051809	total: 139ms	remaining: 18.6s
# 7:	learn: 0.5935566	total: 152ms	remaining: 17.7s
# 7:	learn: 0.5960835	total: 154ms	remaining: 17.9s
# 6:	learn: 0.6115179	total: 138ms	remaining: 18.4s
# 10:	learn: 0.5579435	total: 179ms	remaining: 15.1s
# 7:	learn: 0.6013305	total: 154ms	remaining: 17.9s
# 8:	learn: 0.5871935	total: 168ms	remaining: 17.4s
# 8:	learn: 0.5837386	total: 172ms	remaining: 17.8s
# 8:	learn: 0.5917921	total: 169ms	remaining: 17.5s
# 11:	learn: 0.5500952	total: 196ms	remaining: 15.1s
# 7:	learn: 0.5985636	total: 157ms	remaining: 18.3s
# 9:	learn: 0.5798971	total: 182ms	remaining: 16.9s
# 12:	learn: 0.5411953	total: 208ms	remaining: 14.9s
# 9:	learn: 0.5751641	total: 188ms	remaining: 17.5s
# 9:	learn: 0.5819234	total: 188ms	remaining: 17.5s
# 8:	learn: 0.5863241	total: 174ms	remaining: 18s
# 10:	learn: 0.5710001	total: 199ms	remaining: 16.8s
# 13:	learn: 0.5343232	total: 225ms	remaining: 14.9s
# 10:	learn: 0.5670338	total: 209ms	remaining: 17.6s
# 10:	learn: 0.5740160	total: 205ms	remaining: 17.3s
# 9:	learn: 0.5789140	total: 191ms	remaining: 17.7s
# 11:	learn: 0.5632359	total: 215ms	remaining: 16.6s
# 14:	learn: 0.5270668	total: 244ms	remaining: 15s
# 11:	learn: 0.5656106	total: 223ms	remaining: 17.2s
# 11:	learn: 0.5578645	total: 232ms	remaining: 18s
# 10:	learn: 0.5679293	total: 213ms	remaining: 18s
# 12:	learn: 0.5555026	total: 233ms	remaining: 16.6s
# 12:	learn: 0.5582031	total: 240ms	remaining: 17.1s
# 15:	learn: 0.5192477	total: 268ms	remaining: 15.4s
# 11:	learn: 0.5593940	total: 228ms	remaining: 17.7s
# 12:	learn: 0.5493706	total: 248ms	remaining: 17.7s
# 13:	learn: 0.5484741	total: 247ms	remaining: 16.3s
# 13:	learn: 0.5484156	total: 255ms	remaining: 16.8s
# 12:	learn: 0.5522806	total: 240ms	remaining: 17.1s
# 13:	learn: 0.5410333	total: 263ms	remaining: 17.4s
# 16:	learn: 0.5108442	total: 287ms	remaining: 15.6s
# 14:	learn: 0.5398394	total: 264ms	remaining: 16.3s
# 14:	learn: 0.5328206	total: 279ms	remaining: 17.2s
# 14:	learn: 0.5396104	total: 276ms	remaining: 17s
# 13:	learn: 0.5440690	total: 261ms	remaining: 17.3s
# 17:	learn: 0.5036983	total: 305ms	remaining: 15.6s
# 15:	learn: 0.5330223	total: 286ms	remaining: 16.5s
# 15:	learn: 0.5260782	total: 296ms	remaining: 17.1s
# 15:	learn: 0.5337929	total: 294ms	remaining: 17s
# 14:	learn: 0.5360173	total: 280ms	remaining: 17.3s
# 18:	learn: 0.4970422	total: 322ms	remaining: 15.6s
# 16:	learn: 0.5263745	total: 306ms	remaining: 16.6s
# 16:	learn: 0.5271371	total: 309ms	remaining: 16.8s
# 16:	learn: 0.5194337	total: 314ms	remaining: 17.1s
# 15:	learn: 0.5302176	total: 294ms	remaining: 17s
# 19:	learn: 0.4898488	total: 338ms	remaining: 15.5s
# 17:	learn: 0.5203054	total: 321ms	remaining: 16.4s
# 17:	learn: 0.5194216	total: 325ms	remaining: 16.6s
# 16:	learn: 0.5218863	total: 309ms	remaining: 16.8s
# 20:	learn: 0.4822314	total: 353ms	remaining: 15.5s
# 17:	learn: 0.5119153	total: 334ms	remaining: 17.1s
# 18:	learn: 0.5128953	total: 343ms	remaining: 16.6s
# 17:	learn: 0.5133687	total: 328ms	remaining: 16.8s
# 18:	learn: 0.5116043	total: 347ms	remaining: 16.8s
# 18:	learn: 0.5047456	total: 352ms	remaining: 17.1s
# 21:	learn: 0.4748457	total: 374ms	remaining: 15.6s
# 18:	learn: 0.5079246	total: 344ms	remaining: 16.7s
# 19:	learn: 0.5067885	total: 365ms	remaining: 16.8s
# 19:	learn: 0.5053476	total: 364ms	remaining: 16.8s
# 19:	learn: 0.4994114	total: 370ms	remaining: 17s
# 22:	learn: 0.4687569	total: 392ms	remaining: 15.6s
# 19:	learn: 0.5015381	total: 357ms	remaining: 16.4s
# 20:	learn: 0.4949393	total: 384ms	remaining: 16.8s
# 20:	learn: 0.5004911	total: 384ms	remaining: 16.8s
# 20:	learn: 0.4975955	total: 383ms	remaining: 16.8s
# 23:	learn: 0.4636650	total: 412ms	remaining: 15.7s
# 20:	learn: 0.4970292	total: 378ms	remaining: 16.5s
# 21:	learn: 0.4894094	total: 405ms	remaining: 16.9s
# 21:	learn: 0.4937430	total: 403ms	remaining: 16.8s
# 21:	learn: 0.4913817	total: 405ms	remaining: 16.9s
# 24:	learn: 0.4588719	total: 433ms	remaining: 15.9s
# 21:	learn: 0.4906870	total: 394ms	remaining: 16.4s
# 22:	learn: 0.4840178	total: 424ms	remaining: 16.9s
# 22:	learn: 0.4892812	total: 424ms	remaining: 16.9s
# 25:	learn: 0.4535328	total: 450ms	remaining: 15.8s
# 22:	learn: 0.4846639	total: 409ms	remaining: 16.3s
# 22:	learn: 0.4851358	total: 427ms	remaining: 17s
# 23:	learn: 0.4778376	total: 442ms	remaining: 16.9s
# 23:	learn: 0.4844829	total: 439ms	remaining: 16.8s
# 23:	learn: 0.4794978	total: 422ms	remaining: 16.1s
# 26:	learn: 0.4479767	total: 467ms	remaining: 15.8s
# 23:	learn: 0.4797046	total: 443ms	remaining: 16.9s
# 24:	learn: 0.4742211	total: 434ms	remaining: 15.9s
# 24:	learn: 0.4802411	total: 455ms	remaining: 16.6s
# 24:	learn: 0.4707750	total: 461ms	remaining: 16.9s
# 27:	learn: 0.4415181	total: 485ms	remaining: 15.8s
# 24:	learn: 0.4746003	total: 461ms	remaining: 16.9s
# 25:	learn: 0.4692331	total: 452ms	remaining: 15.9s
# 25:	learn: 0.4743525	total: 470ms	remaining: 16.5s
# 25:	learn: 0.4652972	total: 478ms	remaining: 16.8s
# 28:	learn: 0.4369090	total: 501ms	remaining: 15.7s
# 25:	learn: 0.4676744	total: 478ms	remaining: 16.8s
# 26:	learn: 0.4648586	total: 465ms	remaining: 15.7s
# 26:	learn: 0.4702791	total: 483ms	remaining: 16.3s
# 26:	learn: 0.4590391	total: 495ms	remaining: 16.7s
# 29:	learn: 0.4330328	total: 516ms	remaining: 15.7s
# 27:	learn: 0.4612425	total: 478ms	remaining: 15.6s
# 26:	learn: 0.4613087	total: 497ms	remaining: 16.8s
# 27:	learn: 0.4654300	total: 499ms	remaining: 16.3s
# 30:	learn: 0.4292559	total: 532ms	remaining: 15.6s
# 27:	learn: 0.4549075	total: 512ms	remaining: 16.7s
# 27:	learn: 0.4582944	total: 508ms	remaining: 16.5s
# 28:	learn: 0.4606284	total: 511ms	remaining: 16.1s
# 28:	learn: 0.4570723	total: 494ms	remaining: 15.5s
# 28:	learn: 0.4504383	total: 524ms	remaining: 16.4s
# 29:	learn: 0.4538738	total: 504ms	remaining: 15.3s
# 28:	learn: 0.4536053	total: 520ms	remaining: 16.3s
# 31:	learn: 0.4256061	total: 546ms	remaining: 15.5s
# 29:	learn: 0.4564383	total: 524ms	remaining: 15.9s
# 32:	learn: 0.4219651	total: 559ms	remaining: 15.4s
# 29:	learn: 0.4456265	total: 540ms	remaining: 16.4s
# 29:	learn: 0.4494478	total: 537ms	remaining: 16.3s
# 30:	learn: 0.4485215	total: 521ms	remaining: 15.3s
# 30:	learn: 0.4515430	total: 539ms	remaining: 15.8s
# 30:	learn: 0.4421861	total: 551ms	remaining: 16.2s
# 33:	learn: 0.4183566	total: 575ms	remaining: 15.3s
# 30:	learn: 0.4450796	total: 551ms	remaining: 16.1s
# 31:	learn: 0.4472811	total: 555ms	remaining: 15.7s
# 31:	learn: 0.4439521	total: 538ms	remaining: 15.3s
# 34:	learn: 0.4145028	total: 587ms	remaining: 15.2s
# 31:	learn: 0.4415069	total: 564ms	remaining: 16s
# 32:	learn: 0.4411898	total: 549ms	remaining: 15.1s
# 31:	learn: 0.4372764	total: 570ms	remaining: 16.2s
# 32:	learn: 0.4431860	total: 569ms	remaining: 15.6s
# 35:	learn: 0.4104354	total: 602ms	remaining: 15.1s
# 32:	learn: 0.4340087	total: 583ms	remaining: 16s
# 33:	learn: 0.4409449	total: 581ms	remaining: 15.5s
# 33:	learn: 0.4363357	total: 564ms	remaining: 15s
# 32:	learn: 0.4370624	total: 582ms	remaining: 16s
# 36:	learn: 0.4075873	total: 613ms	remaining: 15s
# 34:	learn: 0.4367709	total: 597ms	remaining: 15.4s
# 33:	learn: 0.4293049	total: 601ms	remaining: 16s
# 33:	learn: 0.4331384	total: 599ms	remaining: 16s
# 37:	learn: 0.4040220	total: 626ms	remaining: 14.9s
# 34:	learn: 0.4323835	total: 586ms	remaining: 15.1s
# 34:	learn: 0.4257256	total: 613ms	remaining: 15.9s
# 38:	learn: 0.4022631	total: 638ms	remaining: 14.7s
# 35:	learn: 0.4296483	total: 597ms	remaining: 15s
# 34:	learn: 0.4267513	total: 614ms	remaining: 15.9s
# 35:	learn: 0.4339738	total: 615ms	remaining: 15.5s
# 35:	learn: 0.4218994	total: 629ms	remaining: 15.8s
# 36:	learn: 0.4310005	total: 627ms	remaining: 15.3s
# 35:	learn: 0.4246074	total: 627ms	remaining: 15.7s
# 39:	learn: 0.3991507	total: 653ms	remaining: 14.7s
# 36:	learn: 0.4255624	total: 615ms	remaining: 15s
# 37:	learn: 0.4268322	total: 640ms	remaining: 15.2s
# 36:	learn: 0.4174544	total: 644ms	remaining: 15.7s
# 37:	learn: 0.4229423	total: 627ms	remaining: 14.9s
# 40:	learn: 0.3953451	total: 669ms	remaining: 14.7s
# 36:	learn: 0.4207737	total: 645ms	remaining: 15.7s
# 37:	learn: 0.4156439	total: 653ms	remaining: 15.5s
# 38:	learn: 0.4226995	total: 653ms	remaining: 15.1s
# 37:	learn: 0.4174594	total: 656ms	remaining: 15.6s
# 41:	learn: 0.3920507	total: 683ms	remaining: 14.6s
# 38:	learn: 0.4197083	total: 642ms	remaining: 14.8s
# 39:	learn: 0.4198926	total: 666ms	remaining: 15s
# 38:	learn: 0.4117378	total: 669ms	remaining: 15.5s
# 39:	learn: 0.4179000	total: 650ms	remaining: 14.6s
# 38:	learn: 0.4149431	total: 666ms	remaining: 15.4s
# 42:	learn: 0.3891242	total: 694ms	remaining: 14.5s
# 39:	learn: 0.4093918	total: 680ms	remaining: 15.3s
# 39:	learn: 0.4114750	total: 679ms	remaining: 15.3s
# 40:	learn: 0.4158041	total: 683ms	remaining: 15s
# 40:	learn: 0.4138945	total: 666ms	remaining: 14.6s
# 43:	learn: 0.3859974	total: 707ms	remaining: 14.4s
# 40:	learn: 0.4060716	total: 695ms	remaining: 15.2s
# 41:	learn: 0.4127322	total: 694ms	remaining: 14.8s
# 40:	learn: 0.4083352	total: 694ms	remaining: 15.2s
# 41:	learn: 0.4111563	total: 681ms	remaining: 14.6s
# 44:	learn: 0.3831343	total: 724ms	remaining: 14.4s
# 41:	learn: 0.4021003	total: 712ms	remaining: 15.2s
# 42:	learn: 0.4086497	total: 696ms	remaining: 14.5s
# 45:	learn: 0.3802645	total: 738ms	remaining: 14.3s
# 42:	learn: 0.4084936	total: 715ms	remaining: 14.9s
# 41:	learn: 0.4038049	total: 714ms	remaining: 15.3s
# 42:	learn: 0.3991604	total: 730ms	remaining: 15.2s
# 43:	learn: 0.4048713	total: 731ms	remaining: 14.9s
# 42:	learn: 0.4005794	total: 730ms	remaining: 15.2s
# 43:	learn: 0.4049351	total: 714ms	remaining: 14.5s
# 46:	learn: 0.3768382	total: 756ms	remaining: 14.4s
# 44:	learn: 0.4029590	total: 726ms	remaining: 14.4s
# 47:	learn: 0.3749208	total: 767ms	remaining: 14.3s
# 43:	learn: 0.3976443	total: 743ms	remaining: 15.1s
# 43:	learn: 0.3955195	total: 748ms	remaining: 15.2s
# 44:	learn: 0.4018356	total: 747ms	remaining: 14.9s
# 44:	learn: 0.3932654	total: 757ms	remaining: 15.1s
# 48:	learn: 0.3730181	total: 780ms	remaining: 14.2s
# 45:	learn: 0.3995823	total: 760ms	remaining: 14.8s
# 45:	learn: 0.3996686	total: 744ms	remaining: 14.5s
# 44:	learn: 0.3942757	total: 763ms	remaining: 15.2s
# 45:	learn: 0.3909066	total: 769ms	remaining: 14.9s
# 46:	learn: 0.3976670	total: 771ms	remaining: 14.7s
# 49:	learn: 0.3710399	total: 795ms	remaining: 14.1s
# 45:	learn: 0.3918231	total: 775ms	remaining: 15.1s
# 46:	learn: 0.3960586	total: 761ms	remaining: 14.5s
# 46:	learn: 0.3866247	total: 786ms	remaining: 14.9s
# 50:	learn: 0.3694401	total: 809ms	remaining: 14.1s
# 47:	learn: 0.3947666	total: 790ms	remaining: 14.7s
# 46:	learn: 0.3888102	total: 792ms	remaining: 15.1s
# 47:	learn: 0.3934166	total: 776ms	remaining: 14.4s
# 51:	learn: 0.3673760	total: 822ms	remaining: 14s
# 47:	learn: 0.3834926	total: 803ms	remaining: 14.9s
# 48:	learn: 0.3923740	total: 804ms	remaining: 14.6s
# 47:	learn: 0.3859940	total: 806ms	remaining: 15s
# 48:	learn: 0.3906428	total: 793ms	remaining: 14.4s
# 52:	learn: 0.3650068	total: 835ms	remaining: 14s
# 48:	learn: 0.3812998	total: 817ms	remaining: 14.8s
# 49:	learn: 0.3905929	total: 816ms	remaining: 14.5s
# 48:	learn: 0.3840462	total: 821ms	remaining: 14.9s
# 49:	learn: 0.3883022	total: 808ms	remaining: 14.4s
# 53:	learn: 0.3623072	total: 851ms	remaining: 14s
# 49:	learn: 0.3777147	total: 832ms	remaining: 14.8s
# 50:	learn: 0.3880599	total: 831ms	remaining: 14.5s
# 49:	learn: 0.3809746	total: 837ms	remaining: 14.9s
# 50:	learn: 0.3857509	total: 823ms	remaining: 14.3s
# 54:	learn: 0.3602132	total: 865ms	remaining: 13.9s
# 50:	learn: 0.3746994	total: 848ms	remaining: 14.8s
# 50:	learn: 0.3791695	total: 846ms	remaining: 14.8s
# 51:	learn: 0.3855771	total: 850ms	remaining: 14.5s
# 51:	learn: 0.3840063	total: 834ms	remaining: 14.2s
# 55:	learn: 0.3588504	total: 879ms	remaining: 13.9s
# 51:	learn: 0.3723747	total: 862ms	remaining: 14.7s
# 51:	learn: 0.3761945	total: 862ms	remaining: 14.7s
# 52:	learn: 0.3819361	total: 847ms	remaining: 14.2s
# 52:	learn: 0.3816764	total: 866ms	remaining: 14.5s
# 56:	learn: 0.3562905	total: 890ms	remaining: 13.8s
# 52:	learn: 0.3745061	total: 873ms	remaining: 14.6s
# 52:	learn: 0.3684101	total: 879ms	remaining: 14.7s
# 53:	learn: 0.3796186	total: 861ms	remaining: 14.1s
# 57:	learn: 0.3539825	total: 902ms	remaining: 13.7s
# 53:	learn: 0.3790703	total: 881ms	remaining: 14.4s
# 53:	learn: 0.3665491	total: 890ms	remaining: 14.6s
# 58:	learn: 0.3523419	total: 912ms	remaining: 13.6s
# 53:	learn: 0.3713334	total: 889ms	remaining: 14.6s
# 54:	learn: 0.3778343	total: 875ms	remaining: 14.1s
# 54:	learn: 0.3760413	total: 898ms	remaining: 14.5s
# 54:	learn: 0.3636899	total: 903ms	remaining: 14.5s
# 59:	learn: 0.3505488	total: 924ms	remaining: 13.6s
# 54:	learn: 0.3691188	total: 902ms	remaining: 14.5s
# 55:	learn: 0.3753004	total: 892ms	remaining: 14.1s
# 55:	learn: 0.3737395	total: 913ms	remaining: 14.4s
# 55:	learn: 0.3603589	total: 916ms	remaining: 14.5s
# 60:	learn: 0.3494077	total: 936ms	remaining: 13.5s
# 55:	learn: 0.3672915	total: 915ms	remaining: 14.4s
# 56:	learn: 0.3581026	total: 925ms	remaining: 14.3s
# 56:	learn: 0.3727670	total: 906ms	remaining: 14s
# 61:	learn: 0.3470717	total: 947ms	remaining: 13.4s
# 56:	learn: 0.3708123	total: 926ms	remaining: 14.4s
# 56:	learn: 0.3652808	total: 926ms	remaining: 14.3s
# 57:	learn: 0.3712438	total: 920ms	remaining: 14s
# 62:	learn: 0.3454135	total: 959ms	remaining: 13.4s
# 57:	learn: 0.3561819	total: 942ms	remaining: 14.3s
# 57:	learn: 0.3625157	total: 939ms	remaining: 14.3s
# 57:	learn: 0.3677655	total: 942ms	remaining: 14.3s
# 58:	learn: 0.3694200	total: 928ms	remaining: 13.9s
# 58:	learn: 0.3607461	total: 948ms	remaining: 14.2s
# 63:	learn: 0.3443879	total: 973ms	remaining: 13.3s
# 58:	learn: 0.3655615	total: 955ms	remaining: 14.3s
# 59:	learn: 0.3674798	total: 939ms	remaining: 13.8s
# 58:	learn: 0.3541572	total: 959ms	remaining: 14.3s
# 59:	learn: 0.3529530	total: 966ms	remaining: 14.2s
# 59:	learn: 0.3641805	total: 964ms	remaining: 14.1s
# 59:	learn: 0.3582418	total: 964ms	remaining: 14.1s
# 64:	learn: 0.3430541	total: 986ms	remaining: 13.3s
# 60:	learn: 0.3652554	total: 954ms	remaining: 13.8s
# 60:	learn: 0.3629941	total: 975ms	remaining: 14.1s
# 65:	learn: 0.3409406	total: 1s	remaining: 13.3s
# 60:	learn: 0.3557772	total: 979ms	remaining: 14.1s
# 60:	learn: 0.3505233	total: 984ms	remaining: 14.2s
# 61:	learn: 0.3630054	total: 970ms	remaining: 13.7s
# 61:	learn: 0.3603929	total: 992ms	remaining: 14s
# 66:	learn: 0.3389942	total: 1.02s	remaining: 13.2s
# 61:	learn: 0.3539844	total: 995ms	remaining: 14.1s
# 61:	learn: 0.3477903	total: 1s	remaining: 14.2s
# 67:	learn: 0.3379665	total: 1.02s	remaining: 13.1s
# 62:	learn: 0.3593112	total: 1s	remaining: 14s
# 62:	learn: 0.3468863	total: 1.01s	remaining: 14s
# 62:	learn: 0.3612615	total: 988ms	remaining: 13.7s
# 62:	learn: 0.3525075	total: 1s	remaining: 14s
# 63:	learn: 0.3574840	total: 1.01s	remaining: 13.9s
# 63:	learn: 0.3502002	total: 1.01s	remaining: 13.9s
# 68:	learn: 0.3347716	total: 1.04s	remaining: 13.1s
# 63:	learn: 0.3451100	total: 1.02s	remaining: 14s
# 63:	learn: 0.3587163	total: 1s	remaining: 13.7s
# 64:	learn: 0.3494685	total: 1.02s	remaining: 13.8s
# 64:	learn: 0.3556703	total: 1.03s	remaining: 13.8s
# 69:	learn: 0.3332762	total: 1.05s	remaining: 13.1s
# 64:	learn: 0.3432573	total: 1.04s	remaining: 13.9s
# 70:	learn: 0.3325055	total: 1.06s	remaining: 12.9s
# 65:	learn: 0.3472673	total: 1.03s	remaining: 13.7s
# 64:	learn: 0.3564496	total: 1.02s	remaining: 13.8s
# 65:	learn: 0.3531705	total: 1.04s	remaining: 13.8s
# 65:	learn: 0.3413568	total: 1.05s	remaining: 13.9s
# 71:	learn: 0.3298583	total: 1.07s	remaining: 12.9s
# 66:	learn: 0.3445773	total: 1.05s	remaining: 13.7s
# 65:	learn: 0.3536919	total: 1.04s	remaining: 13.7s
# 66:	learn: 0.3502324	total: 1.06s	remaining: 13.8s
# 66:	learn: 0.3390969	total: 1.07s	remaining: 13.9s
# 72:	learn: 0.3278923	total: 1.08s	remaining: 12.9s
# 66:	learn: 0.3519867	total: 1.05s	remaining: 13.7s
# 67:	learn: 0.3425356	total: 1.06s	remaining: 13.7s
# 73:	learn: 0.3268451	total: 1.09s	remaining: 12.8s
# 67:	learn: 0.3384375	total: 1.08s	remaining: 13.8s
# 67:	learn: 0.3484255	total: 1.07s	remaining: 13.8s
# 67:	learn: 0.3502712	total: 1.06s	remaining: 13.6s
# 68:	learn: 0.3413158	total: 1.08s	remaining: 13.6s
# 68:	learn: 0.3469876	total: 1.08s	remaining: 13.7s
# 74:	learn: 0.3253441	total: 1.11s	remaining: 12.8s
# 68:	learn: 0.3494465	total: 1.07s	remaining: 13.5s
# 68:	learn: 0.3363314	total: 1.09s	remaining: 13.8s
# 69:	learn: 0.3396634	total: 1.09s	remaining: 13.6s
# 69:	learn: 0.3450585	total: 1.09s	remaining: 13.6s
# 75:	learn: 0.3243331	total: 1.12s	remaining: 12.7s
# 69:	learn: 0.3478795	total: 1.08s	remaining: 13.4s
# 69:	learn: 0.3350415	total: 1.1s	remaining: 13.7s
# 70:	learn: 0.3388147	total: 1.1s	remaining: 13.5s
# 70:	learn: 0.3438673	total: 1.1s	remaining: 13.5s
# 70:	learn: 0.3469728	total: 1.09s	remaining: 13.4s
# 76:	learn: 0.3222791	total: 1.13s	remaining: 12.7s
# 70:	learn: 0.3334168	total: 1.12s	remaining: 13.7s
# 71:	learn: 0.3366723	total: 1.11s	remaining: 13.4s
# 71:	learn: 0.3425928	total: 1.12s	remaining: 13.5s
# 71:	learn: 0.3455304	total: 1.1s	remaining: 13.3s
# 71:	learn: 0.3325546	total: 1.12s	remaining: 13.6s
# 72:	learn: 0.3358485	total: 1.12s	remaining: 13.3s
# 77:	learn: 0.3208855	total: 1.15s	remaining: 12.7s
# 72:	learn: 0.3405357	total: 1.13s	remaining: 13.5s
# 72:	learn: 0.3305645	total: 1.14s	remaining: 13.5s
# 73:	learn: 0.3346539	total: 1.13s	remaining: 13.3s
# 72:	learn: 0.3434016	total: 1.12s	remaining: 13.3s
# 78:	learn: 0.3196827	total: 1.16s	remaining: 12.6s
# 73:	learn: 0.3294230	total: 1.15s	remaining: 13.4s
# 73:	learn: 0.3386615	total: 1.15s	remaining: 13.4s
# 73:	learn: 0.3415554	total: 1.13s	remaining: 13.2s
# 74:	learn: 0.3323124	total: 1.15s	remaining: 13.3s
# 74:	learn: 0.3289115	total: 1.16s	remaining: 13.4s
# 79:	learn: 0.3183049	total: 1.18s	remaining: 12.7s
# 74:	learn: 0.3365848	total: 1.17s	remaining: 13.5s
# 80:	learn: 0.3174529	total: 1.2s	remaining: 12.7s
# 75:	learn: 0.3277817	total: 1.19s	remaining: 13.5s
# 74:	learn: 0.3389916	total: 1.17s	remaining: 13.5s
# 75:	learn: 0.3307469	total: 1.18s	remaining: 13.5s
# 75:	learn: 0.3354946	total: 1.19s	remaining: 13.5s
# 76:	learn: 0.3347691	total: 1.2s	remaining: 13.4s
# 76:	learn: 0.3263807	total: 1.2s	remaining: 13.5s
# 76:	learn: 0.3286528	total: 1.2s	remaining: 13.5s
# 81:	learn: 0.3154178	total: 1.22s	remaining: 12.8s
# 75:	learn: 0.3380677	total: 1.19s	remaining: 13.5s
# 77:	learn: 0.3335954	total: 1.21s	remaining: 13.4s
# 77:	learn: 0.3271142	total: 1.21s	remaining: 13.4s
# 82:	learn: 0.3139778	total: 1.24s	remaining: 12.8s
# 76:	learn: 0.3366750	total: 1.2s	remaining: 13.5s
# 77:	learn: 0.3245304	total: 1.22s	remaining: 13.5s
# 78:	learn: 0.3255832	total: 1.23s	remaining: 13.4s
# 78:	learn: 0.3314308	total: 1.25s	remaining: 13.6s
# 77:	learn: 0.3356674	total: 1.24s	remaining: 13.6s
# 78:	learn: 0.3233862	total: 1.26s	remaining: 13.7s
# 83:	learn: 0.3127173	total: 1.27s	remaining: 13s
# 79:	learn: 0.3236100	total: 1.26s	remaining: 13.5s
# 79:	learn: 0.3301841	total: 1.26s	remaining: 13.6s
# 78:	learn: 0.3335984	total: 1.25s	remaining: 13.6s
# 79:	learn: 0.3212149	total: 1.27s	remaining: 13.7s
# 84:	learn: 0.3099481	total: 1.29s	remaining: 13s
# 80:	learn: 0.3212800	total: 1.28s	remaining: 13.5s
# 79:	learn: 0.3317666	total: 1.26s	remaining: 13.6s
# 80:	learn: 0.3277685	total: 1.29s	remaining: 13.7s
# 80:	learn: 0.3187541	total: 1.29s	remaining: 13.7s
# 85:	learn: 0.3083957	total: 1.31s	remaining: 13s
# 80:	learn: 0.3304547	total: 1.28s	remaining: 13.5s
# 81:	learn: 0.3271650	total: 1.3s	remaining: 13.6s
# 81:	learn: 0.3199007	total: 1.3s	remaining: 13.6s
# 86:	learn: 0.3074653	total: 1.32s	remaining: 13s
# 81:	learn: 0.3288640	total: 1.29s	remaining: 13.5s
# 81:	learn: 0.3174579	total: 1.31s	remaining: 13.7s
# 82:	learn: 0.3258815	total: 1.31s	remaining: 13.5s
# 82:	learn: 0.3169649	total: 1.32s	remaining: 13.7s
# 87:	learn: 0.3057670	total: 1.34s	remaining: 13s
# 82:	learn: 0.3277108	total: 1.31s	remaining: 13.5s
# 82:	learn: 0.3160194	total: 1.33s	remaining: 13.7s
# 83:	learn: 0.3239830	total: 1.33s	remaining: 13.6s
# 83:	learn: 0.3155614	total: 1.34s	remaining: 13.6s
# 88:	learn: 0.3042500	total: 1.36s	remaining: 13s
# 83:	learn: 0.3264735	total: 1.32s	remaining: 13.5s
# 84:	learn: 0.3224160	total: 1.34s	remaining: 13.5s
# 83:	learn: 0.3146395	total: 1.35s	remaining: 13.7s
# 84:	learn: 0.3255439	total: 1.33s	remaining: 13.4s
# 84:	learn: 0.3139958	total: 1.35s	remaining: 13.6s
# 84:	learn: 0.3132587	total: 1.36s	remaining: 13.7s
# 89:	learn: 0.3027419	total: 1.38s	remaining: 13s
# 85:	learn: 0.3244997	total: 1.34s	remaining: 13.3s
# 85:	learn: 0.3207578	total: 1.36s	remaining: 13.6s
# 90:	learn: 0.3017732	total: 1.38s	remaining: 12.9s
# 85:	learn: 0.3123099	total: 1.36s	remaining: 13.6s
# 86:	learn: 0.3230935	total: 1.35s	remaining: 13.3s
# 85:	learn: 0.3111099	total: 1.38s	remaining: 13.7s
# 86:	learn: 0.3112863	total: 1.38s	remaining: 13.5s
# 86:	learn: 0.3188737	total: 1.38s	remaining: 13.5s
# 91:	learn: 0.3002754	total: 1.4s	remaining: 12.9s
# 87:	learn: 0.3219613	total: 1.36s	remaining: 13.2s
# 86:	learn: 0.3098587	total: 1.39s	remaining: 13.6s
# 87:	learn: 0.3100892	total: 1.39s	remaining: 13.5s
# 92:	learn: 0.2984904	total: 1.41s	remaining: 12.9s
# 87:	learn: 0.3177252	total: 1.39s	remaining: 13.5s
# 88:	learn: 0.3207051	total: 1.38s	remaining: 13.2s
# 87:	learn: 0.3083554	total: 1.4s	remaining: 13.6s
# 93:	learn: 0.2973662	total: 1.43s	remaining: 12.8s
# 88:	learn: 0.3084583	total: 1.41s	remaining: 13.4s
# 88:	learn: 0.3161179	total: 1.41s	remaining: 13.5s
# 89:	learn: 0.3189154	total: 1.4s	remaining: 13.2s
# 89:	learn: 0.3076355	total: 1.42s	remaining: 13.4s
# 88:	learn: 0.3068472	total: 1.43s	remaining: 13.6s
# 94:	learn: 0.2953174	total: 1.45s	remaining: 12.9s
# 90:	learn: 0.3063819	total: 1.43s	remaining: 13.4s
# 90:	learn: 0.3178866	total: 1.42s	remaining: 13.2s
# 89:	learn: 0.3146386	total: 1.44s	remaining: 13.6s
# 89:	learn: 0.3058408	total: 1.44s	remaining: 13.6s
# 95:	learn: 0.2943579	total: 1.46s	remaining: 12.8s
# 91:	learn: 0.3045940	total: 1.44s	remaining: 13.3s
# 90:	learn: 0.3128407	total: 1.45s	remaining: 13.5s
# 90:	learn: 0.3049596	total: 1.45s	remaining: 13.6s
# 91:	learn: 0.3166160	total: 1.43s	remaining: 13.2s
# 96:	learn: 0.2928505	total: 1.47s	remaining: 12.8s
# 92:	learn: 0.3028758	total: 1.46s	remaining: 13.3s
# 91:	learn: 0.3112969	total: 1.47s	remaining: 13.5s
# 92:	learn: 0.3154836	total: 1.45s	remaining: 13.2s
# 91:	learn: 0.3040215	total: 1.47s	remaining: 13.6s
# 97:	learn: 0.2916458	total: 1.49s	remaining: 12.8s
# 93:	learn: 0.3144295	total: 1.46s	remaining: 13.2s
# 92:	learn: 0.3032486	total: 1.48s	remaining: 13.5s
# 93:	learn: 0.3018103	total: 1.48s	remaining: 13.3s
# 92:	learn: 0.3095881	total: 1.49s	remaining: 13.5s
# 94:	learn: 0.3011437	total: 1.49s	remaining: 13.2s
# 93:	learn: 0.3022167	total: 1.49s	remaining: 13.4s
# 98:	learn: 0.2903468	total: 1.51s	remaining: 12.8s
# 94:	learn: 0.3128602	total: 1.47s	remaining: 13.1s
# 93:	learn: 0.3087754	total: 1.5s	remaining: 13.5s
# 99:	learn: 0.2892509	total: 1.52s	remaining: 12.7s
# 95:	learn: 0.3119797	total: 1.48s	remaining: 13s
# 95:	learn: 0.2996888	total: 1.5s	remaining: 13.2s
# 94:	learn: 0.3004082	total: 1.51s	remaining: 13.4s
# 96:	learn: 0.3104111	total: 1.49s	remaining: 13s
# 94:	learn: 0.3063056	total: 1.52s	remaining: 13.5s
# 95:	learn: 0.2995984	total: 1.52s	remaining: 13.4s
# 100:	learn: 0.2874661	total: 1.54s	remaining: 12.8s
# 96:	learn: 0.2981955	total: 1.52s	remaining: 13.2s
# 97:	learn: 0.3091292	total: 1.51s	remaining: 13s
# 96:	learn: 0.2983207	total: 1.54s	remaining: 13.4s
# 97:	learn: 0.2966965	total: 1.54s	remaining: 13.2s
# 101:	learn: 0.2863735	total: 1.56s	remaining: 12.8s
# 95:	learn: 0.3044309	total: 1.54s	remaining: 13.6s
# 98:	learn: 0.3072534	total: 1.52s	remaining: 13s
# 97:	learn: 0.2976076	total: 1.55s	remaining: 13.3s
# 99:	learn: 0.3059146	total: 1.53s	remaining: 12.9s
# 96:	learn: 0.3031820	total: 1.55s	remaining: 13.5s
# 98:	learn: 0.2944035	total: 1.55s	remaining: 13.2s
# 102:	learn: 0.2849037	total: 1.57s	remaining: 12.8s
# 98:	learn: 0.2966869	total: 1.56s	remaining: 13.2s
# 100:	learn: 0.3049968	total: 1.54s	remaining: 12.8s
# 97:	learn: 0.3018154	total: 1.57s	remaining: 13.5s
# 99:	learn: 0.2931667	total: 1.57s	remaining: 13.2s
# 101:	learn: 0.3040937	total: 1.56s	remaining: 12.9s
# 103:	learn: 0.2833294	total: 1.6s	remaining: 12.9s
# 98:	learn: 0.3006300	total: 1.58s	remaining: 13.5s
# 99:	learn: 0.2954456	total: 1.59s	remaining: 13.3s
# 100:	learn: 0.2913169	total: 1.58s	remaining: 13.2s
# 104:	learn: 0.2823653	total: 1.61s	remaining: 12.8s
# 99:	learn: 0.2990734	total: 1.6s	remaining: 13.4s
# 100:	learn: 0.2945236	total: 1.6s	remaining: 13.3s
# 102:	learn: 0.3031582	total: 1.58s	remaining: 12.8s
# 101:	learn: 0.2901971	total: 1.6s	remaining: 13.1s
# 105:	learn: 0.2816068	total: 1.62s	remaining: 12.7s
# 103:	learn: 0.3013941	total: 1.59s	remaining: 12.8s
# 106:	learn: 0.2803855	total: 1.63s	remaining: 12.7s
# 102:	learn: 0.2889560	total: 1.61s	remaining: 13.1s
# 100:	learn: 0.2971535	total: 1.61s	remaining: 13.4s
# 101:	learn: 0.2925037	total: 1.62s	remaining: 13.3s
# 104:	learn: 0.3002221	total: 1.61s	remaining: 12.8s
# 101:	learn: 0.2958980	total: 1.63s	remaining: 13.4s
# 103:	learn: 0.2881478	total: 1.63s	remaining: 13.1s
# 102:	learn: 0.2913341	total: 1.63s	remaining: 13.3s
# 107:	learn: 0.2786155	total: 1.65s	remaining: 12.7s
# 105:	learn: 0.2991823	total: 1.62s	remaining: 12.8s
# 104:	learn: 0.2871776	total: 1.64s	remaining: 13s
# 103:	learn: 0.2905301	total: 1.65s	remaining: 13.2s
# 102:	learn: 0.2946206	total: 1.65s	remaining: 13.4s
# 108:	learn: 0.2775016	total: 1.66s	remaining: 12.7s
# 106:	learn: 0.2977121	total: 1.63s	remaining: 12.7s
# 103:	learn: 0.2934270	total: 1.66s	remaining: 13.3s
# 105:	learn: 0.2855800	total: 1.65s	remaining: 13s
# 104:	learn: 0.2893381	total: 1.66s	remaining: 13.2s
# 109:	learn: 0.2760968	total: 1.68s	remaining: 12.6s
# 107:	learn: 0.2966108	total: 1.65s	remaining: 12.7s
# 104:	learn: 0.2921308	total: 1.67s	remaining: 13.3s
# 105:	learn: 0.2885530	total: 1.67s	remaining: 13.1s
# 106:	learn: 0.2843970	total: 1.67s	remaining: 13s
# 110:	learn: 0.2740111	total: 1.7s	remaining: 12.7s
# 108:	learn: 0.2953616	total: 1.66s	remaining: 12.6s
# 106:	learn: 0.2868924	total: 1.69s	remaining: 13.1s
# 105:	learn: 0.2910054	total: 1.68s	remaining: 13.3s
# 107:	learn: 0.2833996	total: 1.68s	remaining: 13s
# 109:	learn: 0.2945058	total: 1.67s	remaining: 12.6s
# 111:	learn: 0.2728570	total: 1.71s	remaining: 12.6s
# 106:	learn: 0.2901143	total: 1.69s	remaining: 13.2s
# 108:	learn: 0.2822493	total: 1.69s	remaining: 12.9s
# 107:	learn: 0.2853556	total: 1.7s	remaining: 13.1s
# 110:	learn: 0.2934599	total: 1.68s	remaining: 12.5s
# 112:	learn: 0.2715701	total: 1.72s	remaining: 12.6s
# 107:	learn: 0.2888331	total: 1.7s	remaining: 13.1s
# 108:	learn: 0.2846210	total: 1.71s	remaining: 13s
# 109:	learn: 0.2811133	total: 1.7s	remaining: 12.9s
# 108:	learn: 0.2881494	total: 1.71s	remaining: 13s
# 111:	learn: 0.2920546	total: 1.69s	remaining: 12.5s
# 109:	learn: 0.2836572	total: 1.72s	remaining: 13s
# 113:	learn: 0.2702824	total: 1.73s	remaining: 12.6s
# 110:	learn: 0.2797186	total: 1.72s	remaining: 12.8s
# 114:	learn: 0.2698004	total: 1.74s	remaining: 12.5s
# 109:	learn: 0.2867313	total: 1.72s	remaining: 13s
# 112:	learn: 0.2910553	total: 1.7s	remaining: 12.5s
# 111:	learn: 0.2782215	total: 1.73s	remaining: 12.8s
# 110:	learn: 0.2824171	total: 1.73s	remaining: 12.9s
# 115:	learn: 0.2688292	total: 1.75s	remaining: 12.4s
# 110:	learn: 0.2858118	total: 1.73s	remaining: 12.9s
# 113:	learn: 0.2896556	total: 1.72s	remaining: 12.5s
# 111:	learn: 0.2819334	total: 1.74s	remaining: 12.9s
# 112:	learn: 0.2767368	total: 1.74s	remaining: 12.8s
# 111:	learn: 0.2847933	total: 1.75s	remaining: 12.9s
# 116:	learn: 0.2674414	total: 1.76s	remaining: 12.4s
# 114:	learn: 0.2887348	total: 1.73s	remaining: 12.4s
# 112:	learn: 0.2810783	total: 1.75s	remaining: 12.8s
# 117:	learn: 0.2667029	total: 1.77s	remaining: 12.3s
# 113:	learn: 0.2752452	total: 1.75s	remaining: 12.7s
# 112:	learn: 0.2830831	total: 1.76s	remaining: 12.9s
# 113:	learn: 0.2803258	total: 1.76s	remaining: 12.8s
# 115:	learn: 0.2872729	total: 1.74s	remaining: 12.4s
# 114:	learn: 0.2742144	total: 1.76s	remaining: 12.7s
# 118:	learn: 0.2651095	total: 1.79s	remaining: 12.3s
# 114:	learn: 0.2791499	total: 1.77s	remaining: 12.7s
# 116:	learn: 0.2855995	total: 1.76s	remaining: 12.4s
# 113:	learn: 0.2813066	total: 1.78s	remaining: 12.9s
# 119:	learn: 0.2643631	total: 1.8s	remaining: 12.3s
# 115:	learn: 0.2731314	total: 1.78s	remaining: 12.6s
# 114:	learn: 0.2806732	total: 1.78s	remaining: 12.8s
# 117:	learn: 0.2847662	total: 1.76s	remaining: 12.3s
# 115:	learn: 0.2777816	total: 1.79s	remaining: 12.7s
# 116:	learn: 0.2716511	total: 1.79s	remaining: 12.6s
# 120:	learn: 0.2629732	total: 1.81s	remaining: 12.3s
# 115:	learn: 0.2798578	total: 1.8s	remaining: 12.8s
# 116:	learn: 0.2769763	total: 1.8s	remaining: 12.7s
# 118:	learn: 0.2837837	total: 1.78s	remaining: 12.3s
# 121:	learn: 0.2625902	total: 1.82s	remaining: 12.2s
# 117:	learn: 0.2763364	total: 1.81s	remaining: 12.6s
# 119:	learn: 0.2833463	total: 1.79s	remaining: 12.2s
# 117:	learn: 0.2704186	total: 1.8s	remaining: 12.6s
# 116:	learn: 0.2786964	total: 1.81s	remaining: 12.7s
# 122:	learn: 0.2618387	total: 1.83s	remaining: 12.1s
# 118:	learn: 0.2696900	total: 1.81s	remaining: 12.5s
# 120:	learn: 0.2818279	total: 1.8s	remaining: 12.2s
# 117:	learn: 0.2774808	total: 1.82s	remaining: 12.7s
# 118:	learn: 0.2749513	total: 1.82s	remaining: 12.6s
# 123:	learn: 0.2610678	total: 1.84s	remaining: 12.1s
# 119:	learn: 0.2742455	total: 1.83s	remaining: 12.5s
# 121:	learn: 0.2810611	total: 1.81s	remaining: 12.1s
# 118:	learn: 0.2766250	total: 1.83s	remaining: 12.6s
# 119:	learn: 0.2684442	total: 1.83s	remaining: 12.5s
# 124:	learn: 0.2599164	total: 1.85s	remaining: 12.1s
# 120:	learn: 0.2733559	total: 1.84s	remaining: 12.4s
# 119:	learn: 0.2753986	total: 1.84s	remaining: 12.6s
# 122:	learn: 0.2798210	total: 1.82s	remaining: 12.1s
# 120:	learn: 0.2669780	total: 1.84s	remaining: 12.5s
# 125:	learn: 0.2593329	total: 1.86s	remaining: 12s
# 121:	learn: 0.2720872	total: 1.85s	remaining: 12.4s
# 121:	learn: 0.2665037	total: 1.85s	remaining: 12.4s
# 126:	learn: 0.2585719	total: 1.87s	remaining: 12s
# 120:	learn: 0.2741133	total: 1.85s	remaining: 12.6s
# 123:	learn: 0.2780204	total: 1.84s	remaining: 12.1s
# 122:	learn: 0.2707982	total: 1.87s	remaining: 12.4s
# 122:	learn: 0.2650767	total: 1.86s	remaining: 12.4s
# 127:	learn: 0.2577169	total: 1.89s	remaining: 12s
# 121:	learn: 0.2725613	total: 1.87s	remaining: 12.5s
# 124:	learn: 0.2766422	total: 1.85s	remaining: 12.1s
# 123:	learn: 0.2640824	total: 1.88s	remaining: 12.3s
# 123:	learn: 0.2693243	total: 1.88s	remaining: 12.4s
# 122:	learn: 0.2707482	total: 1.89s	remaining: 12.5s
# 128:	learn: 0.2565524	total: 1.9s	remaining: 12s
# 125:	learn: 0.2759829	total: 1.87s	remaining: 12.1s
# 124:	learn: 0.2636091	total: 1.89s	remaining: 12.3s
# 124:	learn: 0.2683939	total: 1.89s	remaining: 12.3s
# 123:	learn: 0.2697651	total: 1.9s	remaining: 12.5s
# 129:	learn: 0.2557845	total: 1.92s	remaining: 11.9s
# 126:	learn: 0.2750223	total: 1.88s	remaining: 12s
# 125:	learn: 0.2615238	total: 1.9s	remaining: 12.3s
# 125:	learn: 0.2672440	total: 1.91s	remaining: 12.3s
# 124:	learn: 0.2690898	total: 1.91s	remaining: 12.4s
# 127:	learn: 0.2746320	total: 1.89s	remaining: 12s
# 126:	learn: 0.2667371	total: 1.92s	remaining: 12.3s
# 125:	learn: 0.2679925	total: 1.92s	remaining: 12.4s
# 130:	learn: 0.2545762	total: 1.93s	remaining: 11.9s
# 126:	learn: 0.2606796	total: 1.91s	remaining: 12.3s
# 128:	learn: 0.2739362	total: 1.9s	remaining: 11.9s
# 131:	learn: 0.2539057	total: 1.94s	remaining: 11.9s
# 127:	learn: 0.2656490	total: 1.93s	remaining: 12.2s
# 126:	learn: 0.2669479	total: 1.93s	remaining: 12.3s
# 127:	learn: 0.2595257	total: 1.93s	remaining: 12.2s
# 129:	learn: 0.2728109	total: 1.91s	remaining: 11.9s
# 128:	learn: 0.2648935	total: 1.94s	remaining: 12.2s
# 132:	learn: 0.2529732	total: 1.95s	remaining: 11.9s
# 127:	learn: 0.2663064	total: 1.94s	remaining: 12.3s
# 128:	learn: 0.2587585	total: 1.94s	remaining: 12.2s
# 129:	learn: 0.2638260	total: 1.95s	remaining: 12.1s
# 130:	learn: 0.2718887	total: 1.93s	remaining: 11.9s
# 128:	learn: 0.2655036	total: 1.95s	remaining: 12.2s
# 133:	learn: 0.2519578	total: 1.97s	remaining: 11.8s
# 129:	learn: 0.2575846	total: 1.95s	remaining: 12.1s
# 130:	learn: 0.2632791	total: 1.95s	remaining: 12.1s
# 134:	learn: 0.2513595	total: 1.97s	remaining: 11.8s
# 129:	learn: 0.2648363	total: 1.96s	remaining: 12.2s
# 131:	learn: 0.2707975	total: 1.94s	remaining: 11.9s
# 130:	learn: 0.2566397	total: 1.96s	remaining: 12.1s
# 135:	learn: 0.2505985	total: 1.98s	remaining: 11.7s
# 132:	learn: 0.2700259	total: 1.95s	remaining: 11.8s
# 131:	learn: 0.2619374	total: 1.97s	remaining: 12.1s
# 130:	learn: 0.2636119	total: 1.97s	remaining: 12.2s
# 136:	learn: 0.2499444	total: 1.99s	remaining: 11.7s
# 131:	learn: 0.2552661	total: 1.97s	remaining: 12.1s
# 132:	learn: 0.2607435	total: 1.98s	remaining: 12s
# 137:	learn: 0.2495846	total: 2s	remaining: 11.6s
# 133:	learn: 0.2687898	total: 1.96s	remaining: 11.8s
# 131:	learn: 0.2624980	total: 1.99s	remaining: 12.2s
# 138:	learn: 0.2486835	total: 2s	remaining: 11.6s
# 132:	learn: 0.2542401	total: 1.99s	remaining: 12s
# 133:	learn: 0.2600952	total: 1.99s	remaining: 12s
# 132:	learn: 0.2613758	total: 2s	remaining: 12.1s
# 134:	learn: 0.2675250	total: 1.98s	remaining: 11.8s
# 134:	learn: 0.2588457	total: 2s	remaining: 11.9s
# 133:	learn: 0.2532578	total: 2s	remaining: 12s
# 139:	learn: 0.2472663	total: 2.02s	remaining: 11.6s
# 133:	learn: 0.2607644	total: 2.01s	remaining: 12.1s
# 135:	learn: 0.2663538	total: 1.99s	remaining: 11.8s
# 135:	learn: 0.2581366	total: 2.01s	remaining: 11.9s
# 140:	learn: 0.2464888	total: 2.03s	remaining: 11.5s
# 134:	learn: 0.2523804	total: 2.01s	remaining: 12s
# 134:	learn: 0.2602361	total: 2.02s	remaining: 12s
# 136:	learn: 0.2574817	total: 2.02s	remaining: 11.9s
# 136:	learn: 0.2654735	total: 2s	remaining: 11.7s
# 135:	learn: 0.2594215	total: 2.02s	remaining: 12s
# 141:	learn: 0.2453815	total: 2.04s	remaining: 11.5s
# 135:	learn: 0.2513468	total: 2.02s	remaining: 12s
# 137:	learn: 0.2567398	total: 2.03s	remaining: 11.8s
# 136:	learn: 0.2581822	total: 2.03s	remaining: 11.9s
# 137:	learn: 0.2640093	total: 2.02s	remaining: 11.7s
# 142:	learn: 0.2444466	total: 2.05s	remaining: 11.4s
# 136:	learn: 0.2505000	total: 2.04s	remaining: 11.9s
# 137:	learn: 0.2577626	total: 2.04s	remaining: 11.9s
# 138:	learn: 0.2562797	total: 2.04s	remaining: 11.8s
# 138:	learn: 0.2634112	total: 2.02s	remaining: 11.7s
# 137:	learn: 0.2495062	total: 2.04s	remaining: 11.9s
# 138:	learn: 0.2568626	total: 2.05s	remaining: 11.8s
# 143:	learn: 0.2431124	total: 2.06s	remaining: 11.4s
# 139:	learn: 0.2551955	total: 2.05s	remaining: 11.7s
# 139:	learn: 0.2559384	total: 2.06s	remaining: 11.8s
# 139:	learn: 0.2624102	total: 2.04s	remaining: 11.6s
# 138:	learn: 0.2485838	total: 2.06s	remaining: 11.9s
# 144:	learn: 0.2418095	total: 2.08s	remaining: 11.4s
# 140:	learn: 0.2534534	total: 2.07s	remaining: 11.7s
# 140:	learn: 0.2551045	total: 2.07s	remaining: 11.7s
# 139:	learn: 0.2479757	total: 2.07s	remaining: 11.8s
# 140:	learn: 0.2608252	total: 2.06s	remaining: 11.6s
# 145:	learn: 0.2407366	total: 2.09s	remaining: 11.4s
# 141:	learn: 0.2541584	total: 2.08s	remaining: 11.7s
# 141:	learn: 0.2527091	total: 2.08s	remaining: 11.7s
# 140:	learn: 0.2472297	total: 2.08s	remaining: 11.8s
# 146:	learn: 0.2400102	total: 2.1s	remaining: 11.3s
# 142:	learn: 0.2519144	total: 2.09s	remaining: 11.6s
# 142:	learn: 0.2536563	total: 2.09s	remaining: 11.6s
# 141:	learn: 0.2598128	total: 2.07s	remaining: 11.6s
# 141:	learn: 0.2464814	total: 2.09s	remaining: 11.7s
# 143:	learn: 0.2531715	total: 2.1s	remaining: 11.6s
# 147:	learn: 0.2390474	total: 2.11s	remaining: 11.3s
# 143:	learn: 0.2510910	total: 2.1s	remaining: 11.6s
# 142:	learn: 0.2590327	total: 2.08s	remaining: 11.6s
# 142:	learn: 0.2456824	total: 2.1s	remaining: 11.7s
# 144:	learn: 0.2502781	total: 2.11s	remaining: 11.6s
# 148:	learn: 0.2382698	total: 2.13s	remaining: 11.3s
# 144:	learn: 0.2525059	total: 2.11s	remaining: 11.6s
# 143:	learn: 0.2581840	total: 2.09s	remaining: 11.6s
# 143:	learn: 0.2447441	total: 2.11s	remaining: 11.7s
# 149:	learn: 0.2373132	total: 2.14s	remaining: 11.3s
# 145:	learn: 0.2491605	total: 2.13s	remaining: 11.6s
# 144:	learn: 0.2569561	total: 2.1s	remaining: 11.5s
# 144:	learn: 0.2435200	total: 2.13s	remaining: 11.7s
# 145:	learn: 0.2514179	total: 2.13s	remaining: 11.6s
# 150:	learn: 0.2362768	total: 2.15s	remaining: 11.2s
# 145:	learn: 0.2562870	total: 2.12s	remaining: 11.5s
# 146:	learn: 0.2484956	total: 2.14s	remaining: 11.5s
# 146:	learn: 0.2504061	total: 2.14s	remaining: 11.6s
# 145:	learn: 0.2426655	total: 2.14s	remaining: 11.7s
# 151:	learn: 0.2356652	total: 2.16s	remaining: 11.2s
# 147:	learn: 0.2472917	total: 2.16s	remaining: 11.5s
# 146:	learn: 0.2418018	total: 2.16s	remaining: 11.6s
# 146:	learn: 0.2548018	total: 2.14s	remaining: 11.5s
# 152:	learn: 0.2351195	total: 2.18s	remaining: 11.2s
# 147:	learn: 0.2497513	total: 2.16s	remaining: 11.6s
# 148:	learn: 0.2464860	total: 2.17s	remaining: 11.5s
# 147:	learn: 0.2540641	total: 2.15s	remaining: 11.5s
# 153:	learn: 0.2342355	total: 2.19s	remaining: 11.2s
# 147:	learn: 0.2405029	total: 2.17s	remaining: 11.6s
# 148:	learn: 0.2484128	total: 2.17s	remaining: 11.5s
# 149:	learn: 0.2450504	total: 2.18s	remaining: 11.5s
# 148:	learn: 0.2533219	total: 2.16s	remaining: 11.5s
# 149:	learn: 0.2478939	total: 2.18s	remaining: 11.5s
# 154:	learn: 0.2336475	total: 2.2s	remaining: 11.1s
# 148:	learn: 0.2395797	total: 2.19s	remaining: 11.6s
# 150:	learn: 0.2438763	total: 2.19s	remaining: 11.5s
# 150:	learn: 0.2470308	total: 2.19s	remaining: 11.5s
# 149:	learn: 0.2523020	total: 2.18s	remaining: 11.5s
# 155:	learn: 0.2325075	total: 2.22s	remaining: 11.1s
# 149:	learn: 0.2387586	total: 2.2s	remaining: 11.6s
# 151:	learn: 0.2428744	total: 2.21s	remaining: 11.5s
# 151:	learn: 0.2460970	total: 2.21s	remaining: 11.5s
# 150:	learn: 0.2512329	total: 2.19s	remaining: 11.5s
# 156:	learn: 0.2311077	total: 2.23s	remaining: 11.1s
# 150:	learn: 0.2381448	total: 2.21s	remaining: 11.6s
# 152:	learn: 0.2423471	total: 2.22s	remaining: 11.4s
# 152:	learn: 0.2451444	total: 2.23s	remaining: 11.4s
# 157:	learn: 0.2305701	total: 2.24s	remaining: 11.1s
# 151:	learn: 0.2506404	total: 2.21s	remaining: 11.4s
# 151:	learn: 0.2369528	total: 2.23s	remaining: 11.6s
# 152:	learn: 0.2504034	total: 2.21s	remaining: 11.4s
# 153:	learn: 0.2411587	total: 2.24s	remaining: 11.4s
# 153:	learn: 0.2499595	total: 2.22s	remaining: 11.3s
# 153:	learn: 0.2439796	total: 2.24s	remaining: 11.5s
# 158:	learn: 0.2296575	total: 2.26s	remaining: 11.1s
# 152:	learn: 0.2362047	total: 2.25s	remaining: 11.6s
# 154:	learn: 0.2402122	total: 2.26s	remaining: 11.4s
# 154:	learn: 0.2487186	total: 2.24s	remaining: 11.3s
# 159:	learn: 0.2288539	total: 2.27s	remaining: 11.1s
# 154:	learn: 0.2429667	total: 2.26s	remaining: 11.5s
# 153:	learn: 0.2353551	total: 2.26s	remaining: 11.5s
# 155:	learn: 0.2476754	total: 2.25s	remaining: 11.3s
# 155:	learn: 0.2393200	total: 2.27s	remaining: 11.4s
# 160:	learn: 0.2280054	total: 2.29s	remaining: 11.1s
# 154:	learn: 0.2344773	total: 2.27s	remaining: 11.5s
# 155:	learn: 0.2421133	total: 2.27s	remaining: 11.4s
# 156:	learn: 0.2386145	total: 2.29s	remaining: 11.4s
# 156:	learn: 0.2464485	total: 2.27s	remaining: 11.3s
# 155:	learn: 0.2334520	total: 2.29s	remaining: 11.5s
# 161:	learn: 0.2273516	total: 2.31s	remaining: 11.1s
# 156:	learn: 0.2408297	total: 2.29s	remaining: 11.4s
# 157:	learn: 0.2379377	total: 2.3s	remaining: 11.4s
# 162:	learn: 0.2267288	total: 2.31s	remaining: 11s
# 157:	learn: 0.2455738	total: 2.28s	remaining: 11.3s
# 156:	learn: 0.2326815	total: 2.3s	remaining: 11.5s
# 157:	learn: 0.2400325	total: 2.31s	remaining: 11.4s
# 158:	learn: 0.2371013	total: 2.31s	remaining: 11.3s
# 163:	learn: 0.2260861	total: 2.33s	remaining: 11s
# 158:	learn: 0.2447563	total: 2.29s	remaining: 11.3s
# 157:	learn: 0.2322584	total: 2.31s	remaining: 11.5s
# 158:	learn: 0.2393771	total: 2.32s	remaining: 11.4s
# 164:	learn: 0.2254525	total: 2.34s	remaining: 11s
# 159:	learn: 0.2439980	total: 2.31s	remaining: 11.2s
# 159:	learn: 0.2358162	total: 2.33s	remaining: 11.4s
# 158:	learn: 0.2311436	total: 2.33s	remaining: 11.5s
# 159:	learn: 0.2377264	total: 2.34s	remaining: 11.4s
# 160:	learn: 0.2433225	total: 2.32s	remaining: 11.2s
# 165:	learn: 0.2241644	total: 2.36s	remaining: 11s
# 160:	learn: 0.2347897	total: 2.34s	remaining: 11.3s
# 166:	learn: 0.2238729	total: 2.36s	remaining: 10.9s
# 159:	learn: 0.2301874	total: 2.35s	remaining: 11.4s
# 161:	learn: 0.2428576	total: 2.33s	remaining: 11.2s
# 160:	learn: 0.2367496	total: 2.35s	remaining: 11.4s
# 160:	learn: 0.2299327	total: 2.35s	remaining: 11.4s
# 161:	learn: 0.2338551	total: 2.36s	remaining: 11.3s
# 162:	learn: 0.2422192	total: 2.34s	remaining: 11.2s
# 167:	learn: 0.2228499	total: 2.38s	remaining: 10.9s
# 161:	learn: 0.2358119	total: 2.37s	remaining: 11.4s
# 161:	learn: 0.2291304	total: 2.37s	remaining: 11.4s
# 162:	learn: 0.2331220	total: 2.37s	remaining: 11.3s
# 162:	learn: 0.2351382	total: 2.37s	remaining: 11.3s
# 168:	learn: 0.2218641	total: 2.39s	remaining: 10.9s
# 163:	learn: 0.2414315	total: 2.36s	remaining: 11.2s
# 162:	learn: 0.2284188	total: 2.38s	remaining: 11.3s
# 163:	learn: 0.2343037	total: 2.38s	remaining: 11.3s
# 163:	learn: 0.2321762	total: 2.38s	remaining: 11.3s
# 164:	learn: 0.2334782	total: 2.39s	remaining: 11.2s
# 164:	learn: 0.2404256	total: 2.37s	remaining: 11.1s
# 169:	learn: 0.2209786	total: 2.41s	remaining: 10.9s
# 163:	learn: 0.2274542	total: 2.39s	remaining: 11.3s
# 164:	learn: 0.2313128	total: 2.4s	remaining: 11.3s
# 165:	learn: 0.2399845	total: 2.38s	remaining: 11.1s
# 165:	learn: 0.2305775	total: 2.41s	remaining: 11.2s
# 165:	learn: 0.2324181	total: 2.41s	remaining: 11.2s
# 164:	learn: 0.2267555	total: 2.41s	remaining: 11.3s
# 170:	learn: 0.2199913	total: 2.43s	remaining: 10.9s
# 166:	learn: 0.2393561	total: 2.39s	remaining: 11.1s
# 166:	learn: 0.2319410	total: 2.42s	remaining: 11.2s
# 166:	learn: 0.2294827	total: 2.42s	remaining: 11.2s
# 165:	learn: 0.2256960	total: 2.42s	remaining: 11.3s
# 167:	learn: 0.2386240	total: 2.4s	remaining: 11.1s
# 171:	learn: 0.2187374	total: 2.44s	remaining: 10.9s
# 167:	learn: 0.2309121	total: 2.43s	remaining: 11.2s
# 167:	learn: 0.2282038	total: 2.43s	remaining: 11.2s
# 172:	learn: 0.2183533	total: 2.45s	remaining: 10.9s
# 168:	learn: 0.2379127	total: 2.42s	remaining: 11s
# 166:	learn: 0.2246949	total: 2.43s	remaining: 11.3s
# 168:	learn: 0.2303151	total: 2.44s	remaining: 11.1s
# 168:	learn: 0.2278091	total: 2.44s	remaining: 11.2s
# 173:	learn: 0.2176563	total: 2.46s	remaining: 10.8s
# 169:	learn: 0.2371545	total: 2.42s	remaining: 11s
# 169:	learn: 0.2296158	total: 2.44s	remaining: 11.1s
# 167:	learn: 0.2237498	total: 2.45s	remaining: 11.2s
# 170:	learn: 0.2365065	total: 2.43s	remaining: 10.9s
# 174:	learn: 0.2166902	total: 2.47s	remaining: 10.8s
# 170:	learn: 0.2289211	total: 2.46s	remaining: 11s
# 169:	learn: 0.2269099	total: 2.46s	remaining: 11.1s
# 175:	learn: 0.2163846	total: 2.48s	remaining: 10.7s
# 171:	learn: 0.2355923	total: 2.44s	remaining: 10.9s
# 168:	learn: 0.2224160	total: 2.46s	remaining: 11.2s
# 171:	learn: 0.2278572	total: 2.47s	remaining: 11s
# 170:	learn: 0.2259266	total: 2.47s	remaining: 11.1s
# 176:	learn: 0.2157123	total: 2.48s	remaining: 10.7s
# 177:	learn: 0.2153983	total: 2.49s	remaining: 10.7s
# 169:	learn: 0.2217193	total: 2.47s	remaining: 11.2s
# 172:	learn: 0.2270958	total: 2.48s	remaining: 11s
# 172:	learn: 0.2344640	total: 2.46s	remaining: 10.9s
# 178:	learn: 0.2150405	total: 2.5s	remaining: 10.6s
# 173:	learn: 0.2262459	total: 2.48s	remaining: 10.9s
# 171:	learn: 0.2250083	total: 2.49s	remaining: 11.1s
# 173:	learn: 0.2342514	total: 2.47s	remaining: 10.9s
# 170:	learn: 0.2209963	total: 2.49s	remaining: 11.2s
# 174:	learn: 0.2257414	total: 2.49s	remaining: 10.9s
# 179:	learn: 0.2145339	total: 2.51s	remaining: 10.6s
# 172:	learn: 0.2240036	total: 2.5s	remaining: 11.1s
# 174:	learn: 0.2333705	total: 2.48s	remaining: 10.8s
# 180:	learn: 0.2136366	total: 2.52s	remaining: 10.6s
# 171:	learn: 0.2195864	total: 2.5s	remaining: 11.2s
# 175:	learn: 0.2326494	total: 2.48s	remaining: 10.8s
# 175:	learn: 0.2250780	total: 2.51s	remaining: 10.9s
# 173:	learn: 0.2229838	total: 2.51s	remaining: 11.1s
# 172:	learn: 0.2187330	total: 2.52s	remaining: 11.2s
# 181:	learn: 0.2129564	total: 2.53s	remaining: 10.5s
# 176:	learn: 0.2246165	total: 2.52s	remaining: 10.9s
# 174:	learn: 0.2221352	total: 2.52s	remaining: 11s
# 176:	learn: 0.2314582	total: 2.5s	remaining: 10.8s
# 173:	learn: 0.2183100	total: 2.52s	remaining: 11.1s
# 182:	learn: 0.2125329	total: 2.54s	remaining: 10.5s
# 177:	learn: 0.2238119	total: 2.53s	remaining: 10.8s
# 177:	learn: 0.2309257	total: 2.52s	remaining: 10.8s
# 175:	learn: 0.2212848	total: 2.54s	remaining: 11s
# 174:	learn: 0.2170422	total: 2.54s	remaining: 11.1s
# 176:	learn: 0.2205330	total: 2.55s	remaining: 11s
# 183:	learn: 0.2112654	total: 2.56s	remaining: 10.5s
# 178:	learn: 0.2228704	total: 2.55s	remaining: 10.8s
# 178:	learn: 0.2298104	total: 2.53s	remaining: 10.8s
# 179:	learn: 0.2221757	total: 2.56s	remaining: 10.8s
# 177:	learn: 0.2196680	total: 2.56s	remaining: 11s
# 184:	learn: 0.2105220	total: 2.58s	remaining: 10.5s
# 175:	learn: 0.2157472	total: 2.56s	remaining: 11.1s
# 185:	learn: 0.2098403	total: 2.58s	remaining: 10.5s
# 179:	learn: 0.2284911	total: 2.55s	remaining: 10.8s
# 180:	learn: 0.2214640	total: 2.57s	remaining: 10.8s
# 176:	learn: 0.2150145	total: 2.57s	remaining: 11.1s
# 178:	learn: 0.2188630	total: 2.58s	remaining: 11s
# 180:	learn: 0.2280878	total: 2.56s	remaining: 10.8s
# 181:	learn: 0.2206772	total: 2.58s	remaining: 10.8s
# 186:	learn: 0.2091137	total: 2.6s	remaining: 10.5s
# 177:	learn: 0.2141736	total: 2.59s	remaining: 11.1s
# 179:	learn: 0.2179664	total: 2.6s	remaining: 11s
# 187:	learn: 0.2088675	total: 2.61s	remaining: 10.4s
# 182:	learn: 0.2199767	total: 2.59s	remaining: 10.7s
# 181:	learn: 0.2271358	total: 2.58s	remaining: 10.7s
# 180:	learn: 0.2174813	total: 2.6s	remaining: 10.9s
# 188:	learn: 0.2083425	total: 2.62s	remaining: 10.4s
# 178:	learn: 0.2132568	total: 2.6s	remaining: 11.1s
# 182:	learn: 0.2260530	total: 2.59s	remaining: 10.7s
# 183:	learn: 0.2189047	total: 2.61s	remaining: 10.7s
# 189:	learn: 0.2074573	total: 2.63s	remaining: 10.4s
# 179:	learn: 0.2126251	total: 2.61s	remaining: 11s
# 181:	learn: 0.2162458	total: 2.62s	remaining: 10.9s
# 184:	learn: 0.2181508	total: 2.62s	remaining: 10.7s
# 183:	learn: 0.2251649	total: 2.6s	remaining: 10.7s
# 190:	learn: 0.2071314	total: 2.64s	remaining: 10.3s
# 185:	learn: 0.2175706	total: 2.63s	remaining: 10.6s
# 182:	learn: 0.2153916	total: 2.63s	remaining: 10.9s
# 180:	learn: 0.2115760	total: 2.63s	remaining: 11s
# 184:	learn: 0.2246162	total: 2.61s	remaining: 10.7s
# 186:	learn: 0.2170105	total: 2.63s	remaining: 10.6s
# 181:	learn: 0.2111084	total: 2.63s	remaining: 11s
# 191:	learn: 0.2060012	total: 2.65s	remaining: 10.3s
# 187:	learn: 0.2167228	total: 2.64s	remaining: 10.6s
# 185:	learn: 0.2235934	total: 2.62s	remaining: 10.6s
# 192:	learn: 0.2056223	total: 2.66s	remaining: 10.3s
# 183:	learn: 0.2142478	total: 2.65s	remaining: 10.9s
# 182:	learn: 0.2102508	total: 2.65s	remaining: 11s
# 188:	learn: 0.2156037	total: 2.65s	remaining: 10.6s
# 193:	learn: 0.2051021	total: 2.67s	remaining: 10.3s
# 186:	learn: 0.2225726	total: 2.64s	remaining: 10.6s
# 184:	learn: 0.2136645	total: 2.66s	remaining: 10.9s
# ...
# 885:	learn: 0.1102264	total: 3.77s	remaining: 153ms
# 873:	learn: 0.1145039	total: 3.74s	remaining: 205ms
# 886:	learn: 0.0977651	total: 3.76s	remaining: 148ms
# 877:	learn: 0.1054299	total: 3.71s	remaining: 186ms
# 889:	learn: 0.1097472	total: 3.77s	remaining: 136ms
# 886:	learn: 0.1101340	total: 3.77s	remaining: 149ms
# 874:	learn: 0.1142945	total: 3.74s	remaining: 201ms
# 878:	learn: 0.1053250	total: 3.72s	remaining: 182ms
# 887:	learn: 0.0977460	total: 3.77s	remaining: 144ms
# 890:	learn: 0.1097010	total: 3.78s	remaining: 131ms
# 887:	learn: 0.1101138	total: 3.78s	remaining: 145ms
# 875:	learn: 0.1141205	total: 3.75s	remaining: 197ms
# 888:	learn: 0.0976238	total: 3.77s	remaining: 140ms
# 879:	learn: 0.1051465	total: 3.72s	remaining: 178ms
# 891:	learn: 0.1095711	total: 3.78s	remaining: 127ms
# 889:	learn: 0.0974903	total: 3.77s	remaining: 136ms
# 876:	learn: 0.1140021	total: 3.75s	remaining: 192ms
# 888:	learn: 0.1099300	total: 3.78s	remaining: 140ms
# 880:	learn: 0.1050718	total: 3.73s	remaining: 174ms
# 892:	learn: 0.1093812	total: 3.79s	remaining: 123ms
# 889:	learn: 0.1098061	total: 3.79s	remaining: 136ms
# 877:	learn: 0.1139041	total: 3.75s	remaining: 188ms
# 890:	learn: 0.0972610	total: 3.78s	remaining: 131ms
# 881:	learn: 0.1049825	total: 3.73s	remaining: 169ms
# 893:	learn: 0.1092474	total: 3.79s	remaining: 119ms
# 890:	learn: 0.1095950	total: 3.79s	remaining: 132ms
# 878:	learn: 0.1138270	total: 3.76s	remaining: 184ms
# 882:	learn: 0.1048491	total: 3.73s	remaining: 165ms
# 891:	learn: 0.0971090	total: 3.78s	remaining: 127ms
# 894:	learn: 0.1091070	total: 3.79s	remaining: 114ms
# 891:	learn: 0.1095245	total: 3.79s	remaining: 128ms
# 879:	learn: 0.1137173	total: 3.76s	remaining: 180ms
# 883:	learn: 0.1047378	total: 3.74s	remaining: 161ms
# 895:	learn: 0.1089806	total: 3.8s	remaining: 110ms
# 892:	learn: 0.0969990	total: 3.79s	remaining: 123ms
# 892:	learn: 0.1093596	total: 3.8s	remaining: 123ms
# 880:	learn: 0.1135709	total: 3.77s	remaining: 175ms
# 884:	learn: 0.1046290	total: 3.74s	remaining: 157ms
# 896:	learn: 0.1088286	total: 3.8s	remaining: 106ms
# 893:	learn: 0.0969580	total: 3.79s	remaining: 119ms
# 881:	learn: 0.1133873	total: 3.77s	remaining: 171ms
# 893:	learn: 0.1092070	total: 3.8s	remaining: 119ms
# 885:	learn: 0.1044242	total: 3.75s	remaining: 152ms
# 897:	learn: 0.1086628	total: 3.81s	remaining: 102ms
# 894:	learn: 0.0967701	total: 3.79s	remaining: 114ms
# 882:	learn: 0.1132128	total: 3.77s	remaining: 167ms
# 886:	learn: 0.1043385	total: 3.75s	remaining: 148ms
# 894:	learn: 0.1090604	total: 3.81s	remaining: 115ms
# 898:	learn: 0.1085765	total: 3.81s	remaining: 97.5ms
# 895:	learn: 0.0966229	total: 3.8s	remaining: 110ms
# 895:	learn: 0.1089759	total: 3.81s	remaining: 111ms
# 887:	learn: 0.1041926	total: 3.76s	remaining: 144ms
# 883:	learn: 0.1131052	total: 3.78s	remaining: 162ms
# 899:	learn: 0.1084147	total: 3.81s	remaining: 93.2ms
# 896:	learn: 0.0965173	total: 3.8s	remaining: 106ms
# 884:	learn: 0.1129767	total: 3.78s	remaining: 158ms
# 896:	learn: 0.1089098	total: 3.82s	remaining: 106ms
# 888:	learn: 0.1040128	total: 3.76s	remaining: 140ms
# 900:	learn: 0.1082730	total: 3.82s	remaining: 89ms
# 897:	learn: 0.0963880	total: 3.81s	remaining: 102ms
# 897:	learn: 0.1086993	total: 3.82s	remaining: 102ms
# 889:	learn: 0.1038419	total: 3.76s	remaining: 135ms
# 885:	learn: 0.1127745	total: 3.79s	remaining: 154ms
# 901:	learn: 0.1080437	total: 3.82s	remaining: 84.7ms
# 898:	learn: 0.0962633	total: 3.81s	remaining: 97.5ms
# 898:	learn: 0.1085256	total: 3.82s	remaining: 97.8ms
# 890:	learn: 0.1037732	total: 3.77s	remaining: 131ms
# 886:	learn: 0.1126874	total: 3.79s	remaining: 150ms
# 902:	learn: 0.1079133	total: 3.83s	remaining: 80.5ms
# 899:	learn: 0.0960785	total: 3.81s	remaining: 93.2ms
# 899:	learn: 0.1084073	total: 3.83s	remaining: 93.5ms
# 891:	learn: 0.1037115	total: 3.77s	remaining: 127ms
# 887:	learn: 0.1125869	total: 3.79s	remaining: 145ms
# 900:	learn: 0.0959499	total: 3.82s	remaining: 89ms
# 903:	learn: 0.1076356	total: 3.83s	remaining: 76.3ms
# 900:	learn: 0.1082247	total: 3.83s	remaining: 89.3ms
# 892:	learn: 0.1035536	total: 3.78s	remaining: 123ms
# 901:	learn: 0.0958027	total: 3.82s	remaining: 84.8ms
# 904:	learn: 0.1075013	total: 3.83s	remaining: 72ms
# 888:	learn: 0.1124828	total: 3.8s	remaining: 141ms
# 901:	learn: 0.1081118	total: 3.84s	remaining: 85.1ms
# 893:	learn: 0.1034383	total: 3.78s	remaining: 118ms
# 889:	learn: 0.1123922	total: 3.81s	remaining: 137ms
# 902:	learn: 0.0956793	total: 3.83s	remaining: 80.5ms
# 905:	learn: 0.1072211	total: 3.84s	remaining: 67.8ms
# 902:	learn: 0.1079602	total: 3.84s	remaining: 80.8ms
# 894:	learn: 0.1033019	total: 3.79s	remaining: 114ms
# 903:	learn: 0.0955242	total: 3.83s	remaining: 76.3ms
# 890:	learn: 0.1122350	total: 3.81s	remaining: 133ms
# 906:	learn: 0.1070685	total: 3.84s	remaining: 63.6ms
# 903:	learn: 0.1078269	total: 3.85s	remaining: 76.6ms
# 895:	learn: 0.1031612	total: 3.79s	remaining: 110ms
# 904:	learn: 0.0954544	total: 3.83s	remaining: 72.1ms
# 907:	learn: 0.1068598	total: 3.85s	remaining: 59.3ms
# 891:	learn: 0.1119879	total: 3.81s	remaining: 128ms
# 904:	learn: 0.1076333	total: 3.85s	remaining: 72.3ms
# 896:	learn: 0.1029719	total: 3.79s	remaining: 106ms
# 905:	learn: 0.0953186	total: 3.84s	remaining: 67.8ms
# 908:	learn: 0.1067184	total: 3.85s	remaining: 55.1ms
# 892:	learn: 0.1118436	total: 3.82s	remaining: 124ms
# 905:	learn: 0.1075330	total: 3.85s	remaining: 68.1ms
# 897:	learn: 0.1028673	total: 3.8s	remaining: 102ms
# 906:	learn: 0.0951326	total: 3.84s	remaining: 63.6ms
# 906:	learn: 0.1073733	total: 3.86s	remaining: 63.8ms
# 909:	learn: 0.1066205	total: 3.86s	remaining: 50.9ms
# 907:	learn: 0.0948161	total: 3.85s	remaining: 59.3ms
# 893:	learn: 0.1117240	total: 3.82s	remaining: 120ms
# 898:	learn: 0.1027286	total: 3.8s	remaining: 97.3ms
# 910:	learn: 0.1064582	total: 3.86s	remaining: 46.6ms
# 907:	learn: 0.1071918	total: 3.86s	remaining: 59.5ms
# 908:	learn: 0.0947063	total: 3.85s	remaining: 55.1ms
# 894:	learn: 0.1115875	total: 3.83s	remaining: 115ms
# 899:	learn: 0.1026027	total: 3.81s	remaining: 93.1ms
# 911:	learn: 0.1063135	total: 3.86s	remaining: 42.4ms
# 909:	learn: 0.0946399	total: 3.85s	remaining: 50.8ms
# 908:	learn: 0.1071182	total: 3.87s	remaining: 55.3ms
# 900:	learn: 0.1024094	total: 3.81s	remaining: 88.8ms
# 895:	learn: 0.1114749	total: 3.83s	remaining: 111ms
# 909:	learn: 0.1070471	total: 3.87s	remaining: 51ms
# 912:	learn: 0.1062319	total: 3.87s	remaining: 38.1ms
# 910:	learn: 0.0945349	total: 3.86s	remaining: 46.6ms
# 896:	learn: 0.1114403	total: 3.84s	remaining: 107ms
# 901:	learn: 0.1022114	total: 3.81s	remaining: 84.6ms
# 910:	learn: 0.1069300	total: 3.87s	remaining: 46.8ms
# 913:	learn: 0.1060813	total: 3.87s	remaining: 33.9ms
# 911:	learn: 0.0944144	total: 3.86s	remaining: 42.3ms
# 897:	learn: 0.1112689	total: 3.84s	remaining: 103ms
# 902:	learn: 0.1021090	total: 3.82s	remaining: 80.4ms
# 912:	learn: 0.0942762	total: 3.86s	remaining: 38.1ms
# 914:	learn: 0.1059834	total: 3.88s	remaining: 29.7ms
# 911:	learn: 0.1068304	total: 3.88s	remaining: 42.5ms
# 898:	learn: 0.1111414	total: 3.85s	remaining: 98.4ms
# 903:	learn: 0.1019892	total: 3.82s	remaining: 76.1ms
# 912:	learn: 0.1067601	total: 3.88s	remaining: 38.3ms
# 915:	learn: 0.1059282	total: 3.88s	remaining: 25.4ms
# 913:	learn: 0.0941390	total: 3.87s	remaining: 33.9ms
# 899:	learn: 0.1109806	total: 3.85s	remaining: 94.1ms
# 904:	learn: 0.1019707	total: 3.83s	remaining: 71.9ms
# 916:	learn: 0.1057833	total: 3.88s	remaining: 21.2ms
# 914:	learn: 0.0939759	total: 3.87s	remaining: 29.6ms
# 913:	learn: 0.1066569	total: 3.88s	remaining: 34ms
# 900:	learn: 0.1108733	total: 3.85s	remaining: 89.8ms
# 905:	learn: 0.1017310	total: 3.83s	remaining: 67.7ms
# 917:	learn: 0.1056815	total: 3.89s	remaining: 16.9ms
# 914:	learn: 0.1065935	total: 3.89s	remaining: 29.7ms
# 915:	learn: 0.0938526	total: 3.88s	remaining: 25.4ms
# 901:	learn: 0.1108312	total: 3.86s	remaining: 85.5ms
# 915:	learn: 0.1064967	total: 3.89s	remaining: 25.5ms
# 918:	learn: 0.1055403	total: 3.89s	remaining: 12.7ms
# 916:	learn: 0.0936854	total: 3.88s	remaining: 21.2ms
# 906:	learn: 0.1015434	total: 3.84s	remaining: 63.5ms
# 902:	learn: 0.1106840	total: 3.86s	remaining: 81.2ms
# 919:	learn: 0.1053547	total: 3.89s	remaining: 8.47ms
# 917:	learn: 0.0934908	total: 3.88s	remaining: 16.9ms
# 916:	learn: 0.1063292	total: 3.9s	remaining: 21.2ms
# 907:	learn: 0.1014617	total: 3.84s	remaining: 59.2ms
# 903:	learn: 0.1105423	total: 3.87s	remaining: 77ms
# 918:	learn: 0.0933852	total: 3.89s	remaining: 12.7ms
# 920:	learn: 0.1052002	total: 3.9s	remaining: 4.23ms
# 917:	learn: 0.1060573	total: 3.9s	remaining: 17ms
# 908:	learn: 0.1012155	total: 3.85s	remaining: 55ms
# 904:	learn: 0.1104429	total: 3.87s	remaining: 72.7ms
# 919:	learn: 0.0933385	total: 3.89s	remaining: 8.46ms
# 918:	learn: 0.1057762	total: 3.9s	remaining: 12.7ms
# 921:	learn: 0.1050292	total: 3.9s	remaining: 0us
# 909:	learn: 0.1010541	total: 3.85s	remaining: 50.8ms
# 905:	learn: 0.1103129	total: 3.87s	remaining: 68.4ms
# 920:	learn: 0.0932835	total: 3.89s	remaining: 4.23ms
# 919:	learn: 0.1057072	total: 3.91s	remaining: 8.49ms
# 906:	learn: 0.1101955	total: 3.88s	remaining: 64.1ms
# 910:	learn: 0.1009309	total: 3.85s	remaining: 46.5ms
# 920:	learn: 0.1056791	total: 3.91s	remaining: 4.25ms
# 921:	learn: 0.0931194	total: 3.9s	remaining: 0us
# 911:	learn: 0.1007119	total: 3.85s	remaining: 42.3ms
# 907:	learn: 0.1100041	total: 3.88s	remaining: 59.8ms
# 921:	learn: 0.1055902	total: 3.91s	remaining: 0us
# 908:	learn: 0.1099220	total: 3.88s	remaining: 55.5ms
# 912:	learn: 0.1005712	total: 3.86s	remaining: 38ms
# 909:	learn: 0.1097684	total: 3.88s	remaining: 51.2ms
# 913:	learn: 0.1003734	total: 3.86s	remaining: 33.8ms
# 914:	learn: 0.1001849	total: 3.87s	remaining: 29.6ms
# 910:	learn: 0.1095518	total: 3.89s	remaining: 47ms
# 911:	learn: 0.1095362	total: 3.89s	remaining: 42.7ms
# 915:	learn: 0.1000441	total: 3.87s	remaining: 25.3ms
# 912:	learn: 0.1093713	total: 3.89s	remaining: 38.4ms
# 916:	learn: 0.0998213	total: 3.87s	remaining: 21.1ms
# 913:	learn: 0.1092879	total: 3.9s	remaining: 34.1ms
# 917:	learn: 0.0997259	total: 3.87s	remaining: 16.9ms
# 914:	learn: 0.1091717	total: 3.9s	remaining: 29.8ms
# 918:	learn: 0.0995823	total: 3.88s	remaining: 12.7ms
# 915:	learn: 0.1090899	total: 3.9s	remaining: 25.6ms
# 919:	learn: 0.0994897	total: 3.88s	remaining: 8.43ms
# 916:	learn: 0.1089637	total: 3.9s	remaining: 21.3ms
# 920:	learn: 0.0992198	total: 3.88s	remaining: 4.21ms
# 917:	learn: 0.1088836	total: 3.9s	remaining: 17ms
# 921:	learn: 0.0991071	total: 3.88s	remaining: 0us
# 918:	learn: 0.1086737	total: 3.91s	remaining: 12.8ms
# 919:	learn: 0.1085522	total: 3.91s	remaining: 8.5ms
# 920:	learn: 0.1084814	total: 3.91s	remaining: 4.25ms
# 921:	learn: 0.1083260	total: 3.91s	remaining: 0us
# 0:	learn: 0.6827288	total: 3.86ms	remaining: 394ms
# 1:	learn: 0.6712662	total: 7.32ms	remaining: 370ms
# 2:	learn: 0.6582617	total: 10.5ms	remaining: 351ms
# 3:	learn: 0.6484687	total: 13.2ms	remaining: 327ms
# 4:	learn: 0.6377291	total: 16.5ms	remaining: 323ms
# 5:	learn: 0.6252679	total: 19.9ms	remaining: 321ms
# 6:	learn: 0.6141506	total: 23.4ms	remaining: 320ms
# 7:	learn: 0.6050794	total: 26.1ms	remaining: 310ms
# 8:	learn: 0.5915551	total: 28.6ms	remaining: 298ms
# 9:	learn: 0.5833293	total: 31.6ms	remaining: 294ms
# 10:	learn: 0.5758064	total: 34.4ms	remaining: 287ms
# 11:	learn: 0.5678920	total: 37.8ms	remaining: 286ms
# 12:	learn: 0.5603723	total: 40.8ms	remaining: 283ms
# 13:	learn: 0.5539059	total: 44ms	remaining: 280ms
# 14:	learn: 0.5476859	total: 46.9ms	remaining: 275ms
# 15:	learn: 0.5411287	total: 50.2ms	remaining: 273ms
# 16:	learn: 0.5333888	total: 53.6ms	remaining: 271ms
# 17:	learn: 0.5263854	total: 56.9ms	remaining: 269ms
# 18:	learn: 0.5180456	total: 60.3ms	remaining: 266ms
# 19:	learn: 0.5127901	total: 62.9ms	remaining: 261ms
# 20:	learn: 0.5075216	total: 66ms	remaining: 258ms
# 21:	learn: 0.5035009	total: 68.3ms	remaining: 251ms
# 22:	learn: 0.4990989	total: 70.7ms	remaining: 246ms
# 23:	learn: 0.4944311	total: 73.8ms	remaining: 243ms
# 24:	learn: 0.4899502	total: 76.9ms	remaining: 240ms
# 25:	learn: 0.4837121	total: 80.3ms	remaining: 238ms
# 26:	learn: 0.4784622	total: 82.7ms	remaining: 233ms
# 27:	learn: 0.4745155	total: 85.5ms	remaining: 229ms
# 28:	learn: 0.4692782	total: 88.6ms	remaining: 226ms
# 29:	learn: 0.4630563	total: 92ms	remaining: 224ms
# 30:	learn: 0.4594640	total: 95.1ms	remaining: 221ms
# 31:	learn: 0.4553519	total: 97.7ms	remaining: 217ms
# 32:	learn: 0.4525465	total: 100ms	remaining: 212ms
# 33:	learn: 0.4497353	total: 104ms	remaining: 210ms
# 34:	learn: 0.4461858	total: 107ms	remaining: 207ms
# 35:	learn: 0.4424173	total: 110ms	remaining: 204ms
# 36:	learn: 0.4386827	total: 112ms	remaining: 200ms
# 37:	learn: 0.4359328	total: 116ms	remaining: 199ms
# 38:	learn: 0.4320982	total: 119ms	remaining: 196ms
# 39:	learn: 0.4303715	total: 122ms	remaining: 192ms
# 40:	learn: 0.4275224	total: 125ms	remaining: 189ms
# 41:	learn: 0.4248039	total: 127ms	remaining: 185ms
# 42:	learn: 0.4241099	total: 128ms	remaining: 179ms
# 43:	learn: 0.4222462	total: 131ms	remaining: 175ms
# 44:	learn: 0.4201225	total: 133ms	remaining: 172ms
# 45:	learn: 0.4178363	total: 136ms	remaining: 168ms
# 46:	learn: 0.4156263	total: 138ms	remaining: 165ms
# 47:	learn: 0.4124971	total: 142ms	remaining: 162ms
# 48:	learn: 0.4099670	total: 146ms	remaining: 160ms
# 49:	learn: 0.4083696	total: 148ms	remaining: 157ms
# 50:	learn: 0.4059085	total: 151ms	remaining: 154ms
# 51:	learn: 0.4025250	total: 155ms	remaining: 152ms
# 52:	learn: 0.4005836	total: 157ms	remaining: 148ms
# 53:	learn: 0.3984958	total: 160ms	remaining: 145ms
# 54:	learn: 0.3961617	total: 162ms	remaining: 142ms
# 55:	learn: 0.3941716	total: 165ms	remaining: 139ms
# 56:	learn: 0.3912835	total: 169ms	remaining: 136ms
# 57:	learn: 0.3895059	total: 171ms	remaining: 133ms
# 58:	learn: 0.3880953	total: 174ms	remaining: 130ms
# 59:	learn: 0.3858330	total: 178ms	remaining: 127ms
# 60:	learn: 0.3847219	total: 181ms	remaining: 124ms
# 61:	learn: 0.3831595	total: 184ms	remaining: 122ms
# 62:	learn: 0.3809158	total: 187ms	remaining: 119ms
# 63:	learn: 0.3797528	total: 189ms	remaining: 115ms
# 64:	learn: 0.3784053	total: 192ms	remaining: 112ms
# 65:	learn: 0.3763595	total: 194ms	remaining: 109ms
# 66:	learn: 0.3746981	total: 198ms	remaining: 106ms
# 67:	learn: 0.3736314	total: 200ms	remaining: 103ms
# 68:	learn: 0.3713467	total: 202ms	remaining: 99.8ms
# 69:	learn: 0.3698133	total: 204ms	remaining: 96.4ms
# 70:	learn: 0.3680531	total: 207ms	remaining: 93.4ms
# 71:	learn: 0.3673819	total: 210ms	remaining: 90.2ms
# 72:	learn: 0.3657330	total: 212ms	remaining: 87ms
# 73:	learn: 0.3637633	total: 215ms	remaining: 84.1ms
# 74:	learn: 0.3624911	total: 217ms	remaining: 81ms
# 75:	learn: 0.3608587	total: 219ms	remaining: 77.9ms
# 76:	learn: 0.3596415	total: 222ms	remaining: 74.9ms
# 77:	learn: 0.3579255	total: 224ms	remaining: 71.8ms
# 78:	learn: 0.3569725	total: 227ms	remaining: 68.9ms
# 79:	learn: 0.3563390	total: 228ms	remaining: 65.6ms
# 80:	learn: 0.3548526	total: 231ms	remaining: 62.7ms
# 81:	learn: 0.3530488	total: 233ms	remaining: 59.7ms
# 82:	learn: 0.3518973	total: 235ms	remaining: 56.7ms
# 83:	learn: 0.3499587	total: 239ms	remaining: 54ms
# 84:	learn: 0.3487607	total: 241ms	remaining: 51.1ms
# 85:	learn: 0.3469927	total: 244ms	remaining: 48.2ms
# 86:	learn: 0.3459466	total: 245ms	remaining: 45.1ms
# 87:	learn: 0.3443717	total: 248ms	remaining: 42.3ms
# 88:	learn: 0.3435715	total: 250ms	remaining: 39.3ms
# 89:	learn: 0.3419464	total: 253ms	remaining: 36.6ms
# 90:	learn: 0.3410433	total: 255ms	remaining: 33.6ms
# 91:	learn: 0.3392327	total: 257ms	remaining: 30.8ms
# 92:	learn: 0.3383565	total: 260ms	remaining: 27.9ms
# 93:	learn: 0.3370789	total: 262ms	remaining: 25.1ms
# 94:	learn: 0.3359330	total: 265ms	remaining: 22.3ms
# 95:	learn: 0.3348275	total: 267ms	remaining: 19.5ms
# 96:	learn: 0.3343701	total: 269ms	remaining: 16.6ms
# 97:	learn: 0.3335334	total: 271ms	remaining: 13.8ms
# 98:	learn: 0.3323661	total: 273ms	remaining: 11ms
# 99:	learn: 0.3311703	total: 275ms	remaining: 8.26ms
# 100:	learn: 0.3294228	total: 278ms	remaining: 5.51ms
# 101:	learn: 0.3275387	total: 281ms	remaining: 2.76ms
# 102:	learn: 0.3261377	total: 283ms	remaining: 0us
# ROC AUC = 0.843
#
# Лучшие параметры модели:
# depth = 5
# grow_policy = Depthwise
# iterations = 103
# l2_leaf_reg = 1.0131357873772266
# loss_function = Logloss
# min_data_in_leaf = 15
# one_hot_max_size = 2

# %%
# расcчитаем y
y_pred = cbc_model.predict(scaled_X_test)

# оценим метрики
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {round(accuracy, 4)}")
print(f"Precision: {round(precision, 4)}")  
print(f"Recall: {round(recall, 4)}")        
print(f"F1-score: {round(f1, 4)}")

# сохраним данные в таблицу
res = {"Accuracy": round(accuracy, 4),
       "Precision": round(precision, 4),
       "Recall": round(recall, 4),
       "F1-score": round(f1, 4),
       "ROC AUC": round(roc_auc, 4)}

metrics.loc[2] = res
# Out:
# Accuracy: 0.8505
# Precision: 0.8554
# Recall: 0.8068
# F1-score: 0.8304

# %%
metrics.index = ['RandomForestClassifier', 'GradientBoostingClassifier', 'CatBoostClassifier']
metrics.head()
# Out:
#                             Accuracy  Precision  Recall  F1-score  ROC AUC
# RandomForestClassifier        0.8299     0.8571  0.7500    0.8000   0.8266
# GradientBoostingClassifier    0.8093     0.8493  0.7045    0.7702   0.8407
# CatBoostClassifier            0.8505     0.8554  0.8068    0.8304   0.8430

# %% [markdown]
# #### Вывод
# Было выполнено преобразование признака IC50, mM по бинарному критерию. Критерий оценки состоял из сравнения медианного значения признака IC50, mM с текущим значением данных.
#
# Таким образом данные превосзодившие медианное значение IC50, mM получали значение True, равные или меньшие получали значение False.
#
# Для булевой целевой переменной IC50 были дообработанны данные:
# * Добавлен дополнительный признак CC50, mM в данные для обучения
# * Сокращено количество признаков до 50
# * Данные разделены на тестовыые и тренировочные
# * Проведена стандартизация тренировочных данных и на её основе стандартизированы тестовые данные
#
# Затем были подобраны параметры и построены три модели:
#
# * RandomForestClassifier c параметрами:
#     - bootstrap = True
#     - max_depth = 50
#     - max_features = sqrt
#     - min_samples_leaf = 10
#     - min_samples_split = 20
#     - n_estimators = 500
#
# * GradientBoostingClassifier с параметрами:
#     - max_depth = 4
#     - min_samples_leaf = 4
#     - min_samples_split = 6
#     - n_estimators = 200
#
# * CatBoostClassifier с параметрами:
#     - depth = 5
#     - grow_policy = Depthwise
#     - iterations = 103
#     - l2_leaf_reg = 1.0131357873772266
#     - loss_function = Logloss
#     - min_data_in_leaf = 15
#     - one_hot_max_size = 2
#
# В качестве метрик для оценки работы модели использовались:
# * Accuracy
# * Precision
# * Recall
# * F1-score
# * ROC AUC
#
# Наилучшие показатели метрик и при обучение и при валидации на тестовых данных получились у модели CatBoostClassifier.
