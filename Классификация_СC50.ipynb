# %% [markdown]
# ### Используемые библиотеки

# %%
import pandas as pd
from skopt import BayesSearchCV
from catboost import CatBoostClassifier
from skopt.space import Categorical, Real
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, mutual_info_regression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# считываем обработанные данные
df = pd.read_csv("data.csv")
df_y = df[['IC50, mM', 'CC50, mM', 'SI']].copy()
df_x = df.drop(columns=['IC50, mM', 'CC50, mM', 'SI'])

# добавляем новый признак согласно заданию
median = df_y['CC50, mM'].median()
df_y['bool'] = (df_y['CC50, mM'] > median).astype(bool)

# %% [markdown]
# ### Классификация CC50 (превышение медианного значения выборки)

# %%
# датасет для сравнения метрик по каждой из модели
metrics = pd.DataFrame(columns=["Accuracy",
                                "Precision",
                                "Recall",
                                "F1-score",
                                "ROC AUC"]
                                )

# %%
# избавимся от лишних признаков, выделим целевую переменную и добавим дополнительный признак
y_data = df_y['bool']
x_data = df_x
x_data['IC50, mM'] = df_y['IC50, mM']

# сократим количество признаков до 50 с помощью Mutual Info
selector = SelectKBest(score_func=mutual_info_regression, k=50)
select_x_data = selector.fit_transform(x_data, y_data)
selected_features = x_data.columns[selector.get_support()]
x_data = pd.DataFrame(select_x_data, columns=selected_features)

# разделим данные на тестовыые и тренировочные
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)
print(f'Тренеровочные данные: {X_train.shape}, {y_train.shape}')
print(f'Tестовые данные: {X_test.shape}, {y_test.shape}')

# стандартизируем данные train
scaler = StandardScaler()
tmp_data = scaler.fit_transform(X_train)
scaled_X_train = pd.DataFrame(tmp_data, columns=x_data.columns)

# стандартизируем данные test
tmp_data = scaler.transform(X_test)
scaled_X_test = pd.DataFrame(tmp_data, columns=x_data.columns)
# Out:
# Тренеровочные данные: (772, 50), (772,)
# Tестовые данные: (194, 50), (194,)

# %% [markdown]
# #### RandomForestClassifier

# %%
# определим пространство гиперпараметров для модели RandomForestClassifier
param_space_rfr = {
    'n_estimators': (50, 500),
    'max_depth': (1, 50),
    'min_samples_split': (2, 20),
    'min_samples_leaf': (1, 10),
    'max_features': Categorical(['sqrt', 'log2']),
    'bootstrap': Categorical([True, False])
}

# создадим модель
model = RandomForestClassifier(random_state=42)

# оптимизируем с помощью Байесовского поиска
bayes_search = BayesSearchCV(
    estimator=model,
    search_spaces=param_space_rfr,
    n_iter=20,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=42,
)

bayes_search.fit(scaled_X_train, y_train)

# выведем показатели
roc_auc = round(bayes_search.best_score_, 4)
print(f'ROC AUC = {roc_auc}\n')
print('Лучшие параметры модели:')
for k, v in bayes_search.best_params_.items():
    print(f"{k} = {v}")

# сохраним модель с наилучшими параметрами
rfc_model = bayes_search.best_estimator_
# Out:
# ROC AUC = 0.8767
#
# Лучшие параметры модели:
# bootstrap = True
# max_depth = 15
# max_features = sqrt
# min_samples_leaf = 2
# min_samples_split = 2
# n_estimators = 263

# %%
# расcчитаем y
y_pred = rfc_model.predict(scaled_X_test)

# оценим метрики
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {round(accuracy, 4)}")
print(f"Precision: {round(precision, 4)}")  
print(f"Recall: {round(recall, 4)}")        
print(f"F1-score: {round(f1, 4)}")

# сохраним данные в таблицу
res = {"Accuracy": round(accuracy, 4),
       "Precision": round(precision, 4),
       "Recall": round(recall, 4),
       "F1-score": round(f1, 4),
       "ROC AUC": round(roc_auc, 4)}

metrics.loc[0] = res
# Out:
# Accuracy: 0.8557
# Precision: 0.8488
# Recall: 0.8295
# F1-score: 0.8391

# %% [markdown]
# #### GradientBoostingClassifier

# %%
# определим пространство гиперпараметров для модели GradientBoostingClassifier
param_space_gbr = {
    'n_estimators': (10, 200),
    'max_depth': (1, 20),
    'min_samples_split': (2, 10),
    'min_samples_leaf': (1, 7),
}

# создадим модель
model = GradientBoostingClassifier(random_state=42)

# оптимизируем с помощью Байесовского поиска
bayes_search = BayesSearchCV(
    estimator=model,
    search_spaces=param_space_gbr,
    n_iter=20,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=42,
)

bayes_search.fit(scaled_X_train, y_train)

# выведем показатели
roc_auc = round(bayes_search.best_score_, 4)
print(f'ROC AUC = {roc_auc}\n')
print('Лучшие параметры модели:')
for k, v in bayes_search.best_params_.items():
    print(f"{k} = {v}")

# сохраним модель с наилучшими параметрами
gbc_model = bayes_search.best_estimator_
# Out:
# ROC AUC = 0.8919
#
# Лучшие параметры модели:
# max_depth = 19
# min_samples_leaf = 5
# min_samples_split = 9
# n_estimators = 89

# %%
# расcчитаем y
y_pred = gbc_model.predict(scaled_X_test)

# оценим метрики
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {round(accuracy, 4)}")
print(f"Precision: {round(precision, 4)}")  
print(f"Recall: {round(recall, 4)}")        
print(f"F1-score: {round(f1, 4)}")

# сохраним данные в таблицу
res = {"Accuracy": round(accuracy, 4),
       "Precision": round(precision, 4),
       "Recall": round(recall, 4),
       "F1-score": round(f1, 4),
       "ROC AUC": round(roc_auc, 4)}

metrics.loc[1] = res
# Out:
# Accuracy: 0.8505
# Precision: 0.8734
# Recall: 0.7841
# F1-score: 0.8263

# %% [markdown]
# #### CatBoostClassifier

# %%
# определим пространство гиперпараметров для модели CatBoostClassifier
param_space_cbc = {
    'iterations': (100, 1000),
    'depth': (4, 10),
    'grow_policy': Categorical(['SymmetricTree', 'Depthwise', 'Lossguide']),
    'loss_function': Categorical(['Logloss', 'CrossEntropy']),
    'l2_leaf_reg': Real(1, 10),
    'min_data_in_leaf': (1, 50),
    'one_hot_max_size': (2, 10)
}

# создадим модель
model = CatBoostClassifier()

# оптимизируем с помощью Байесовского поиска
bayes_search = BayesSearchCV(
    estimator=model,
    search_spaces=param_space_cbc,
    n_iter=20,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=42,
)

bayes_search.fit(scaled_X_train, y_train)

# выведем показатели
roc_auc = round(bayes_search.best_score_, 4)
print(f'ROC AUC = {roc_auc}\n')
print('Лучшие параметры модели:')
for k, v in bayes_search.best_params_.items():
    print(f"{k} = {v}")

# сохраним модель с наилучшими параметрами
cbc_model = bayes_search.best_estimator_
# Out:
# 0:	learn: 0.6731447	total: 63.8ms	remaining: 60s
# 0:	learn: 0.6735223	total: 65.6ms	remaining: 1m 1s
# 0:	learn: 0.6752117	total: 66.4ms	remaining: 1m 2s
# 1:	learn: 0.6582652	total: 71.9ms	remaining: 33.7s
# 1:	learn: 0.6559134	total: 72.4ms	remaining: 34s
# 1:	learn: 0.6575973	total: 77.9ms	remaining: 36.6s
# 2:	learn: 0.6381419	total: 81.5ms	remaining: 25.4s
# 2:	learn: 0.6400362	total: 82ms	remaining: 25.6s
# 2:	learn: 0.6423703	total: 87.9ms	remaining: 27.5s
# 3:	learn: 0.6269970	total: 93.4ms	remaining: 21.8s
# 0:	learn: 0.6752909	total: 67.7ms	remaining: 1m 3s
# 3:	learn: 0.6223692	total: 98.8ms	remaining: 23.1s
# 0:	learn: 0.6732538	total: 68.4ms	remaining: 1m 4s
# 3:	learn: 0.6259380	total: 105ms	remaining: 24.5s
# 1:	learn: 0.6576910	total: 79ms	remaining: 37s
# 4:	learn: 0.6138272	total: 110ms	remaining: 20.6s
# 4:	learn: 0.6076249	total: 114ms	remaining: 21.3s
# 1:	learn: 0.6554720	total: 81.9ms	remaining: 38.4s
# 4:	learn: 0.6098125	total: 119ms	remaining: 22.3s
# 2:	learn: 0.6390384	total: 95.9ms	remaining: 29.9s
# 5:	learn: 0.6004674	total: 125ms	remaining: 19.5s
# 2:	learn: 0.6374078	total: 93.5ms	remaining: 29.2s
# 5:	learn: 0.5929008	total: 128ms	remaining: 20s
# 5:	learn: 0.5968504	total: 131ms	remaining: 20.4s
# 3:	learn: 0.6209496	total: 112ms	remaining: 26.2s
# 6:	learn: 0.5815043	total: 142ms	remaining: 18.9s
# 3:	learn: 0.6242626	total: 109ms	remaining: 25.5s
# 6:	learn: 0.5868792	total: 143ms	remaining: 19.1s
# 6:	learn: 0.5815713	total: 147ms	remaining: 19.6s
# 4:	learn: 0.6050245	total: 126ms	remaining: 23.6s
# 4:	learn: 0.6081619	total: 121ms	remaining: 22.6s
# 7:	learn: 0.5769652	total: 156ms	remaining: 18.2s
# 7:	learn: 0.5696544	total: 160ms	remaining: 18.6s
# 7:	learn: 0.5687526	total: 162ms	remaining: 18.9s
# 5:	learn: 0.5915769	total: 145ms	remaining: 22.6s
# 5:	learn: 0.5917794	total: 141ms	remaining: 22s
# 8:	learn: 0.5570699	total: 176ms	remaining: 18.2s
# 8:	learn: 0.5645830	total: 177ms	remaining: 18.3s
# 8:	learn: 0.5559598	total: 182ms	remaining: 18.8s
# 6:	learn: 0.5752159	total: 163ms	remaining: 21.7s
# 9:	learn: 0.5525367	total: 191ms	remaining: 17.8s
# 9:	learn: 0.5456289	total: 191ms	remaining: 17.8s
# 6:	learn: 0.5775377	total: 158ms	remaining: 21s
# 9:	learn: 0.5449703	total: 198ms	remaining: 18.4s
# 7:	learn: 0.5644541	total: 177ms	remaining: 20.6s
# 10:	learn: 0.5355551	total: 205ms	remaining: 17.3s
# 10:	learn: 0.5436796	total: 205ms	remaining: 17.3s
# 7:	learn: 0.5652890	total: 173ms	remaining: 20.1s
# 10:	learn: 0.5344495	total: 214ms	remaining: 18.1s
# 8:	learn: 0.5527048	total: 190ms	remaining: 19.6s
# 11:	learn: 0.5258260	total: 219ms	remaining: 16.9s
# 11:	learn: 0.5334655	total: 221ms	remaining: 17.1s
# 8:	learn: 0.5522694	total: 192ms	remaining: 19.8s
# 11:	learn: 0.5235966	total: 230ms	remaining: 17.8s
# 9:	learn: 0.5415655	total: 205ms	remaining: 19s
# 12:	learn: 0.5167863	total: 235ms	remaining: 16.8s
# 12:	learn: 0.5225092	total: 237ms	remaining: 16.9s
# 9:	learn: 0.5402208	total: 208ms	remaining: 19.3s
# 12:	learn: 0.5122888	total: 244ms	remaining: 17.4s
# 10:	learn: 0.5283266	total: 222ms	remaining: 18.7s
# 13:	learn: 0.5123059	total: 251ms	remaining: 16.6s
# 13:	learn: 0.5066297	total: 253ms	remaining: 16.7s
# 10:	learn: 0.5292960	total: 223ms	remaining: 18.9s
# 13:	learn: 0.5039687	total: 258ms	remaining: 17.1s
# 11:	learn: 0.5184033	total: 237ms	remaining: 18.4s
# 14:	learn: 0.5020910	total: 268ms	remaining: 16.5s
# 11:	learn: 0.5173461	total: 234ms	remaining: 18.1s
# 14:	learn: 0.4983484	total: 268ms	remaining: 16.6s
# 14:	learn: 0.4944625	total: 270ms	remaining: 16.6s
# 15:	learn: 0.4922111	total: 283ms	remaining: 16.3s
# 12:	learn: 0.5080249	total: 253ms	remaining: 18s
# 12:	learn: 0.5063352	total: 261ms	remaining: 18.6s
# 15:	learn: 0.4861637	total: 290ms	remaining: 16.8s
# 15:	learn: 0.4900766	total: 291ms	remaining: 16.8s
# 16:	learn: 0.4794633	total: 301ms	remaining: 16.3s
# 13:	learn: 0.4985728	total: 268ms	remaining: 17.7s
# 16:	learn: 0.4850629	total: 302ms	remaining: 16.4s
# 16:	learn: 0.4823068	total: 303ms	remaining: 16.5s
# 13:	learn: 0.4944154	total: 277ms	remaining: 18.3s
# 17:	learn: 0.4787601	total: 311ms	remaining: 15.9s
# 17:	learn: 0.4764035	total: 313ms	remaining: 16s
# 17:	learn: 0.4704664	total: 314ms	remaining: 16.1s
# 14:	learn: 0.4891618	total: 283ms	remaining: 17.4s
# 14:	learn: 0.4866138	total: 292ms	remaining: 18s
# 18:	learn: 0.4634851	total: 327ms	remaining: 15.9s
# 18:	learn: 0.4707767	total: 329ms	remaining: 15.9s
# 18:	learn: 0.4682620	total: 333ms	remaining: 16.1s
# 15:	learn: 0.4807570	total: 301ms	remaining: 17.4s
# 15:	learn: 0.4777534	total: 307ms	remaining: 17.7s
# 19:	learn: 0.4560159	total: 344ms	remaining: 15.8s
# 19:	learn: 0.4633458	total: 346ms	remaining: 15.9s
# 16:	learn: 0.4746311	total: 314ms	remaining: 17s
# 16:	learn: 0.4692465	total: 320ms	remaining: 17.4s
# 19:	learn: 0.4604515	total: 351ms	remaining: 16.2s
# 20:	learn: 0.4507732	total: 354ms	remaining: 15.5s
# 20:	learn: 0.4574942	total: 359ms	remaining: 15.7s
# 17:	learn: 0.4686860	total: 328ms	remaining: 16.8s
# 17:	learn: 0.4590064	total: 335ms	remaining: 17.2s
# 20:	learn: 0.4543524	total: 363ms	remaining: 15.9s
# 21:	learn: 0.4447227	total: 367ms	remaining: 15.3s
# 21:	learn: 0.4525649	total: 370ms	remaining: 15.4s
# 21:	learn: 0.4474403	total: 376ms	remaining: 15.7s
# 18:	learn: 0.4621067	total: 344ms	remaining: 16.7s
# 22:	learn: 0.4395037	total: 380ms	remaining: 15.1s
# 18:	learn: 0.4529824	total: 354ms	remaining: 17.2s
# 22:	learn: 0.4456090	total: 382ms	remaining: 15.2s
# 22:	learn: 0.4407754	total: 388ms	remaining: 15.5s
# 19:	learn: 0.4527343	total: 358ms	remaining: 16.5s
# 23:	learn: 0.4385313	total: 394ms	remaining: 15.1s
# 23:	learn: 0.4341427	total: 396ms	remaining: 15.1s
# 19:	learn: 0.4445366	total: 369ms	remaining: 17s
# 23:	learn: 0.4367513	total: 403ms	remaining: 15.4s
# 20:	learn: 0.4445475	total: 374ms	remaining: 16.4s
# 24:	learn: 0.4330626	total: 408ms	remaining: 14.9s
# 20:	learn: 0.4388312	total: 382ms	remaining: 16.7s
# 24:	learn: 0.4288386	total: 412ms	remaining: 15.1s
# 24:	learn: 0.4305541	total: 419ms	remaining: 15.3s
# 21:	learn: 0.4333025	total: 395ms	remaining: 16.5s
# 21:	learn: 0.4391270	total: 389ms	remaining: 16.2s
# 25:	learn: 0.4262982	total: 422ms	remaining: 14.8s
# 25:	learn: 0.4226363	total: 426ms	remaining: 15s
# 22:	learn: 0.4269520	total: 406ms	remaining: 16.2s
# 25:	learn: 0.4273628	total: 434ms	remaining: 15.3s
# 26:	learn: 0.4227045	total: 435ms	remaining: 14.7s
# 22:	learn: 0.4330814	total: 402ms	remaining: 16s
# 26:	learn: 0.4169587	total: 438ms	remaining: 14.8s
# 23:	learn: 0.4229620	total: 419ms	remaining: 16s
# 26:	learn: 0.4215372	total: 449ms	remaining: 15.2s
# 27:	learn: 0.4130556	total: 451ms	remaining: 14.7s
# 23:	learn: 0.4269788	total: 418ms	remaining: 15.9s
# 27:	learn: 0.4176062	total: 453ms	remaining: 14.7s
# 28:	learn: 0.4126038	total: 462ms	remaining: 14.5s
# 27:	learn: 0.4144558	total: 462ms	remaining: 15s
# 24:	learn: 0.4167861	total: 435ms	remaining: 15.9s
# 24:	learn: 0.4213167	total: 430ms	remaining: 15.7s
# 28:	learn: 0.4070903	total: 466ms	remaining: 14.7s
# 25:	learn: 0.4126846	total: 449ms	remaining: 15.8s
# 28:	learn: 0.4091190	total: 476ms	remaining: 15s
# 29:	learn: 0.4017959	total: 479ms	remaining: 14.5s
# 25:	learn: 0.4151283	total: 447ms	remaining: 15.7s
# 29:	learn: 0.4065775	total: 482ms	remaining: 14.6s
# 30:	learn: 0.3976789	total: 494ms	remaining: 14.5s
# 26:	learn: 0.4073102	total: 467ms	remaining: 15.8s
# 29:	learn: 0.4039446	total: 495ms	remaining: 15s
# 26:	learn: 0.4097647	total: 461ms	remaining: 15.6s
# 30:	learn: 0.4015588	total: 497ms	remaining: 14.6s
# 31:	learn: 0.3934965	total: 505ms	remaining: 14.3s
# 27:	learn: 0.4028719	total: 480ms	remaining: 15.6s
# 27:	learn: 0.4054436	total: 472ms	remaining: 15.4s
# 30:	learn: 0.3985647	total: 510ms	remaining: 15s
# 31:	learn: 0.3958620	total: 512ms	remaining: 14.5s
# 28:	learn: 0.3966005	total: 491ms	remaining: 15.4s
# 28:	learn: 0.4005739	total: 483ms	remaining: 15.2s
# 32:	learn: 0.3892468	total: 520ms	remaining: 14.3s
# 32:	learn: 0.3934279	total: 522ms	remaining: 14.3s
# 31:	learn: 0.3943518	total: 523ms	remaining: 14.8s
# 29:	learn: 0.3969807	total: 497ms	remaining: 15.1s
# 29:	learn: 0.3922535	total: 507ms	remaining: 15.4s
# 33:	learn: 0.3845424	total: 535ms	remaining: 14.3s
# 33:	learn: 0.3893606	total: 538ms	remaining: 14.3s
# 32:	learn: 0.3889168	total: 540ms	remaining: 14.8s
# 30:	learn: 0.3923493	total: 510ms	remaining: 14.9s
# 33:	learn: 0.3863611	total: 550ms	remaining: 14.7s
# 30:	learn: 0.3875702	total: 523ms	remaining: 15.3s
# 34:	learn: 0.3857870	total: 550ms	remaining: 14.2s
# 34:	learn: 0.3808093	total: 555ms	remaining: 14.3s
# 31:	learn: 0.3888157	total: 523ms	remaining: 14.8s
# 31:	learn: 0.3838104	total: 533ms	remaining: 15.1s
# 35:	learn: 0.3818228	total: 562ms	remaining: 14.1s
# 34:	learn: 0.3810972	total: 566ms	remaining: 14.6s
# 35:	learn: 0.3770814	total: 568ms	remaining: 14.3s
# 32:	learn: 0.3850600	total: 536ms	remaining: 14.7s
# 32:	learn: 0.3794338	total: 546ms	remaining: 15s
# 36:	learn: 0.3777740	total: 574ms	remaining: 14s
# 35:	learn: 0.3768873	total: 578ms	remaining: 14.5s
# 36:	learn: 0.3733363	total: 580ms	remaining: 14.2s
# 33:	learn: 0.3821254	total: 549ms	remaining: 14.6s
# 33:	learn: 0.3764877	total: 558ms	remaining: 14.9s
# 37:	learn: 0.3730354	total: 588ms	remaining: 14s
# 36:	learn: 0.3727157	total: 595ms	remaining: 14.5s
# 37:	learn: 0.3699155	total: 596ms	remaining: 14.1s
# 34:	learn: 0.3779407	total: 565ms	remaining: 14.6s
# 38:	learn: 0.3699475	total: 602ms	remaining: 13.9s
# 34:	learn: 0.3719549	total: 576ms	remaining: 14.9s
# 38:	learn: 0.3678397	total: 607ms	remaining: 14s
# 37:	learn: 0.3686763	total: 612ms	remaining: 14.5s
# 35:	learn: 0.3745815	total: 579ms	remaining: 14.5s
# 39:	learn: 0.3656462	total: 617ms	remaining: 13.9s
# 39:	learn: 0.3638383	total: 620ms	remaining: 14s
# 35:	learn: 0.3681039	total: 594ms	remaining: 14.9s
# 38:	learn: 0.3656924	total: 626ms	remaining: 14.5s
# 36:	learn: 0.3703350	total: 592ms	remaining: 14.4s
# 40:	learn: 0.3630715	total: 631ms	remaining: 13.8s
# 36:	learn: 0.3634477	total: 608ms	remaining: 14.8s
# 40:	learn: 0.3602122	total: 638ms	remaining: 14s
# 37:	learn: 0.3675655	total: 603ms	remaining: 14.3s
# 39:	learn: 0.3630032	total: 640ms	remaining: 14.4s
# 41:	learn: 0.3596974	total: 648ms	remaining: 13.9s
# 40:	learn: 0.3606619	total: 650ms	remaining: 14.3s
# 38:	learn: 0.3638870	total: 614ms	remaining: 14.2s
# 37:	learn: 0.3593867	total: 624ms	remaining: 14.8s
# 41:	learn: 0.3566870	total: 654ms	remaining: 14s
# 41:	learn: 0.3580356	total: 661ms	remaining: 14.1s
# 39:	learn: 0.3605650	total: 626ms	remaining: 14.1s
# 42:	learn: 0.3560189	total: 661ms	remaining: 13.8s
# 38:	learn: 0.3564063	total: 636ms	remaining: 14.7s
# 42:	learn: 0.3529631	total: 666ms	remaining: 13.9s
# 42:	learn: 0.3563210	total: 670ms	remaining: 14s
# 43:	learn: 0.3532995	total: 673ms	remaining: 13.7s
# 40:	learn: 0.3564680	total: 640ms	remaining: 14s
# 39:	learn: 0.3533184	total: 651ms	remaining: 14.6s
# 43:	learn: 0.3536709	total: 679ms	remaining: 13.8s
# 43:	learn: 0.3489088	total: 686ms	remaining: 14s
# 44:	learn: 0.3507838	total: 690ms	remaining: 13.7s
# 40:	learn: 0.3492479	total: 667ms	remaining: 14.6s
# 44:	learn: 0.3504062	total: 695ms	remaining: 13.8s
# 41:	learn: 0.3526394	total: 660ms	remaining: 14.1s
# 44:	learn: 0.3467106	total: 701ms	remaining: 13.9s
# 45:	learn: 0.3478504	total: 703ms	remaining: 13.7s
# 42:	learn: 0.3489638	total: 669ms	remaining: 14s
# 45:	learn: 0.3454422	total: 708ms	remaining: 13.8s
# 41:	learn: 0.3461084	total: 681ms	remaining: 14.6s
# 45:	learn: 0.3477015	total: 711ms	remaining: 13.8s
# 46:	learn: 0.3450252	total: 714ms	remaining: 13.6s
# 43:	learn: 0.3464258	total: 681ms	remaining: 13.9s
# 42:	learn: 0.3431135	total: 695ms	remaining: 14.5s
# 46:	learn: 0.3409287	total: 722ms	remaining: 13.7s
# 46:	learn: 0.3434117	total: 725ms	remaining: 13.8s
# 47:	learn: 0.3421098	total: 724ms	remaining: 13.5s
# 44:	learn: 0.3431273	total: 693ms	remaining: 13.8s
# 47:	learn: 0.3390158	total: 736ms	remaining: 13.7s
# 48:	learn: 0.3387876	total: 736ms	remaining: 13.4s
# 43:	learn: 0.3399336	total: 711ms	remaining: 14.5s
# 47:	learn: 0.3392565	total: 741ms	remaining: 13.8s
# 45:	learn: 0.3391436	total: 709ms	remaining: 13.8s
# 48:	learn: 0.3358329	total: 749ms	remaining: 13.6s
# 44:	learn: 0.3363730	total: 722ms	remaining: 14.4s
# 49:	learn: 0.3353668	total: 750ms	remaining: 13.3s
# 48:	learn: 0.3356188	total: 755ms	remaining: 13.7s
# 46:	learn: 0.3363071	total: 722ms	remaining: 13.7s
# 50:	learn: 0.3326605	total: 761ms	remaining: 13.3s
# 49:	learn: 0.3324357	total: 763ms	remaining: 13.6s
# 45:	learn: 0.3341965	total: 738ms	remaining: 14.3s
# 47:	learn: 0.3346955	total: 730ms	remaining: 13.6s
# 49:	learn: 0.3330397	total: 768ms	remaining: 13.7s
# 51:	learn: 0.3306512	total: 771ms	remaining: 13.2s
# 46:	learn: 0.3305986	total: 752ms	remaining: 14.3s
# 50:	learn: 0.3299171	total: 780ms	remaining: 13.6s
# 50:	learn: 0.3292611	total: 780ms	remaining: 13.6s
# 48:	learn: 0.3317487	total: 746ms	remaining: 13.6s
# 52:	learn: 0.3277831	total: 784ms	remaining: 13.1s
# 51:	learn: 0.3277387	total: 787ms	remaining: 13.4s
# 47:	learn: 0.3287760	total: 765ms	remaining: 14.2s
# 51:	learn: 0.3271173	total: 793ms	remaining: 13.5s
# 49:	learn: 0.3288524	total: 761ms	remaining: 13.5s
# 53:	learn: 0.3264518	total: 796ms	remaining: 13.1s
# 52:	learn: 0.3249011	total: 801ms	remaining: 13.4s
# 48:	learn: 0.3260416	total: 779ms	remaining: 14.2s
# 52:	learn: 0.3245565	total: 807ms	remaining: 13.5s
# 50:	learn: 0.3261325	total: 775ms	remaining: 13.5s
# 54:	learn: 0.3239447	total: 811ms	remaining: 13.1s
# 53:	learn: 0.3221616	total: 815ms	remaining: 13.4s
# 49:	learn: 0.3236465	total: 792ms	remaining: 14.1s
# 53:	learn: 0.3220847	total: 821ms	remaining: 13.5s
# 54:	learn: 0.3205931	total: 828ms	remaining: 13.3s
# 55:	learn: 0.3212488	total: 828ms	remaining: 13.1s
# 51:	learn: 0.3233024	total: 794ms	remaining: 13.6s
# 50:	learn: 0.3204999	total: 810ms	remaining: 14.1s
# 54:	learn: 0.3187821	total: 837ms	remaining: 13.5s
# 55:	learn: 0.3172766	total: 842ms	remaining: 13.3s
# 56:	learn: 0.3191135	total: 842ms	remaining: 13s
# 52:	learn: 0.3208096	total: 808ms	remaining: 13.5s
# 51:	learn: 0.3181070	total: 821ms	remaining: 14s
# 55:	learn: 0.3161970	total: 849ms	remaining: 13.4s
# 57:	learn: 0.3168999	total: 854ms	remaining: 13s
# 53:	learn: 0.3178216	total: 822ms	remaining: 13.5s
# 56:	learn: 0.3147661	total: 859ms	remaining: 13.3s
# 56:	learn: 0.3138239	total: 860ms	remaining: 13.3s
# 52:	learn: 0.3154043	total: 834ms	remaining: 14s
# 58:	learn: 0.3148381	total: 866ms	remaining: 12.9s
# 53:	learn: 0.3131684	total: 844ms	remaining: 13.8s
# 54:	learn: 0.3152438	total: 836ms	remaining: 13.4s
# 57:	learn: 0.3129220	total: 873ms	remaining: 13.3s
# 57:	learn: 0.3114751	total: 875ms	remaining: 13.3s
# 59:	learn: 0.3124638	total: 881ms	remaining: 12.9s
# 54:	learn: 0.3107685	total: 857ms	remaining: 13.8s
# 55:	learn: 0.3130606	total: 851ms	remaining: 13.4s
# 58:	learn: 0.3105465	total: 889ms	remaining: 13.3s
# 58:	learn: 0.3093272	total: 892ms	remaining: 13.3s
# 60:	learn: 0.3109159	total: 898ms	remaining: 12.9s
# 59:	learn: 0.3079200	total: 901ms	remaining: 13.2s
# 56:	learn: 0.3115150	total: 866ms	remaining: 13.4s
# 59:	learn: 0.3085442	total: 902ms	remaining: 13.2s
# 55:	learn: 0.3079291	total: 875ms	remaining: 13.8s
# 57:	learn: 0.3104349	total: 872ms	remaining: 13.3s
# 56:	learn: 0.3058555	total: 886ms	remaining: 13.7s
# 61:	learn: 0.3080966	total: 911ms	remaining: 12.9s
# 60:	learn: 0.3055283	total: 916ms	remaining: 13.2s
# 60:	learn: 0.3064434	total: 919ms	remaining: 13.2s
# 62:	learn: 0.3064776	total: 920ms	remaining: 12.8s
# 58:	learn: 0.3083104	total: 887ms	remaining: 13.3s
# 57:	learn: 0.3034188	total: 898ms	remaining: 13.7s
# 61:	learn: 0.3039948	total: 928ms	remaining: 13.1s
# 61:	learn: 0.3042892	total: 929ms	remaining: 13.2s
# 63:	learn: 0.3038469	total: 931ms	remaining: 12.7s
# 58:	learn: 0.3014562	total: 909ms	remaining: 13.6s
# 59:	learn: 0.3055750	total: 900ms	remaining: 13.2s
# 62:	learn: 0.3016436	total: 939ms	remaining: 13.1s
# 62:	learn: 0.3026336	total: 940ms	remaining: 13.1s
# 64:	learn: 0.3020784	total: 941ms	remaining: 12.7s
# 59:	learn: 0.2995925	total: 917ms	remaining: 13.4s
# 60:	learn: 0.3036699	total: 909ms	remaining: 13.1s
# 63:	learn: 0.3004470	total: 952ms	remaining: 13s
# 65:	learn: 0.3001506	total: 952ms	remaining: 12.6s
# 63:	learn: 0.2995450	total: 955ms	remaining: 13.1s
# 61:	learn: 0.3013653	total: 921ms	remaining: 13s
# 60:	learn: 0.2964551	total: 931ms	remaining: 13.4s
# 66:	learn: 0.2987860	total: 960ms	remaining: 12.5s
# 64:	learn: 0.2981916	total: 965ms	remaining: 13s
# 62:	learn: 0.2993817	total: 933ms	remaining: 13s
# 64:	learn: 0.2975887	total: 970ms	remaining: 13.1s
# 61:	learn: 0.2950397	total: 943ms	remaining: 13.4s
# 65:	learn: 0.2958045	total: 977ms	remaining: 12.9s
# 67:	learn: 0.2963215	total: 975ms	remaining: 12.5s
# 65:	learn: 0.2955711	total: 983ms	remaining: 13s
# 63:	learn: 0.2975014	total: 947ms	remaining: 13s
# 68:	learn: 0.2954314	total: 981ms	remaining: 12.4s
# 62:	learn: 0.2928048	total: 957ms	remaining: 13.3s
# 66:	learn: 0.2933925	total: 992ms	remaining: 12.9s
# 64:	learn: 0.2959562	total: 958ms	remaining: 12.9s
# 66:	learn: 0.2936795	total: 995ms	remaining: 13s
# 69:	learn: 0.2932638	total: 993ms	remaining: 12.3s
# 63:	learn: 0.2906304	total: 969ms	remaining: 13.3s
# 65:	learn: 0.2943280	total: 965ms	remaining: 12.8s
# 67:	learn: 0.2916044	total: 1s	remaining: 12.9s
# 64:	learn: 0.2889376	total: 979ms	remaining: 13.2s
# 70:	learn: 0.2911602	total: 1.01s	remaining: 12.3s
# 68:	learn: 0.2899222	total: 1.01s	remaining: 12.7s
# 67:	learn: 0.2919104	total: 1.01s	remaining: 13s
# 66:	learn: 0.2917612	total: 981ms	remaining: 12.8s
# 65:	learn: 0.2864660	total: 992ms	remaining: 13.1s
# 69:	learn: 0.2884638	total: 1.02s	remaining: 12.7s
# 71:	learn: 0.2889438	total: 1.02s	remaining: 12.3s
# 67:	learn: 0.2900174	total: 991ms	remaining: 12.7s
# 68:	learn: 0.2893410	total: 1.03s	remaining: 13s
# 66:	learn: 0.2841771	total: 1s	remaining: 13.1s
# 70:	learn: 0.2861281	total: 1.03s	remaining: 12.7s
# 72:	learn: 0.2865656	total: 1.03s	remaining: 12.3s
# 68:	learn: 0.2882248	total: 1s	remaining: 12.7s
# 69:	learn: 0.2879524	total: 1.04s	remaining: 12.9s
# 67:	learn: 0.2823510	total: 1.02s	remaining: 13.1s
# 73:	learn: 0.2856917	total: 1.04s	remaining: 12.2s
# 71:	learn: 0.2840682	total: 1.05s	remaining: 12.6s
# 69:	learn: 0.2858163	total: 1.01s	remaining: 12.6s
# 70:	learn: 0.2859478	total: 1.05s	remaining: 12.9s
# 68:	learn: 0.2811293	total: 1.03s	remaining: 13s
# 72:	learn: 0.2816696	total: 1.06s	remaining: 12.6s
# 74:	learn: 0.2836051	total: 1.06s	remaining: 12.2s
# 70:	learn: 0.2833349	total: 1.03s	remaining: 12.6s
# 71:	learn: 0.2846499	total: 1.06s	remaining: 12.8s
# 69:	learn: 0.2794591	total: 1.04s	remaining: 12.9s
# 75:	learn: 0.2822055	total: 1.07s	remaining: 12.1s
# 73:	learn: 0.2799662	total: 1.07s	remaining: 12.6s
# 72:	learn: 0.2830948	total: 1.08s	remaining: 12.8s
# 71:	learn: 0.2812451	total: 1.04s	remaining: 12.6s
# 70:	learn: 0.2781230	total: 1.06s	remaining: 12.9s
# 76:	learn: 0.2799786	total: 1.08s	remaining: 12.1s
# 74:	learn: 0.2781119	total: 1.09s	remaining: 12.6s
# 71:	learn: 0.2755848	total: 1.07s	remaining: 12.9s
# 75:	learn: 0.2768188	total: 1.1s	remaining: 12.5s
# 73:	learn: 0.2812735	total: 1.1s	remaining: 12.8s
# 72:	learn: 0.2776635	total: 1.06s	remaining: 12.6s
# 77:	learn: 0.2790004	total: 1.1s	remaining: 12.1s
# 74:	learn: 0.2797268	total: 1.11s	remaining: 12.8s
# 73:	learn: 0.2761900	total: 1.07s	remaining: 12.5s
# 78:	learn: 0.2770259	total: 1.1s	remaining: 12.1s
# 76:	learn: 0.2748669	total: 1.11s	remaining: 12.4s
# 72:	learn: 0.2730693	total: 1.09s	remaining: 12.9s
# 75:	learn: 0.2780979	total: 1.12s	remaining: 12.7s
# 74:	learn: 0.2737861	total: 1.08s	remaining: 12.5s
# 79:	learn: 0.2751713	total: 1.12s	remaining: 12s
# 77:	learn: 0.2737395	total: 1.12s	remaining: 12.4s
# 73:	learn: 0.2712063	total: 1.1s	remaining: 12.9s
# 80:	learn: 0.2743460	total: 1.12s	remaining: 11.9s
# 76:	learn: 0.2770072	total: 1.13s	remaining: 12.6s
# 75:	learn: 0.2722367	total: 1.09s	remaining: 12.4s
# 78:	learn: 0.2723916	total: 1.13s	remaining: 12.3s
# 81:	learn: 0.2733223	total: 1.13s	remaining: 11.8s
# 74:	learn: 0.2695944	total: 1.11s	remaining: 12.9s
# 77:	learn: 0.2752194	total: 1.14s	remaining: 12.6s
# 76:	learn: 0.2706258	total: 1.11s	remaining: 12.4s
# 82:	learn: 0.2720617	total: 1.14s	remaining: 11.8s
# 79:	learn: 0.2698025	total: 1.15s	remaining: 12.3s
# 75:	learn: 0.2683481	total: 1.13s	remaining: 12.8s
# 77:	learn: 0.2694006	total: 1.12s	remaining: 12.3s
# 78:	learn: 0.2736843	total: 1.16s	remaining: 12.6s
# 80:	learn: 0.2684608	total: 1.16s	remaining: 12.3s
# 83:	learn: 0.2699933	total: 1.16s	remaining: 11.8s
# 78:	learn: 0.2676873	total: 1.13s	remaining: 12.3s
# 76:	learn: 0.2664246	total: 1.14s	remaining: 12.8s
# 79:	learn: 0.2726489	total: 1.17s	remaining: 12.6s
# 81:	learn: 0.2665848	total: 1.17s	remaining: 12.2s
# 84:	learn: 0.2690600	total: 1.17s	remaining: 11.8s
# 79:	learn: 0.2654722	total: 1.14s	remaining: 12.3s
# 85:	learn: 0.2678974	total: 1.18s	remaining: 11.7s
# 77:	learn: 0.2637447	total: 1.15s	remaining: 12.8s
# 80:	learn: 0.2706112	total: 1.18s	remaining: 12.5s
# 80:	learn: 0.2643614	total: 1.15s	remaining: 12.2s
# 82:	learn: 0.2647055	total: 1.19s	remaining: 12.3s
# 78:	learn: 0.2627974	total: 1.17s	remaining: 12.7s
# 86:	learn: 0.2661863	total: 1.19s	remaining: 11.7s
# 81:	learn: 0.2690888	total: 1.2s	remaining: 12.6s
# 81:	learn: 0.2626285	total: 1.16s	remaining: 12.2s
# 83:	learn: 0.2631583	total: 1.2s	remaining: 12.2s
# 82:	learn: 0.2617241	total: 1.17s	remaining: 12.1s
# 84:	learn: 0.2609582	total: 1.21s	remaining: 12.2s
# 79:	learn: 0.2613153	total: 1.19s	remaining: 12.8s
# 82:	learn: 0.2676524	total: 1.22s	remaining: 12.6s
# 87:	learn: 0.2641687	total: 1.22s	remaining: 11.8s
# 83:	learn: 0.2668408	total: 1.22s	remaining: 12.5s
# 85:	learn: 0.2595381	total: 1.23s	remaining: 12.2s
# 88:	learn: 0.2635437	total: 1.23s	remaining: 11.7s
# 83:	learn: 0.2596249	total: 1.19s	remaining: 12.2s
# 80:	learn: 0.2598760	total: 1.2s	remaining: 12.8s
# 86:	learn: 0.2580213	total: 1.23s	remaining: 12.1s
# 84:	learn: 0.2648532	total: 1.24s	remaining: 12.5s
# 81:	learn: 0.2589460	total: 1.21s	remaining: 12.7s
# 87:	learn: 0.2569245	total: 1.24s	remaining: 12s
# 84:	learn: 0.2580168	total: 1.21s	remaining: 12.2s
# 89:	learn: 0.2608095	total: 1.25s	remaining: 11.8s
# 88:	learn: 0.2555392	total: 1.25s	remaining: 12s
# 85:	learn: 0.2634440	total: 1.26s	remaining: 12.5s
# 82:	learn: 0.2577593	total: 1.23s	remaining: 12.7s
# 89:	learn: 0.2547961	total: 1.26s	remaining: 12s
# 86:	learn: 0.2617873	total: 1.27s	remaining: 12.5s
# 90:	learn: 0.2592816	total: 1.27s	remaining: 11.8s
# 83:	learn: 0.2570615	total: 1.24s	remaining: 12.7s
# 85:	learn: 0.2557523	total: 1.23s	remaining: 12.3s
# 84:	learn: 0.2565848	total: 1.25s	remaining: 12.6s
# 90:	learn: 0.2541526	total: 1.28s	remaining: 12s
# 86:	learn: 0.2547811	total: 1.25s	remaining: 12.2s
# 87:	learn: 0.2601631	total: 1.29s	remaining: 12.5s
# 85:	learn: 0.2557727	total: 1.26s	remaining: 12.6s
# 91:	learn: 0.2575371	total: 1.29s	remaining: 11.9s
# 87:	learn: 0.2537905	total: 1.26s	remaining: 12.2s
# 91:	learn: 0.2523472	total: 1.3s	remaining: 12s
# 88:	learn: 0.2587127	total: 1.3s	remaining: 12.5s
# 86:	learn: 0.2535840	total: 1.28s	remaining: 12.6s
# 88:	learn: 0.2519657	total: 1.27s	remaining: 12.2s
# 92:	learn: 0.2558438	total: 1.31s	remaining: 11.9s
# 87:	learn: 0.2522428	total: 1.29s	remaining: 12.5s
# 89:	learn: 0.2579116	total: 1.32s	remaining: 12.5s
# 92:	learn: 0.2505306	total: 1.32s	remaining: 12s
# 93:	learn: 0.2549708	total: 1.32s	remaining: 11.9s
# 89:	learn: 0.2509924	total: 1.29s	remaining: 12.2s
# 88:	learn: 0.2513763	total: 1.3s	remaining: 12.4s
# 90:	learn: 0.2568340	total: 1.33s	remaining: 12.4s
# 94:	learn: 0.2536348	total: 1.33s	remaining: 11.8s
# 93:	learn: 0.2494759	total: 1.33s	remaining: 12s
# 90:	learn: 0.2498380	total: 1.29s	remaining: 12.1s
# 91:	learn: 0.2556216	total: 1.34s	remaining: 12.4s
# 95:	learn: 0.2525548	total: 1.34s	remaining: 11.8s
# 89:	learn: 0.2492175	total: 1.32s	remaining: 12.4s
# 91:	learn: 0.2483667	total: 1.31s	remaining: 12s
# 94:	learn: 0.2480110	total: 1.35s	remaining: 12s
# 92:	learn: 0.2543279	total: 1.35s	remaining: 12.3s
# 90:	learn: 0.2469229	total: 1.33s	remaining: 12.4s
# 96:	learn: 0.2508632	total: 1.35s	remaining: 11.8s
# 92:	learn: 0.2469352	total: 1.32s	remaining: 12.1s
# 95:	learn: 0.2462254	total: 1.36s	remaining: 12s
# 93:	learn: 0.2533070	total: 1.37s	remaining: 12.3s
# 91:	learn: 0.2456643	total: 1.34s	remaining: 12.3s
# 93:	learn: 0.2455783	total: 1.33s	remaining: 12s
# 96:	learn: 0.2445381	total: 1.37s	remaining: 11.9s
# 97:	learn: 0.2490167	total: 1.37s	remaining: 11.8s
# 94:	learn: 0.2522314	total: 1.38s	remaining: 12.2s
# 92:	learn: 0.2442588	total: 1.35s	remaining: 12.3s
# 98:	learn: 0.2483893	total: 1.38s	remaining: 11.7s
# 94:	learn: 0.2444456	total: 1.35s	remaining: 12s
# 97:	learn: 0.2424773	total: 1.39s	remaining: 12s
# 93:	learn: 0.2431178	total: 1.36s	remaining: 12.3s
# 95:	learn: 0.2501610	total: 1.4s	remaining: 12.3s
# 95:	learn: 0.2429730	total: 1.36s	remaining: 12s
# 99:	learn: 0.2471333	total: 1.4s	remaining: 11.8s
# 96:	learn: 0.2493508	total: 1.41s	remaining: 12.2s
# 98:	learn: 0.2410710	total: 1.41s	remaining: 12s
# 94:	learn: 0.2417155	total: 1.38s	remaining: 12.3s
# 96:	learn: 0.2412289	total: 1.38s	remaining: 12s
# 97:	learn: 0.2488297	total: 1.41s	remaining: 12.2s
# 100:	learn: 0.2458432	total: 1.42s	remaining: 11.8s
# 99:	learn: 0.2396453	total: 1.42s	remaining: 11.9s
# 95:	learn: 0.2401762	total: 1.39s	remaining: 12.3s
# 98:	learn: 0.2471801	total: 1.43s	remaining: 12.1s
# 97:	learn: 0.2394457	total: 1.39s	remaining: 11.9s
# 101:	learn: 0.2447428	total: 1.43s	remaining: 11.7s
# 100:	learn: 0.2382750	total: 1.43s	remaining: 11.9s
# 99:	learn: 0.2459187	total: 1.44s	remaining: 12.1s
# 102:	learn: 0.2436121	total: 1.44s	remaining: 11.7s
# 98:	learn: 0.2386479	total: 1.4s	remaining: 11.9s
# 96:	learn: 0.2386487	total: 1.41s	remaining: 12.3s
# 100:	learn: 0.2448848	total: 1.44s	remaining: 12s
# 101:	learn: 0.2370711	total: 1.45s	remaining: 11.9s
# 97:	learn: 0.2376200	total: 1.43s	remaining: 12.3s
# 102:	learn: 0.2359042	total: 1.46s	remaining: 11.8s
# 99:	learn: 0.2373696	total: 1.42s	remaining: 11.9s
# 103:	learn: 0.2423220	total: 1.46s	remaining: 11.7s
# 98:	learn: 0.2367412	total: 1.44s	remaining: 12.2s
# 101:	learn: 0.2431277	total: 1.47s	remaining: 12s
# 100:	learn: 0.2365349	total: 1.43s	remaining: 11.9s
# 103:	learn: 0.2344547	total: 1.47s	remaining: 11.8s
# 99:	learn: 0.2361695	total: 1.44s	remaining: 12.1s
# 104:	learn: 0.2340008	total: 1.47s	remaining: 11.7s
# 104:	learn: 0.2406973	total: 1.47s	remaining: 11.7s
# 101:	learn: 0.2358492	total: 1.44s	remaining: 11.8s
# 102:	learn: 0.2415248	total: 1.48s	remaining: 12s
# 105:	learn: 0.2329561	total: 1.48s	remaining: 11.7s
# 100:	learn: 0.2354851	total: 1.45s	remaining: 12.1s
# 105:	learn: 0.2397597	total: 1.48s	remaining: 11.7s
# 106:	learn: 0.2386945	total: 1.5s	remaining: 11.6s
# 103:	learn: 0.2403948	total: 1.5s	remaining: 12.1s
# 106:	learn: 0.2318269	total: 1.5s	remaining: 11.7s
# 101:	learn: 0.2336913	total: 1.48s	remaining: 12.1s
# 102:	learn: 0.2340671	total: 1.47s	remaining: 11.9s
# 107:	learn: 0.2379636	total: 1.5s	remaining: 11.6s
# 107:	learn: 0.2309719	total: 1.51s	remaining: 11.7s
# 104:	learn: 0.2394235	total: 1.51s	remaining: 12s
# 102:	learn: 0.2330812	total: 1.49s	remaining: 12.1s
# 103:	learn: 0.2326496	total: 1.48s	remaining: 11.9s
# 108:	learn: 0.2366191	total: 1.51s	remaining: 11.6s
# 108:	learn: 0.2298178	total: 1.52s	remaining: 11.6s
# 104:	learn: 0.2318793	total: 1.49s	remaining: 11.8s
# 105:	learn: 0.2375193	total: 1.53s	remaining: 12s
# 105:	learn: 0.2310384	total: 1.49s	remaining: 11.8s
# 109:	learn: 0.2357299	total: 1.53s	remaining: 11.5s
# 103:	learn: 0.2313788	total: 1.5s	remaining: 12.1s
# 109:	learn: 0.2287594	total: 1.53s	remaining: 11.6s
# 106:	learn: 0.2365693	total: 1.54s	remaining: 12s
# 110:	learn: 0.2343467	total: 1.54s	remaining: 11.5s
# 106:	learn: 0.2296702	total: 1.5s	remaining: 11.7s
# 110:	learn: 0.2272836	total: 1.55s	remaining: 11.5s
# 104:	learn: 0.2299068	total: 1.52s	remaining: 12.1s
# 107:	learn: 0.2287701	total: 1.51s	remaining: 11.7s
# 111:	learn: 0.2264090	total: 1.55s	remaining: 11.5s
# 111:	learn: 0.2327228	total: 1.55s	remaining: 11.5s
# 108:	learn: 0.2280507	total: 1.52s	remaining: 11.6s
# 107:	learn: 0.2351678	total: 1.56s	remaining: 12s
# 105:	learn: 0.2285201	total: 1.53s	remaining: 12.1s
# 112:	learn: 0.2254681	total: 1.56s	remaining: 11.5s
# 108:	learn: 0.2333497	total: 1.57s	remaining: 12s
# 112:	learn: 0.2314364	total: 1.57s	remaining: 11.5s
# 109:	learn: 0.2268543	total: 1.53s	remaining: 11.6s
# 106:	learn: 0.2269217	total: 1.55s	remaining: 12s
# 113:	learn: 0.2247292	total: 1.57s	remaining: 11.4s
# 113:	learn: 0.2310368	total: 1.57s	remaining: 11.4s
# 109:	learn: 0.2325595	total: 1.58s	remaining: 11.9s
# 110:	learn: 0.2321808	total: 1.58s	remaining: 11.8s
# 114:	learn: 0.2237507	total: 1.58s	remaining: 11.4s
# 110:	learn: 0.2253031	total: 1.55s	remaining: 11.6s
# 114:	learn: 0.2301924	total: 1.58s	remaining: 11.4s
# 107:	learn: 0.2250079	total: 1.56s	remaining: 12.1s
# 111:	learn: 0.2243558	total: 1.56s	remaining: 11.5s
# 111:	learn: 0.2306335	total: 1.6s	remaining: 11.8s
# 115:	learn: 0.2223481	total: 1.6s	remaining: 11.3s
# 115:	learn: 0.2292239	total: 1.6s	remaining: 11.3s
# 112:	learn: 0.2234652	total: 1.57s	remaining: 11.5s
# 112:	learn: 0.2296152	total: 1.61s	remaining: 11.8s
# 108:	learn: 0.2233684	total: 1.58s	remaining: 12s
# 116:	learn: 0.2212624	total: 1.61s	remaining: 11.3s
# 113:	learn: 0.2228895	total: 1.57s	remaining: 11.4s
# 116:	learn: 0.2282127	total: 1.61s	remaining: 11.3s
# 109:	learn: 0.2224429	total: 1.59s	remaining: 12s
# 113:	learn: 0.2283970	total: 1.62s	remaining: 11.7s
# 117:	learn: 0.2198151	total: 1.62s	remaining: 11.3s
# 114:	learn: 0.2207343	total: 1.59s	remaining: 11.4s
# 114:	learn: 0.2274201	total: 1.63s	remaining: 11.7s
# 110:	learn: 0.2214359	total: 1.6s	remaining: 12s
# 117:	learn: 0.2267821	total: 1.63s	remaining: 11.3s
# 115:	learn: 0.2267763	total: 1.64s	remaining: 11.6s
# 118:	learn: 0.2183941	total: 1.64s	remaining: 11.3s
# 115:	learn: 0.2195815	total: 1.6s	remaining: 11.4s
# 111:	learn: 0.2202278	total: 1.61s	remaining: 11.9s
# 116:	learn: 0.2250937	total: 1.65s	remaining: 11.6s
# 112:	learn: 0.2195595	total: 1.62s	remaining: 11.8s
# 118:	learn: 0.2256362	total: 1.64s	remaining: 11.3s
# 119:	learn: 0.2171761	total: 1.65s	remaining: 11.3s
# 116:	learn: 0.2179779	total: 1.61s	remaining: 11.3s
# 119:	learn: 0.2246098	total: 1.65s	remaining: 11.3s
# 117:	learn: 0.2237364	total: 1.66s	remaining: 11.6s
# 120:	learn: 0.2161634	total: 1.66s	remaining: 11.2s
# 113:	learn: 0.2185333	total: 1.63s	remaining: 11.8s
# 120:	learn: 0.2234722	total: 1.66s	remaining: 11.3s
# 117:	learn: 0.2166762	total: 1.63s	remaining: 11.4s
# 118:	learn: 0.2229766	total: 1.67s	remaining: 11.5s
# 121:	learn: 0.2148536	total: 1.67s	remaining: 11.2s
# 114:	learn: 0.2174876	total: 1.65s	remaining: 11.8s
# 118:	learn: 0.2160861	total: 1.64s	remaining: 11.3s
# 121:	learn: 0.2225128	total: 1.67s	remaining: 11.2s
# 119:	learn: 0.2213264	total: 1.68s	remaining: 11.5s
# 122:	learn: 0.2134568	total: 1.68s	remaining: 11.2s
# 115:	learn: 0.2160941	total: 1.66s	remaining: 11.8s
# 119:	learn: 0.2152461	total: 1.65s	remaining: 11.3s
# 120:	learn: 0.2206289	total: 1.69s	remaining: 11.5s
# 122:	learn: 0.2210191	total: 1.69s	remaining: 11.2s
# 120:	learn: 0.2147525	total: 1.66s	remaining: 11.3s
# 121:	learn: 0.2199078	total: 1.7s	remaining: 11.4s
# 116:	learn: 0.2150858	total: 1.67s	remaining: 11.8s
# 123:	learn: 0.2123176	total: 1.7s	remaining: 11.2s
# 123:	learn: 0.2203694	total: 1.7s	remaining: 11.2s
# 121:	learn: 0.2137967	total: 1.67s	remaining: 11.2s
# 117:	learn: 0.2134451	total: 1.68s	remaining: 11.7s
# 124:	learn: 0.2118398	total: 1.71s	remaining: 11.2s
# 124:	learn: 0.2192956	total: 1.71s	remaining: 11.2s
# 122:	learn: 0.2186511	total: 1.72s	remaining: 11.4s
# 118:	learn: 0.2128917	total: 1.69s	remaining: 11.7s
# 122:	learn: 0.2129803	total: 1.68s	remaining: 11.2s
# 125:	learn: 0.2108406	total: 1.72s	remaining: 11.1s
# 125:	learn: 0.2184258	total: 1.72s	remaining: 11.1s
# 123:	learn: 0.2176430	total: 1.73s	remaining: 11.4s
# 123:	learn: 0.2121218	total: 1.69s	remaining: 11.2s
# 119:	learn: 0.2115379	total: 1.71s	remaining: 11.7s
# 124:	learn: 0.2170262	total: 1.74s	remaining: 11.3s
# 126:	learn: 0.2174432	total: 1.73s	remaining: 11.1s
# 126:	learn: 0.2095296	total: 1.74s	remaining: 11.1s
# 124:	learn: 0.2110430	total: 1.71s	remaining: 11.1s
# 127:	learn: 0.2163480	total: 1.74s	remaining: 11s
# 125:	learn: 0.2164254	total: 1.75s	remaining: 11.3s
# 120:	learn: 0.2101248	total: 1.72s	remaining: 11.7s
# 127:	learn: 0.2085805	total: 1.75s	remaining: 11.1s
# 128:	learn: 0.2157780	total: 1.75s	remaining: 11s
# 126:	learn: 0.2155751	total: 1.76s	remaining: 11.3s
# 121:	learn: 0.2092541	total: 1.73s	remaining: 11.6s
# 125:	learn: 0.2098026	total: 1.72s	remaining: 11.1s
# 128:	learn: 0.2074114	total: 1.76s	remaining: 11.1s
# 126:	learn: 0.2094147	total: 1.73s	remaining: 11s
# 129:	learn: 0.2151131	total: 1.76s	remaining: 11s
# 127:	learn: 0.2147896	total: 1.77s	remaining: 11.2s
# 122:	learn: 0.2084372	total: 1.74s	remaining: 11.6s
# 129:	learn: 0.2066620	total: 1.77s	remaining: 11s
# 127:	learn: 0.2085699	total: 1.74s	remaining: 11s
# 128:	learn: 0.2142273	total: 1.77s	remaining: 11.2s
# 130:	learn: 0.2140678	total: 1.77s	remaining: 10.9s
# 123:	learn: 0.2075727	total: 1.75s	remaining: 11.5s
# 130:	learn: 0.2056406	total: 1.78s	remaining: 11s
# 128:	learn: 0.2071205	total: 1.75s	remaining: 11s
# 131:	learn: 0.2123977	total: 1.78s	remaining: 10.9s
# 129:	learn: 0.2127059	total: 1.79s	remaining: 11.2s
# 124:	learn: 0.2069344	total: 1.76s	remaining: 11.5s
# 129:	learn: 0.2064319	total: 1.76s	remaining: 10.9s
# 131:	learn: 0.2048173	total: 1.79s	remaining: 11s
# 130:	learn: 0.2121314	total: 1.8s	remaining: 11.1s
# 132:	learn: 0.2113350	total: 1.79s	remaining: 10.9s
# 125:	learn: 0.2057300	total: 1.77s	remaining: 11.5s
# 130:	learn: 0.2054189	total: 1.77s	remaining: 10.9s
# 131:	learn: 0.2108494	total: 1.81s	remaining: 11.1s
# 132:	learn: 0.2036560	total: 1.81s	remaining: 11s
# 126:	learn: 0.2043549	total: 1.79s	remaining: 11.4s
# 133:	learn: 0.2096544	total: 1.81s	remaining: 10.9s
# 131:	learn: 0.2041993	total: 1.78s	remaining: 10.9s
# 132:	learn: 0.2100870	total: 1.82s	remaining: 11s
# 133:	learn: 0.2025867	total: 1.82s	remaining: 11s
# 127:	learn: 0.2029699	total: 1.8s	remaining: 11.4s
# 132:	learn: 0.2031248	total: 1.79s	remaining: 10.9s
# 134:	learn: 0.2084470	total: 1.82s	remaining: 10.9s
# 133:	learn: 0.2092956	total: 1.83s	remaining: 11s
# 134:	learn: 0.2017890	total: 1.83s	remaining: 10.9s
# 128:	learn: 0.2022785	total: 1.81s	remaining: 11.4s
# 133:	learn: 0.2021933	total: 1.8s	remaining: 10.8s
# 135:	learn: 0.2014000	total: 1.84s	remaining: 10.9s
# 134:	learn: 0.2019235	total: 1.8s	remaining: 10.8s
# 134:	learn: 0.2083818	total: 1.84s	remaining: 11s
# 135:	learn: 0.2069019	total: 1.84s	remaining: 10.9s
# 129:	learn: 0.2012066	total: 1.82s	remaining: 11.3s
# 136:	learn: 0.2004600	total: 1.85s	remaining: 10.8s
# 135:	learn: 0.2013811	total: 1.81s	remaining: 10.7s
# 137:	learn: 0.1998908	total: 1.85s	remaining: 10.8s
# 135:	learn: 0.2073183	total: 1.86s	remaining: 11s
# 136:	learn: 0.2060319	total: 1.85s	remaining: 10.9s
# 130:	learn: 0.2001448	total: 1.83s	remaining: 11.3s
# 136:	learn: 0.2003307	total: 1.83s	remaining: 10.7s
# 137:	learn: 0.2051975	total: 1.86s	remaining: 10.8s
# 136:	learn: 0.2062850	total: 1.87s	remaining: 11s
# 131:	learn: 0.1994271	total: 1.84s	remaining: 11.3s
# 138:	learn: 0.1990348	total: 1.87s	remaining: 10.8s
# 137:	learn: 0.1991490	total: 1.84s	remaining: 10.7s
# 138:	learn: 0.2046088	total: 1.87s	remaining: 10.8s
# 137:	learn: 0.2058897	total: 1.88s	remaining: 10.9s
# 132:	learn: 0.1985412	total: 1.85s	remaining: 11.3s
# 139:	learn: 0.1983738	total: 1.88s	remaining: 10.8s
# 133:	learn: 0.1981209	total: 1.87s	remaining: 11.2s
# 138:	learn: 0.2050793	total: 1.9s	remaining: 10.9s
# 138:	learn: 0.1977691	total: 1.86s	remaining: 10.7s
# 139:	learn: 0.2033509	total: 1.89s	remaining: 10.8s
# 140:	learn: 0.1973921	total: 1.9s	remaining: 10.8s
# 139:	learn: 0.2045488	total: 1.91s	remaining: 10.9s
# 134:	learn: 0.1972034	total: 1.88s	remaining: 11.2s
# 141:	learn: 0.1966588	total: 1.91s	remaining: 10.7s
# 140:	learn: 0.2023787	total: 1.9s	remaining: 10.8s
# 139:	learn: 0.1965678	total: 1.87s	remaining: 10.7s
# 141:	learn: 0.2020188	total: 1.91s	remaining: 10.7s
# 142:	learn: 0.1955561	total: 1.92s	remaining: 10.7s
# 140:	learn: 0.2031648	total: 1.92s	remaining: 10.9s
# 140:	learn: 0.1957706	total: 1.88s	remaining: 10.7s
# 135:	learn: 0.1962513	total: 1.89s	remaining: 11.2s
# 142:	learn: 0.2013655	total: 1.92s	remaining: 10.7s
# 141:	learn: 0.2025726	total: 1.93s	remaining: 10.8s
# 143:	learn: 0.1946181	total: 1.93s	remaining: 10.7s
# 136:	learn: 0.1954296	total: 1.9s	remaining: 11.2s
# 141:	learn: 0.1950938	total: 1.9s	remaining: 10.6s
# 142:	learn: 0.2020118	total: 1.94s	remaining: 10.8s
# 143:	learn: 0.2006367	total: 1.93s	remaining: 10.7s
# 137:	learn: 0.1946634	total: 1.92s	remaining: 11.1s
# 142:	learn: 0.1937596	total: 1.91s	remaining: 10.6s
# 144:	learn: 0.1935008	total: 1.94s	remaining: 10.7s
# 143:	learn: 0.2010620	total: 1.95s	remaining: 10.8s
# 143:	learn: 0.1934196	total: 1.91s	remaining: 10.6s
# 144:	learn: 0.1994851	total: 1.95s	remaining: 10.7s
# 138:	learn: 0.1936806	total: 1.93s	remaining: 11.1s
# 145:	learn: 0.1922737	total: 1.96s	remaining: 10.6s
# 144:	learn: 0.2002015	total: 1.96s	remaining: 10.7s
# 139:	learn: 0.1930901	total: 1.93s	remaining: 11.1s
# 145:	learn: 0.1981655	total: 1.96s	remaining: 10.7s
# 145:	learn: 0.1997398	total: 1.97s	remaining: 10.7s
# 146:	learn: 0.1911760	total: 1.97s	remaining: 10.6s
# 140:	learn: 0.1924273	total: 1.94s	remaining: 11s
# 144:	learn: 0.1919035	total: 1.93s	remaining: 10.6s
# 146:	learn: 0.1994784	total: 1.97s	remaining: 10.6s
# 146:	learn: 0.1972950	total: 1.97s	remaining: 10.6s
# 141:	learn: 0.1915530	total: 1.95s	remaining: 11s
# 147:	learn: 0.1897111	total: 1.98s	remaining: 10.6s
# 147:	learn: 0.1985127	total: 1.99s	remaining: 10.6s
# 145:	learn: 0.1908509	total: 1.95s	remaining: 10.6s
# 147:	learn: 0.1968189	total: 1.98s	remaining: 10.6s
# 142:	learn: 0.1903847	total: 1.96s	remaining: 10.9s
# 148:	learn: 0.1890977	total: 1.99s	remaining: 10.6s
# 146:	learn: 0.1901958	total: 1.96s	remaining: 10.5s
# 148:	learn: 0.1976850	total: 2s	remaining: 10.6s
# 147:	learn: 0.1893986	total: 1.96s	remaining: 10.5s
# 148:	learn: 0.1955867	total: 2s	remaining: 10.6s
# 143:	learn: 0.1892033	total: 1.98s	remaining: 10.9s
# 149:	learn: 0.1882229	total: 2s	remaining: 10.6s
# 150:	learn: 0.1874823	total: 2.01s	remaining: 10.5s
# 149:	learn: 0.1964869	total: 2.01s	remaining: 10.6s
# 148:	learn: 0.1882488	total: 1.98s	remaining: 10.5s
# 144:	learn: 0.1882328	total: 1.99s	remaining: 10.9s
# 149:	learn: 0.1941595	total: 2.02s	remaining: 10.6s
# 149:	learn: 0.1872333	total: 1.99s	remaining: 10.5s
# 151:	learn: 0.1868966	total: 2.02s	remaining: 10.5s
# 150:	learn: 0.1951813	total: 2.03s	remaining: 10.6s
# 152:	learn: 0.1863541	total: 2.03s	remaining: 10.4s
# 145:	learn: 0.1876198	total: 2s	remaining: 10.9s
# 150:	learn: 0.1866340	total: 2s	remaining: 10.4s
# 150:	learn: 0.1932302	total: 2.03s	remaining: 10.6s
# 151:	learn: 0.1940428	total: 2.04s	remaining: 10.6s
# 151:	learn: 0.1863188	total: 2s	remaining: 10.4s
# 153:	learn: 0.1853749	total: 2.04s	remaining: 10.4s
# 146:	learn: 0.1866595	total: 2.02s	remaining: 10.9s
# 151:	learn: 0.1923282	total: 2.04s	remaining: 10.6s
# 154:	learn: 0.1841315	total: 2.05s	remaining: 10.4s
# 152:	learn: 0.1854194	total: 2.02s	remaining: 10.4s
# 152:	learn: 0.1930065	total: 2.06s	remaining: 10.6s
# 147:	learn: 0.1856127	total: 2.03s	remaining: 10.9s
# 152:	learn: 0.1915124	total: 2.06s	remaining: 10.6s
# 155:	learn: 0.1833353	total: 2.06s	remaining: 10.4s
# 153:	learn: 0.1922328	total: 2.07s	remaining: 10.6s
# 148:	learn: 0.1849227	total: 2.04s	remaining: 10.8s
# 153:	learn: 0.1910130	total: 2.07s	remaining: 10.6s
# 153:	learn: 0.1838993	total: 2.04s	remaining: 10.4s
# 149:	learn: 0.1844871	total: 2.05s	remaining: 10.8s
# 156:	learn: 0.1823382	total: 2.08s	remaining: 10.4s
# 154:	learn: 0.1915348	total: 2.08s	remaining: 10.6s
# 154:	learn: 0.1900022	total: 2.08s	remaining: 10.5s
# 157:	learn: 0.1817956	total: 2.09s	remaining: 10.3s
# 154:	learn: 0.1829798	total: 2.05s	remaining: 10.4s
# 150:	learn: 0.1834990	total: 2.07s	remaining: 10.8s
# 158:	learn: 0.1814311	total: 2.1s	remaining: 10.3s
# 155:	learn: 0.1905659	total: 2.1s	remaining: 10.6s
# 155:	learn: 0.1885827	total: 2.1s	remaining: 10.6s
# 151:	learn: 0.1823610	total: 2.08s	remaining: 10.8s
# 155:	learn: 0.1820390	total: 2.07s	remaining: 10.4s
# 159:	learn: 0.1807278	total: 2.11s	remaining: 10.3s
# 156:	learn: 0.1900402	total: 2.11s	remaining: 10.5s
# 156:	learn: 0.1878771	total: 2.11s	remaining: 10.5s
# 156:	learn: 0.1811836	total: 2.08s	remaining: 10.4s
# 152:	learn: 0.1818196	total: 2.09s	remaining: 10.8s
# 157:	learn: 0.1893771	total: 2.12s	remaining: 10.5s
# 160:	learn: 0.1795779	total: 2.12s	remaining: 10.3s
# 157:	learn: 0.1870688	total: 2.12s	remaining: 10.5s
# 158:	learn: 0.1889682	total: 2.13s	remaining: 10.5s
# 153:	learn: 0.1812092	total: 2.1s	remaining: 10.7s
# 157:	learn: 0.1799705	total: 2.1s	remaining: 10.4s
# 161:	learn: 0.1788673	total: 2.13s	remaining: 10.3s
# 158:	learn: 0.1864837	total: 2.13s	remaining: 10.5s
# 159:	learn: 0.1884217	total: 2.14s	remaining: 10.4s
# 159:	learn: 0.1862935	total: 2.14s	remaining: 10.4s
# 154:	learn: 0.1802642	total: 2.12s	remaining: 10.7s
# 162:	learn: 0.1781999	total: 2.14s	remaining: 10.2s
# 158:	learn: 0.1790754	total: 2.11s	remaining: 10.4s
# 160:	learn: 0.1877266	total: 2.15s	remaining: 10.4s
# 163:	learn: 0.1775584	total: 2.15s	remaining: 10.2s
# 160:	learn: 0.1852677	total: 2.15s	remaining: 10.4s
# 155:	learn: 0.1797229	total: 2.13s	remaining: 10.7s
# 159:	learn: 0.1779461	total: 2.12s	remaining: 10.3s
# 161:	learn: 0.1871423	total: 2.16s	remaining: 10.4s
# 160:	learn: 0.1773067	total: 2.13s	remaining: 10.3s
# 161:	learn: 0.1844883	total: 2.16s	remaining: 10.4s
# 164:	learn: 0.1767361	total: 2.17s	remaining: 10.2s
# 156:	learn: 0.1789016	total: 2.14s	remaining: 10.7s
# 162:	learn: 0.1862812	total: 2.17s	remaining: 10.4s
# 157:	learn: 0.1782220	total: 2.15s	remaining: 10.7s
# 163:	learn: 0.1857282	total: 2.18s	remaining: 10.3s
# 162:	learn: 0.1836937	total: 2.18s	remaining: 10.4s
# 161:	learn: 0.1762185	total: 2.15s	remaining: 10.3s
# 165:	learn: 0.1759019	total: 2.18s	remaining: 10.2s
# 158:	learn: 0.1773927	total: 2.17s	remaining: 10.6s
# 164:	learn: 0.1850437	total: 2.19s	remaining: 10.3s
# 163:	learn: 0.1830144	total: 2.19s	remaining: 10.4s
# 166:	learn: 0.1749483	total: 2.2s	remaining: 10.2s
# 162:	learn: 0.1754835	total: 2.16s	remaining: 10.3s
# 159:	learn: 0.1768009	total: 2.18s	remaining: 10.6s
# 167:	learn: 0.1746548	total: 2.2s	remaining: 10.1s
# 164:	learn: 0.1824256	total: 2.2s	remaining: 10.3s
# 165:	learn: 0.1842152	total: 2.21s	remaining: 10.3s
# 163:	learn: 0.1742563	total: 2.18s	remaining: 10.3s
# 165:	learn: 0.1817400	total: 2.21s	remaining: 10.3s
# 168:	learn: 0.1738298	total: 2.21s	remaining: 10.1s
# 160:	learn: 0.1759049	total: 2.19s	remaining: 10.6s
# 166:	learn: 0.1835673	total: 2.22s	remaining: 10.3s
# 169:	learn: 0.1731432	total: 2.22s	remaining: 10.1s
# 161:	learn: 0.1754475	total: 2.2s	remaining: 10.6s
# 166:	learn: 0.1806749	total: 2.22s	remaining: 10.3s
# 164:	learn: 0.1729931	total: 2.19s	remaining: 10.3s
# 170:	learn: 0.1726274	total: 2.23s	remaining: 10s
# 162:	learn: 0.1752296	total: 2.2s	remaining: 10.5s
# 167:	learn: 0.1825217	total: 2.24s	remaining: 10.3s
# 167:	learn: 0.1801765	total: 2.23s	remaining: 10.3s
# 165:	learn: 0.1724208	total: 2.2s	remaining: 10.3s
# 171:	learn: 0.1720560	total: 2.24s	remaining: 10s
# 168:	learn: 0.1817874	total: 2.25s	remaining: 10.2s
# 163:	learn: 0.1735889	total: 2.22s	remaining: 10.5s
# 168:	learn: 0.1795573	total: 2.24s	remaining: 10.2s
# 166:	learn: 0.1712905	total: 2.21s	remaining: 10.2s
# 172:	learn: 0.1712554	total: 2.25s	remaining: 10s
# 169:	learn: 0.1787829	total: 2.25s	remaining: 10.2s
# 167:	learn: 0.1707574	total: 2.22s	remaining: 10.2s
# 169:	learn: 0.1805097	total: 2.26s	remaining: 10.3s
# 164:	learn: 0.1727761	total: 2.23s	remaining: 10.5s
# 173:	learn: 0.1703370	total: 2.27s	remaining: 9.98s
# 170:	learn: 0.1801262	total: 2.27s	remaining: 10.2s
# 170:	learn: 0.1775574	total: 2.27s	remaining: 10.2s
# 168:	learn: 0.1698852	total: 2.24s	remaining: 10.2s
# 165:	learn: 0.1716849	total: 2.25s	remaining: 10.5s
# 171:	learn: 0.1794802	total: 2.28s	remaining: 10.2s
# 169:	learn: 0.1692846	total: 2.25s	remaining: 10.2s
# 174:	learn: 0.1689885	total: 2.28s	remaining: 9.99s
# 171:	learn: 0.1769891	total: 2.28s	remaining: 10.2s
# 170:	learn: 0.1686415	total: 2.26s	remaining: 10.1s
# 175:	learn: 0.1686295	total: 2.29s	remaining: 9.96s
# 166:	learn: 0.1705363	total: 2.27s	remaining: 10.5s
# 171:	learn: 0.1683031	total: 2.26s	remaining: 10.1s
# 172:	learn: 0.1781393	total: 2.3s	remaining: 10.2s
# 176:	learn: 0.1681666	total: 2.3s	remaining: 9.93s
# 172:	learn: 0.1756731	total: 2.3s	remaining: 10.2s
# 177:	learn: 0.1677332	total: 2.31s	remaining: 9.89s
# 172:	learn: 0.1675534	total: 2.28s	remaining: 10.1s
# 167:	learn: 0.1696968	total: 2.29s	remaining: 10.5s
# 173:	learn: 0.1772913	total: 2.32s	remaining: 10.2s
# 173:	learn: 0.1746488	total: 2.32s	remaining: 10.2s
# 173:	learn: 0.1669491	total: 2.29s	remaining: 10.1s
# 174:	learn: 0.1770648	total: 2.32s	remaining: 10.2s
# 178:	learn: 0.1670315	total: 2.32s	remaining: 9.88s
# 174:	learn: 0.1743060	total: 2.32s	remaining: 10.2s
# 168:	learn: 0.1689161	total: 2.3s	remaining: 10.5s
# 174:	learn: 0.1661571	total: 2.3s	remaining: 10s
# 175:	learn: 0.1763771	total: 2.34s	remaining: 10.1s
# 179:	learn: 0.1662589	total: 2.33s	remaining: 9.86s
# 175:	learn: 0.1734750	total: 2.33s	remaining: 10.1s
# 169:	learn: 0.1679255	total: 2.31s	remaining: 10.5s
# 180:	learn: 0.1656492	total: 2.34s	remaining: 9.83s
# 176:	learn: 0.1757253	total: 2.35s	remaining: 10.1s
# 176:	learn: 0.1727220	total: 2.34s	remaining: 10.1s
# 175:	learn: 0.1653127	total: 2.32s	remaining: 10.1s
# 170:	learn: 0.1671523	total: 2.33s	remaining: 10.5s
# 177:	learn: 0.1722306	total: 2.35s	remaining: 10.1s
# 177:	learn: 0.1749308	total: 2.36s	remaining: 10.1s
# 176:	learn: 0.1645390	total: 2.32s	remaining: 10s
# 181:	learn: 0.1642913	total: 2.36s	remaining: 9.83s
# 171:	learn: 0.1663263	total: 2.34s	remaining: 10.4s
# 177:	learn: 0.1638817	total: 2.33s	remaining: 9.99s
# 178:	learn: 0.1740748	total: 2.37s	remaining: 10.1s
# 182:	learn: 0.1636115	total: 2.37s	remaining: 9.81s
# 178:	learn: 0.1709276	total: 2.37s	remaining: 10.1s
# 172:	learn: 0.1657970	total: 2.35s	remaining: 10.4s
# 178:	learn: 0.1633676	total: 2.34s	remaining: 9.96s
# 179:	learn: 0.1734290	total: 2.38s	remaining: 10.1s
# 183:	learn: 0.1624109	total: 2.38s	remaining: 9.8s
# 179:	learn: 0.1628919	total: 2.35s	remaining: 9.93s
# 179:	learn: 0.1702337	total: 2.38s	remaining: 10.1s
# 173:	learn: 0.1650027	total: 2.36s	remaining: 10.4s
# 180:	learn: 0.1729614	total: 2.39s	remaining: 10s
# 180:	learn: 0.1622878	total: 2.36s	remaining: 9.89s
# 184:	learn: 0.1615530	total: 2.4s	remaining: 9.78s
# 180:	learn: 0.1690755	total: 2.4s	remaining: 10s
# 174:	learn: 0.1640965	total: 2.37s	remaining: 10.4s
# 181:	learn: 0.1721186	total: 2.4s	remaining: 10s
# 181:	learn: 0.1615903	total: 2.37s	remaining: 9.86s
# 185:	learn: 0.1610256	total: 2.4s	remaining: 9.74s
# 181:	learn: 0.1684400	total: 2.4s	remaining: 10s
# 175:	learn: 0.1638042	total: 2.38s	remaining: 10.3s
# 176:	learn: 0.1635662	total: 2.39s	remaining: 10.3s
# 182:	learn: 0.1609652	total: 2.38s	remaining: 9.85s
# 186:	learn: 0.1601117	total: 2.42s	remaining: 9.73s
# 182:	learn: 0.1712263	total: 2.42s	remaining: 10s
# 182:	learn: 0.1679223	total: 2.42s	remaining: 9.99s
# 183:	learn: 0.1605111	total: 2.39s	remaining: 9.81s
# 177:	learn: 0.1629009	total: 2.4s	remaining: 10.3s
# 187:	learn: 0.1596511	total: 2.42s	remaining: 9.7s
# 183:	learn: 0.1702942	total: 2.43s	remaining: 9.99s
# 183:	learn: 0.1672402	total: 2.43s	remaining: 9.98s
# 178:	learn: 0.1623909	total: 2.41s	remaining: 10.2s
# 184:	learn: 0.1594835	total: 2.4s	remaining: 9.81s
# 188:	learn: 0.1587840	total: 2.44s	remaining: 9.7s
# 184:	learn: 0.1666792	total: 2.44s	remaining: 9.95s
# 184:	learn: 0.1694852	total: 2.44s	remaining: 9.98s
# 179:	learn: 0.1616937	total: 2.42s	remaining: 10.2s
# 185:	learn: 0.1690787	total: 2.45s	remaining: 9.94s
# 189:	learn: 0.1580682	total: 2.45s	remaining: 9.68s
# 185:	learn: 0.1586462	total: 2.42s	remaining: 9.8s
# 185:	learn: 0.1658749	total: 2.45s	remaining: 9.94s
# 180:	learn: 0.1612958	total: 2.43s	remaining: 10.2s
# 186:	learn: 0.1582041	total: 2.42s	remaining: 9.77s
# 186:	learn: 0.1684815	total: 2.46s	remaining: 9.92s
# 186:	learn: 0.1651982	total: 2.46s	remaining: 9.91s
# 190:	learn: 0.1570725	total: 2.47s	remaining: 9.67s
# 187:	learn: 0.1576784	total: 2.43s	remaining: 9.73s
# 187:	learn: 0.1679974	total: 2.47s	remaining: 9.89s
# 187:	learn: 0.1646341	total: 2.47s	remaining: 9.88s
# 181:	learn: 0.1602328	total: 2.45s	remaining: 10.2s
# 191:	learn: 0.1563016	total: 2.48s	remaining: 9.65s
# 188:	learn: 0.1569866	total: 2.44s	remaining: 9.71s
# ...
# 333:	learn: 0.1148707	total: 9.99s	remaining: 9.09s
# 334:	learn: 0.1145168	total: 10s	remaining: 9.05s
# 335:	learn: 0.1141524	total: 10s	remaining: 9.01s
# 336:	learn: 0.1137951	total: 10s	remaining: 8.97s
# 337:	learn: 0.1136418	total: 10.1s	remaining: 8.94s
# 338:	learn: 0.1131987	total: 10.1s	remaining: 8.9s
# 339:	learn: 0.1126603	total: 10.1s	remaining: 8.86s
# 340:	learn: 0.1123372	total: 10.1s	remaining: 8.83s
# 341:	learn: 0.1118557	total: 10.2s	remaining: 8.82s
# 342:	learn: 0.1115693	total: 10.2s	remaining: 8.79s
# 343:	learn: 0.1112253	total: 10.3s	remaining: 8.77s
# 344:	learn: 0.1109043	total: 10.3s	remaining: 8.74s
# 345:	learn: 0.1105748	total: 10.3s	remaining: 8.71s
# 346:	learn: 0.1100600	total: 10.4s	remaining: 8.68s
# 347:	learn: 0.1095312	total: 10.4s	remaining: 8.65s
# 348:	learn: 0.1091172	total: 10.4s	remaining: 8.62s
# 349:	learn: 0.1086592	total: 10.5s	remaining: 8.6s
# 350:	learn: 0.1083359	total: 10.5s	remaining: 8.57s
# 351:	learn: 0.1079992	total: 10.5s	remaining: 8.54s
# 352:	learn: 0.1076110	total: 10.5s	remaining: 8.5s
# 353:	learn: 0.1071168	total: 10.6s	remaining: 8.47s
# 354:	learn: 0.1067146	total: 10.6s	remaining: 8.43s
# 355:	learn: 0.1064257	total: 10.6s	remaining: 8.39s
# 356:	learn: 0.1063310	total: 10.6s	remaining: 8.36s
# 357:	learn: 0.1059926	total: 10.6s	remaining: 8.32s
# 358:	learn: 0.1059241	total: 10.7s	remaining: 8.31s
# 359:	learn: 0.1058694	total: 10.7s	remaining: 8.28s
# 360:	learn: 0.1057919	total: 10.7s	remaining: 8.24s
# 361:	learn: 0.1053928	total: 10.8s	remaining: 8.21s
# 362:	learn: 0.1051563	total: 10.8s	remaining: 8.17s
# 363:	learn: 0.1048442	total: 10.8s	remaining: 8.14s
# 364:	learn: 0.1044804	total: 10.8s	remaining: 8.1s
# 365:	learn: 0.1041406	total: 10.9s	remaining: 8.07s
# 366:	learn: 0.1038798	total: 10.9s	remaining: 8.03s
# 367:	learn: 0.1035972	total: 10.9s	remaining: 8s
# 368:	learn: 0.1033308	total: 10.9s	remaining: 7.96s
# 369:	learn: 0.1028737	total: 10.9s	remaining: 7.93s
# 370:	learn: 0.1028277	total: 11s	remaining: 7.89s
# 371:	learn: 0.1023816	total: 11s	remaining: 7.86s
# 372:	learn: 0.1019515	total: 11s	remaining: 7.82s
# 373:	learn: 0.1018897	total: 11s	remaining: 7.79s
# 374:	learn: 0.1015337	total: 11.1s	remaining: 7.75s
# 375:	learn: 0.1014820	total: 11.1s	remaining: 7.72s
# 376:	learn: 0.1010856	total: 11.1s	remaining: 7.68s
# 377:	learn: 0.1010308	total: 11.1s	remaining: 7.64s
# 378:	learn: 0.1008014	total: 11.1s	remaining: 7.61s
# 379:	learn: 0.1005111	total: 11.2s	remaining: 7.63s
# 380:	learn: 0.1001987	total: 11.3s	remaining: 7.6s
# 381:	learn: 0.0997394	total: 11.3s	remaining: 7.58s
# 382:	learn: 0.0996722	total: 11.3s	remaining: 7.54s
# 383:	learn: 0.0992212	total: 11.4s	remaining: 7.51s
# 384:	learn: 0.0991898	total: 11.4s	remaining: 7.49s
# 385:	learn: 0.0989170	total: 11.4s	remaining: 7.46s
# 386:	learn: 0.0988713	total: 11.5s	remaining: 7.44s
# 387:	learn: 0.0988318	total: 11.6s	remaining: 7.44s
# 388:	learn: 0.0984626	total: 11.6s	remaining: 7.41s
# 389:	learn: 0.0982070	total: 11.6s	remaining: 7.38s
# 390:	learn: 0.0978739	total: 11.6s	remaining: 7.35s
# 391:	learn: 0.0978289	total: 11.7s	remaining: 7.36s
# 392:	learn: 0.0974668	total: 11.8s	remaining: 7.33s
# 393:	learn: 0.0973753	total: 11.8s	remaining: 7.3s
# 394:	learn: 0.0972864	total: 11.8s	remaining: 7.27s
# 395:	learn: 0.0972151	total: 11.9s	remaining: 7.25s
# 396:	learn: 0.0969193	total: 11.9s	remaining: 7.23s
# 397:	learn: 0.0968694	total: 11.9s	remaining: 7.2s
# 398:	learn: 0.0968213	total: 12s	remaining: 7.17s
# 399:	learn: 0.0967157	total: 12s	remaining: 7.13s
# 400:	learn: 0.0962800	total: 12s	remaining: 7.11s
# 401:	learn: 0.0962335	total: 12.1s	remaining: 7.1s
# 402:	learn: 0.0959457	total: 12.1s	remaining: 7.07s
# 403:	learn: 0.0958835	total: 12.1s	remaining: 7.04s
# 404:	learn: 0.0956293	total: 12.2s	remaining: 7s
# 405:	learn: 0.0954719	total: 12.3s	remaining: 7.02s
# 406:	learn: 0.0952153	total: 12.4s	remaining: 7.01s
# 407:	learn: 0.0951489	total: 12.4s	remaining: 6.98s
# 408:	learn: 0.0947355	total: 12.4s	remaining: 6.97s
# 409:	learn: 0.0946793	total: 12.5s	remaining: 6.94s
# 410:	learn: 0.0946202	total: 12.5s	remaining: 6.91s
# 411:	learn: 0.0945035	total: 12.5s	remaining: 6.87s
# 412:	learn: 0.0942768	total: 12.5s	remaining: 6.83s
# 413:	learn: 0.0941168	total: 12.6s	remaining: 6.8s
# 414:	learn: 0.0940502	total: 12.6s	remaining: 6.76s
# 415:	learn: 0.0939915	total: 12.6s	remaining: 6.75s
# 416:	learn: 0.0936829	total: 12.7s	remaining: 6.72s
# 417:	learn: 0.0933770	total: 12.7s	remaining: 6.68s
# 418:	learn: 0.0933076	total: 12.7s	remaining: 6.65s
# 419:	learn: 0.0930752	total: 12.7s	remaining: 6.61s
# 420:	learn: 0.0927232	total: 12.8s	remaining: 6.58s
# 421:	learn: 0.0924522	total: 12.8s	remaining: 6.54s
# 422:	learn: 0.0923902	total: 12.8s	remaining: 6.51s
# 423:	learn: 0.0923364	total: 12.8s	remaining: 6.48s
# 424:	learn: 0.0921145	total: 12.9s	remaining: 6.46s
# 425:	learn: 0.0918297	total: 12.9s	remaining: 6.43s
# 426:	learn: 0.0917978	total: 12.9s	remaining: 6.39s
# 427:	learn: 0.0915742	total: 13s	remaining: 6.36s
# 428:	learn: 0.0912939	total: 13s	remaining: 6.32s
# 429:	learn: 0.0909527	total: 13s	remaining: 6.29s
# 430:	learn: 0.0909010	total: 13.1s	remaining: 6.28s
# 431:	learn: 0.0905726	total: 13.1s	remaining: 6.24s
# 432:	learn: 0.0901979	total: 13.1s	remaining: 6.21s
# 433:	learn: 0.0901273	total: 13.1s	remaining: 6.17s
# 434:	learn: 0.0899453	total: 13.2s	remaining: 6.14s
# 435:	learn: 0.0896054	total: 13.2s	remaining: 6.1s
# 436:	learn: 0.0895098	total: 13.2s	remaining: 6.07s
# 437:	learn: 0.0892335	total: 13.2s	remaining: 6.04s
# 438:	learn: 0.0891780	total: 13.3s	remaining: 6.02s
# 439:	learn: 0.0891155	total: 13.3s	remaining: 5.99s
# 440:	learn: 0.0888334	total: 13.3s	remaining: 5.95s
# 441:	learn: 0.0887809	total: 13.3s	remaining: 5.92s
# 442:	learn: 0.0886569	total: 13.4s	remaining: 5.88s
# 443:	learn: 0.0883412	total: 13.4s	remaining: 5.85s
# 444:	learn: 0.0880875	total: 13.4s	remaining: 5.81s
# 445:	learn: 0.0879094	total: 13.6s	remaining: 5.84s
# 446:	learn: 0.0877877	total: 13.6s	remaining: 5.82s
# 447:	learn: 0.0877334	total: 13.6s	remaining: 5.78s
# 448:	learn: 0.0876765	total: 13.7s	remaining: 5.75s
# 449:	learn: 0.0875355	total: 13.7s	remaining: 5.71s
# 450:	learn: 0.0873852	total: 13.7s	remaining: 5.7s
# 451:	learn: 0.0871192	total: 13.8s	remaining: 5.66s
# 452:	learn: 0.0870840	total: 13.8s	remaining: 5.63s
# 453:	learn: 0.0868983	total: 13.8s	remaining: 5.59s
# 454:	learn: 0.0865966	total: 13.8s	remaining: 5.56s
# 455:	learn: 0.0864160	total: 13.8s	remaining: 5.53s
# 456:	learn: 0.0862396	total: 13.9s	remaining: 5.51s
# 457:	learn: 0.0861086	total: 13.9s	remaining: 5.47s
# 458:	learn: 0.0860385	total: 13.9s	remaining: 5.44s
# 459:	learn: 0.0858964	total: 14s	remaining: 5.4s
# 460:	learn: 0.0858378	total: 14s	remaining: 5.37s
# 461:	learn: 0.0856891	total: 14s	remaining: 5.33s
# 462:	learn: 0.0855386	total: 14s	remaining: 5.3s
# 463:	learn: 0.0851904	total: 14s	remaining: 5.27s
# 464:	learn: 0.0851390	total: 14.1s	remaining: 5.25s
# 465:	learn: 0.0850163	total: 14.1s	remaining: 5.22s
# 466:	learn: 0.0849610	total: 14.2s	remaining: 5.18s
# 467:	learn: 0.0845925	total: 14.2s	remaining: 5.15s
# 468:	learn: 0.0845404	total: 14.2s	remaining: 5.11s
# 469:	learn: 0.0843023	total: 14.2s	remaining: 5.08s
# 470:	learn: 0.0842479	total: 14.2s	remaining: 5.05s
# 471:	learn: 0.0841746	total: 14.3s	remaining: 5.01s
# 472:	learn: 0.0838843	total: 14.3s	remaining: 4.99s
# 473:	learn: 0.0838248	total: 14.3s	remaining: 4.96s
# 474:	learn: 0.0835794	total: 14.3s	remaining: 4.92s
# 475:	learn: 0.0832868	total: 14.4s	remaining: 4.89s
# 476:	learn: 0.0832284	total: 14.4s	remaining: 4.86s
# 477:	learn: 0.0831855	total: 14.4s	remaining: 4.82s
# 478:	learn: 0.0831368	total: 14.5s	remaining: 4.82s
# 479:	learn: 0.0830426	total: 14.6s	remaining: 4.8s
# 480:	learn: 0.0829213	total: 14.6s	remaining: 4.77s
# 481:	learn: 0.0828712	total: 14.7s	remaining: 4.75s
# 482:	learn: 0.0826279	total: 14.7s	remaining: 4.72s
# 483:	learn: 0.0825850	total: 14.7s	remaining: 4.69s
# 484:	learn: 0.0823728	total: 14.8s	remaining: 4.65s
# 485:	learn: 0.0823278	total: 14.8s	remaining: 4.62s
# 486:	learn: 0.0821232	total: 14.8s	remaining: 4.59s
# 487:	learn: 0.0820087	total: 14.8s	remaining: 4.55s
# 488:	learn: 0.0817945	total: 14.8s	remaining: 4.52s
# 489:	learn: 0.0817399	total: 14.9s	remaining: 4.49s
# 490:	learn: 0.0815726	total: 14.9s	remaining: 4.45s
# 491:	learn: 0.0813247	total: 14.9s	remaining: 4.42s
# 492:	learn: 0.0812748	total: 15s	remaining: 4.4s
# 493:	learn: 0.0810607	total: 15s	remaining: 4.37s
# 494:	learn: 0.0808982	total: 15s	remaining: 4.33s
# 495:	learn: 0.0805998	total: 15s	remaining: 4.3s
# 496:	learn: 0.0805645	total: 15s	remaining: 4.27s
# 497:	learn: 0.0804772	total: 15.1s	remaining: 4.23s
# 498:	learn: 0.0802503	total: 15.1s	remaining: 4.2s
# 499:	learn: 0.0802042	total: 15.1s	remaining: 4.17s
# 500:	learn: 0.0799065	total: 15.2s	remaining: 4.15s
# 501:	learn: 0.0795590	total: 15.2s	remaining: 4.11s
# 502:	learn: 0.0794139	total: 15.2s	remaining: 4.08s
# 503:	learn: 0.0792090	total: 15.2s	remaining: 4.05s
# 504:	learn: 0.0790731	total: 15.2s	remaining: 4.01s
# 505:	learn: 0.0787606	total: 15.3s	remaining: 3.98s
# 506:	learn: 0.0785788	total: 15.3s	remaining: 3.95s
# 507:	learn: 0.0785296	total: 15.3s	remaining: 3.92s
# 508:	learn: 0.0783432	total: 15.4s	remaining: 3.9s
# 509:	learn: 0.0781150	total: 15.4s	remaining: 3.86s
# 510:	learn: 0.0779046	total: 15.4s	remaining: 3.83s
# 511:	learn: 0.0778648	total: 15.4s	remaining: 3.8s
# 512:	learn: 0.0778185	total: 15.5s	remaining: 3.77s
# 513:	learn: 0.0775865	total: 15.5s	remaining: 3.73s
# 514:	learn: 0.0775361	total: 15.5s	remaining: 3.7s
# 515:	learn: 0.0775017	total: 15.5s	remaining: 3.67s
# 516:	learn: 0.0773430	total: 15.7s	remaining: 3.67s
# 517:	learn: 0.0771255	total: 15.7s	remaining: 3.64s
# 518:	learn: 0.0770786	total: 15.7s	remaining: 3.61s
# 519:	learn: 0.0770356	total: 15.8s	remaining: 3.58s
# 520:	learn: 0.0769913	total: 15.8s	remaining: 3.54s
# 521:	learn: 0.0768576	total: 15.8s	remaining: 3.51s
# 522:	learn: 0.0766152	total: 15.8s	remaining: 3.48s
# 523:	learn: 0.0765867	total: 15.8s	remaining: 3.45s
# 524:	learn: 0.0765455	total: 15.9s	remaining: 3.42s
# 525:	learn: 0.0765010	total: 15.9s	remaining: 3.38s
# 526:	learn: 0.0762931	total: 15.9s	remaining: 3.35s
# 527:	learn: 0.0762509	total: 15.9s	remaining: 3.32s
# 528:	learn: 0.0762150	total: 16s	remaining: 3.29s
# 529:	learn: 0.0760088	total: 16s	remaining: 3.26s
# 530:	learn: 0.0759176	total: 16s	remaining: 3.23s
# 531:	learn: 0.0757817	total: 16s	remaining: 3.2s
# 532:	learn: 0.0757363	total: 16.1s	remaining: 3.16s
# 533:	learn: 0.0756901	total: 16.1s	remaining: 3.13s
# 534:	learn: 0.0756556	total: 16.1s	remaining: 3.1s
# 535:	learn: 0.0754460	total: 16.1s	remaining: 3.07s
# 536:	learn: 0.0752823	total: 16.1s	remaining: 3.04s
# 537:	learn: 0.0751590	total: 16.2s	remaining: 3.01s
# 538:	learn: 0.0750782	total: 16.2s	remaining: 2.98s
# 539:	learn: 0.0750147	total: 16.2s	remaining: 2.95s
# 540:	learn: 0.0747175	total: 16.3s	remaining: 2.92s
# 541:	learn: 0.0745229	total: 16.3s	remaining: 2.88s
# 542:	learn: 0.0744816	total: 16.3s	remaining: 2.85s
# 543:	learn: 0.0742729	total: 16.3s	remaining: 2.82s
# 544:	learn: 0.0740969	total: 16.4s	remaining: 2.79s
# 545:	learn: 0.0740557	total: 16.4s	remaining: 2.77s
# 546:	learn: 0.0738393	total: 16.4s	remaining: 2.73s
# 547:	learn: 0.0736277	total: 16.5s	remaining: 2.7s
# 548:	learn: 0.0735878	total: 16.5s	remaining: 2.67s
# 549:	learn: 0.0735117	total: 16.5s	remaining: 2.64s
# 550:	learn: 0.0734812	total: 16.5s	remaining: 2.61s
# 551:	learn: 0.0733291	total: 16.6s	remaining: 2.58s
# 552:	learn: 0.0731383	total: 16.7s	remaining: 2.57s
# 553:	learn: 0.0729826	total: 16.7s	remaining: 2.54s
# 554:	learn: 0.0729444	total: 16.8s	remaining: 2.51s
# 555:	learn: 0.0728499	total: 16.8s	remaining: 2.48s
# 556:	learn: 0.0726733	total: 16.8s	remaining: 2.45s
# 557:	learn: 0.0724581	total: 16.9s	remaining: 2.42s
# 558:	learn: 0.0723202	total: 16.9s	remaining: 2.39s
# 559:	learn: 0.0721918	total: 16.9s	remaining: 2.35s
# 560:	learn: 0.0721101	total: 16.9s	remaining: 2.32s
# 561:	learn: 0.0720723	total: 17s	remaining: 2.29s
# 562:	learn: 0.0718703	total: 17s	remaining: 2.26s
# 563:	learn: 0.0717823	total: 17s	remaining: 2.23s
# 564:	learn: 0.0717447	total: 17.1s	remaining: 2.21s
# 565:	learn: 0.0715567	total: 17.1s	remaining: 2.17s
# 566:	learn: 0.0715175	total: 17.1s	remaining: 2.14s
# 567:	learn: 0.0713431	total: 17.1s	remaining: 2.11s
# 568:	learn: 0.0711939	total: 17.1s	remaining: 2.08s
# 569:	learn: 0.0710296	total: 17.2s	remaining: 2.05s
# 570:	learn: 0.0709904	total: 17.2s	remaining: 2.02s
# 571:	learn: 0.0708221	total: 17.3s	remaining: 1.99s
# 572:	learn: 0.0707847	total: 17.3s	remaining: 1.96s
# 573:	learn: 0.0707238	total: 17.3s	remaining: 1.93s
# 574:	learn: 0.0706926	total: 17.3s	remaining: 1.9s
# 575:	learn: 0.0704873	total: 17.3s	remaining: 1.87s
# 576:	learn: 0.0704106	total: 17.4s	remaining: 1.83s
# 577:	learn: 0.0701797	total: 17.4s	remaining: 1.8s
# 578:	learn: 0.0699819	total: 17.4s	remaining: 1.78s
# 579:	learn: 0.0699504	total: 17.5s	remaining: 1.75s
# 580:	learn: 0.0698693	total: 17.5s	remaining: 1.72s
# 581:	learn: 0.0697221	total: 17.5s	remaining: 1.68s
# 582:	learn: 0.0696905	total: 17.5s	remaining: 1.65s
# 583:	learn: 0.0695891	total: 17.5s	remaining: 1.62s
# 584:	learn: 0.0694864	total: 17.6s	remaining: 1.59s
# 585:	learn: 0.0694362	total: 17.6s	remaining: 1.56s
# 586:	learn: 0.0693805	total: 17.6s	remaining: 1.53s
# 587:	learn: 0.0692342	total: 17.7s	remaining: 1.51s
# 588:	learn: 0.0690348	total: 17.8s	remaining: 1.48s
# 589:	learn: 0.0688533	total: 17.8s	remaining: 1.45s
# 590:	learn: 0.0687221	total: 17.9s	remaining: 1.42s
# 591:	learn: 0.0686956	total: 17.9s	remaining: 1.39s
# 592:	learn: 0.0684672	total: 17.9s	remaining: 1.36s
# 593:	learn: 0.0682805	total: 18s	remaining: 1.33s
# 594:	learn: 0.0680537	total: 18s	remaining: 1.3s
# 595:	learn: 0.0680310	total: 18s	remaining: 1.27s
# 596:	learn: 0.0678856	total: 18s	remaining: 1.24s
# 597:	learn: 0.0677292	total: 18s	remaining: 1.21s
# 598:	learn: 0.0676991	total: 18.1s	remaining: 1.18s
# 599:	learn: 0.0676633	total: 18.1s	remaining: 1.15s
# 600:	learn: 0.0675653	total: 18.1s	remaining: 1.11s
# 601:	learn: 0.0674475	total: 18.1s	remaining: 1.08s
# 602:	learn: 0.0674144	total: 18.2s	remaining: 1.05s
# 603:	learn: 0.0672728	total: 18.2s	remaining: 1.02s
# 604:	learn: 0.0671089	total: 18.2s	remaining: 993ms
# 605:	learn: 0.0670770	total: 18.2s	remaining: 963ms
# 606:	learn: 0.0669435	total: 18.3s	remaining: 933ms
# 607:	learn: 0.0667558	total: 18.3s	remaining: 903ms
# 608:	learn: 0.0667166	total: 18.3s	remaining: 872ms
# 609:	learn: 0.0666803	total: 18.3s	remaining: 842ms
# 610:	learn: 0.0665262	total: 18.4s	remaining: 811ms
# 611:	learn: 0.0663637	total: 18.4s	remaining: 781ms
# 612:	learn: 0.0663372	total: 18.4s	remaining: 750ms
# 613:	learn: 0.0663022	total: 18.4s	remaining: 721ms
# 614:	learn: 0.0662469	total: 18.5s	remaining: 691ms
# 615:	learn: 0.0662188	total: 18.5s	remaining: 661ms
# 616:	learn: 0.0660873	total: 18.5s	remaining: 631ms
# 617:	learn: 0.0659488	total: 18.5s	remaining: 600ms
# 618:	learn: 0.0658425	total: 18.6s	remaining: 570ms
# 619:	learn: 0.0657252	total: 18.6s	remaining: 540ms
# 620:	learn: 0.0656837	total: 18.6s	remaining: 509ms
# 621:	learn: 0.0656505	total: 18.6s	remaining: 479ms
# 622:	learn: 0.0655297	total: 18.7s	remaining: 450ms
# 623:	learn: 0.0653939	total: 18.8s	remaining: 421ms
# 624:	learn: 0.0653632	total: 18.8s	remaining: 391ms
# 625:	learn: 0.0651431	total: 18.8s	remaining: 361ms
# 626:	learn: 0.0651128	total: 18.9s	remaining: 332ms
# 627:	learn: 0.0649672	total: 18.9s	remaining: 302ms
# 628:	learn: 0.0647820	total: 19s	remaining: 271ms
# 629:	learn: 0.0646511	total: 19s	remaining: 241ms
# 630:	learn: 0.0644976	total: 19s	remaining: 211ms
# 631:	learn: 0.0643602	total: 19s	remaining: 181ms
# 632:	learn: 0.0641460	total: 19.1s	remaining: 151ms
# 633:	learn: 0.0639821	total: 19.1s	remaining: 121ms
# 634:	learn: 0.0639547	total: 19.1s	remaining: 90.4ms
# 635:	learn: 0.0637932	total: 19.2s	remaining: 60.2ms
# 636:	learn: 0.0636551	total: 19.2s	remaining: 30.1ms
# 637:	learn: 0.0636008	total: 19.2s	remaining: 0us
# ROC AUC = 0.891
#
# Лучшие параметры модели:
# depth = 9
# grow_policy = SymmetricTree
# iterations = 638
# l2_leaf_reg = 8.224883030406795
# loss_function = CrossEntropy
# min_data_in_leaf = 6
# one_hot_max_size = 8

# %%
# расcчитаем y
y_pred = cbc_model.predict(scaled_X_test)

# оценим метрики
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {round(accuracy, 4)}")
print(f"Precision: {round(precision, 4)}")  
print(f"Recall: {round(recall, 4)}")        
print(f"F1-score: {round(f1, 4)}")

# сохраним данные в таблицу
res = {"Accuracy": round(accuracy, 4),
       "Precision": round(precision, 4),
       "Recall": round(recall, 4),
       "F1-score": round(f1, 4),
       "ROC AUC": round(roc_auc, 4)}

metrics.loc[2] = res
# Out:
# Accuracy: 0.866
# Precision: 0.878
# Recall: 0.8182
# F1-score: 0.8471

# %%
metrics.index = ['RandomForestClassifier', 'GradientBoostingClassifier', 'CatBoostClassifier']
metrics.head()
# Out:
#                             Accuracy  Precision  Recall  F1-score  ROC AUC
# RandomForestClassifier        0.8557     0.8488  0.8295    0.8391   0.8767
# GradientBoostingClassifier    0.8505     0.8734  0.7841    0.8263   0.8919
# CatBoostClassifier            0.8660     0.8780  0.8182    0.8471   0.8910

# %% [markdown]
# #### Вывод
# Было выполнено преобразование признака СC50, mM по бинарному критерию. Критерий оценки состоял из сравнения медианного значения признака СC50, mM с текущим значением данных.
#
# Таким образом данные превосзодившие медианное значение СC50, mM получали значение True, равные или меньшие получали значение False.
#
# Для булевой целевой переменной СC50 были дообработанны данные:
# * Добавлен дополнительный признак IC50, mM в данные для обучения
# * Сокращено количество признаков до 50
# * Данные разделены на тестовыые и тренировочные
# * Проведена стандартизация тренировочных данных и на её основе стандартизированы тестовые данные
#
# Затем были подобраны параметры и построены три модели:
#
# * RandomForestClassifier c параметрами:
#     - bootstrap = True
#     - max_depth = 15
#     - max_features = sqrt
#     - min_samples_leaf = 2
#     - min_samples_split = 2
#     - n_estimators = 263
#
# * GradientBoostingClassifier с параметрами:
#     - max_depth = 19
#     - min_samples_leaf = 5
#     - min_samples_split = 9
#     - n_estimators = 89
#
# * CatBoostClassifier с параметрами:
#     - depth = 9
#     - grow_policy = SymmetricTree
#     - iterations = 638
#     - l2_leaf_reg = 8.224883030406795
#     - loss_function = CrossEntropy
#     - min_data_in_leaf = 6
#     - one_hot_max_size = 8
#
# В качестве метрик для оценки работы модели использовались:
# * Accuracy
# * Precision
# * Recall
# * F1-score
# * ROC AUC
#
# Наилучшие показатели при обучение получились у модели CatBoostClassifier, однако после валидации на тестовых данных, модель GradientBoostingClassifier показала наилучшие результаты.
